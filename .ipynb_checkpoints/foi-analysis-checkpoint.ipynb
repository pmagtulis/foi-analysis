# %% [markdown]
# # FOI requests data analysis
#
# As of November 7, 2022, PST
#
# In this notebook, we use the CSV file generated by the auto-scraper to make our analysis of FOI requests.
#
# Remember that the **foi-ph-scraper** ideally scrapes new information from the website every Sunday of the week. The file generated is in a separate repository, which I will just read in here.
#
# **Note**: There were some weeks in 2022 when the scraper failed to run because the website was down. I'm still in the process of looking into entries that were missed. So far, the scraper runs every three days and fetches 3,000 entries every time. This ensures that new entries (and some old ones are collected). We drop the duplicates in the cleaning process.

# %%
import pandas as pd
import re
import requests
from plotnine import *
pd.set_option("display.max_columns", None)

# %% [markdown]
# ## Read df and clean it
#
# Read through the CSV, remove unnecessary columns, look for NaN values and duplicates, convert to datetime before you go through the data.

# %%
df = pd.read_csv('foi_final.csv')
df.tail(10)
# Out:
# /var/folders/00/cqb74mkn60g_hf2zk42fy8_m0000gp/T/ipykernel_22320/1295593880.py:1: DtypeWarning: Columns (7,8) have mixed types. Specify dtype option on import or set low_memory=False.
#         Unnamed: 0  agency        date  \
# 151739      151739    PCSO  2022-11-07
# 151740      151740    DSWD  2022-11-07
# 151741      151741     DOH  2022-11-07
# 151742      151742     PSA  2022-11-07
# 151743      151743    JJWC  2022-11-07
# 151744      151744     PNP  2022-11-07
# 151745      151745     PNP  2022-11-07
# 151746      151746  NAMRIA  2022-11-07
# 151747      151747     NBI  2022-11-07
# 151748      151748    DOLE  2022-11-07
#
#                                                     title    status  \
# 151739  Financial assistance for my husband to have co...   PENDING
# 151740     4Ps Beneficiaries and Budget from 2007 to 2022  ACCEPTED
# 151741                            REQUEST FOR STROKE DATA   PENDING
# 151742                            REQUEST FOR STROKE DATA   PENDING
# 151743                                    CICL CALABARZON   PENDING
# 151744                                    CICL CALABARZON   PENDING
# 151745                                      CICL REGION 3   PENDING
# 151746  Climate Disaster Risk Assessment of San Juan B...   PENDING
# 151747                                        ONLINE SCAM   PENDING
# 151748                                             Thesis   PENDING
#
#                                                   purpose  \
# 151739  Financial Help for complete medication for my ...
# 151740                                  Research purposes
# 151741                                  RESEARCH PURPOSES
# 151742                                  RESEARCH PURPOSES
# 151743                                    Thesis Research
# 151744                               Architectural Thesis
# 151745                               Architectural Thesis
# 151746                               Architectural Thesis
# 151747                                           Personal
# 151748                                           Research
#
#                  period_covered  \
# 151739  10/20/2022 - 11/07/2022
# 151740  01/01/2007 - 11/01/2022
# 151741  11/07/2022 - 11/07/2022
# 151742  11/07/2022 - 11/07/2022
# 151743  11/07/2022 - 11/07/2022
# 151744  11/07/2022 - 11/07/2022
# 151745  11/07/2022 - 11/07/2022
# 151746  11/07/2022 - 11/07/2022
# 151747  11/06/2022 - 11/07/2022
# 151748  10/28/2021 - 10/28/2021
#
#                                                      link reason_denial
# 151739  https://www.foi.gov.ph/requests/aglzfmVmb2ktcG...           NaN
# 151740  https://www.foi.gov.ph/requests/aglzfmVmb2ktcG...           NaN
# 151741  https://www.foi.gov.ph/requests/aglzfmVmb2ktcG...           NaN
# 151742  https://www.foi.gov.ph/requests/aglzfmVmb2ktcG...           NaN
# 151743  https://www.foi.gov.ph/requests/aglzfmVmb2ktcG...           NaN
# 151744  https://www.foi.gov.ph/requests/aglzfmVmb2ktcG...           NaN
# 151745  https://www.foi.gov.ph/requests/aglzfmVmb2ktcG...           NaN
# 151746  https://www.foi.gov.ph/requests/aglzfmVmb2ktcG...           NaN
# 151747  https://www.foi.gov.ph/requests/aglzfmVmb2ktcG...           NaN
# 151748  https://www.foi.gov.ph/requests/aglzfmVmb2ktcG...           NaN

# %% [markdown]
# ## Drop 'Unnamed' column

# %%
df=df.drop('Unnamed: 0', axis=1)
df
# Out:
#         agency        date                                              title  \
# 0         DICT  2016-11-25  Projects to be implemented by the DICT for the...
# 1          NAP  2016-11-25  Juan Arellano Drawings and Plans of Plaza Impr...
# 2          PNP  2016-11-25  Number of robbery, rape and riding in tandem c...
# 3          PSA  2016-11-25         Ethnographic Population in the Philippines
# 4         PCOO  2016-11-25                                           Agencies
# ...        ...         ...                                                ...
# 151744     PNP  2022-11-07                                    CICL CALABARZON
# 151745     PNP  2022-11-07                                      CICL REGION 3
# 151746  NAMRIA  2022-11-07  Climate Disaster Risk Assessment of San Juan B...
# 151747     NBI  2022-11-07                                        ONLINE SCAM
# 151748    DOLE  2022-11-07                                             Thesis
#
#             status                                            purpose  \
# 0         ACCEPTED                                           Research
# 1       SUCCESSFUL  Research work on urban and public history duri...
# 2           CLOSED                                           Research
# 3       SUCCESSFUL                                           Research
# 4           DENIED                 Research and basis of authenticity
# ...            ...                                                ...
# 151744     PENDING                               Architectural Thesis
# 151745     PENDING                               Architectural Thesis
# 151746     PENDING                               Architectural Thesis
# 151747     PENDING                                           Personal
# 151748     PENDING                                           Research
#
#                  period_covered  \
# 0       11/25/2016 - 11/25/2016
# 1       01/01/1930 - 12/31/1950
# 2       06/01/2006 - 11/01/2016
# 3       11/25/2000 - 11/25/2016
# 4       07/01/2016 - 11/25/2016
# ...                         ...
# 151744  11/07/2022 - 11/07/2022
# 151745  11/07/2022 - 11/07/2022
# 151746  11/07/2022 - 11/07/2022
# 151747  11/06/2022 - 11/07/2022
# 151748  10/28/2021 - 10/28/2021
#
#                                                      link reason_denial
# 0                                                     NaN             —
# 1                                                     NaN             —
# 2                                                     NaN             —
# 3                                                     NaN             —
# 4                                                     NaN             —
# ...                                                   ...           ...
# 151744  https://www.foi.gov.ph/requests/aglzfmVmb2ktcG...           NaN
# 151745  https://www.foi.gov.ph/requests/aglzfmVmb2ktcG...           NaN
# 151746  https://www.foi.gov.ph/requests/aglzfmVmb2ktcG...           NaN
# 151747  https://www.foi.gov.ph/requests/aglzfmVmb2ktcG...           NaN
# 151748  https://www.foi.gov.ph/requests/aglzfmVmb2ktcG...           NaN
#
# [151749 rows x 8 columns]

# %% [markdown]
# ## Convert to datetime

# %%
df.dtypes
# Out:
# agency            object
# date              object
# title             object
# status            object
# purpose           object
# period_covered    object
# link              object
# reason_denial     object
# dtype: object

# %%
df.date = pd.to_datetime(df.date)

# %%
df.dtypes
# Out:
# agency                    object
# date              datetime64[ns]
# title                     object
# status                    object
# purpose                   object
# period_covered            object
# link                      object
# reason_denial             object
# dtype: object

# %% [markdown]
# ## Check for duplicates
#
# There are some duplicates found, but let's check. Remember, we only drop the duplicates if they are the same across **all columns**. Otherwise, we keep them, especially if the same requests are filed with different agencies.

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df[df.duplicated()]
# Out:
# Empty DataFrame
# Columns: [agency, date, title, status, purpose, period_covered, link, reason_denial]
# Index: []

# %% [markdown]
# ## Looking into the NaNs
#
# We look for null values and whether they account for significant number of the data.

# %%
df.isna().sum()
# Out:
# agency                1
# date                  0
# title                 3
# status                0
# purpose               4
# period_covered        0
# link              90765
# reason_denial     60984
# dtype: int64

# %% [markdown]
# Interpretation: The **link** column have nearly 91,000 null values. This is because a large part of the data in our df came from an existing CSV maintained by the government. The same goes for **reason_denial.**
#
# You can find the CSV here: https://docs.google.com/spreadsheets/d/1kblO1_-gL65qXu_EJJBvc59UUHBQ7K3c/edit?fbclid=IwAR332h3xXbevTcnDiKQwKWldsod3kPP3J0T9_5NSXALgFI7XZPyIxMuqXg0#gid=875187444
#
# The data is updated quarterly. We merged this data early on with the scraped data from the website.

# %% [markdown]
# ## Analysis
#
# Now that we have all the requests contained in one file, we can now analyze them, still using pandas.

# %% [markdown]
# ## How much of the requests are granted or denied?

# %%
df.status.value_counts(normalize=True) *100
# Out:
# SUCCESSFUL                35.832197
# DENIED                    22.301300
# PENDING                   17.461071
# ACCEPTED                   7.399719
# PARTIALLY SUCCESSFUL       6.522613
# AWAITING CLARIFICATION     3.692940
# REFERRED                   2.578600
# CLOSED                     2.282717
# PROCESSING                 1.879419
# EXTENDED                   0.049424
# Name: status, dtype: float64

# %%
(
    ggplot(df) + 
    geom_bar(aes(x="status")) + 
    theme(figure_size=(15,7), axis_ticks_length=10) + 
    labs(title="Over 1 in 4 FOI requests denied")
)
# Out:
# <ggplot: (686133537)>

# %% [markdown]
# Note: We are still seeking clarification from PCOO on what **CLOSED** means. Meanwhile, over one in four FOI requests are denied by agencies. Over half are **successful** or **partially sucessful**.

# %% [markdown]
# ## Which agencies get the most FOI requests?

# %%
df.agency.value_counts().head(10)
# Out:
# DOH      15123
# PSA       8733
# DOLE      6419
# BIR       6394
# DepEd     6241
# SSS       5277
# DSWD      5212
# NTC       4540
# OWWA      4356
# DPWH      3819
# Name: agency, dtype: int64

# %% [markdown]
# The Department of Health, Philippine Statistics Authority and the labor department get the most requests.

# %% [markdown]
# ## Which agencies deny the most requests?
#
# The Bureau of Internal Revenue tops the list, although a deeper probe would show most of the denials were a result of requests for personal tax records, which are not for public consumption.

# %%
df[df.status=="DENIED"].agency.value_counts().head(10)
# Out:
# BIR     3429
# DSWD    3079
# NBI     1600
# DENR    1439
# DOH     1237
# DTI     1175
# DOLE     877
# DOTr     866
# HDMF     818
# NTC      756
# Name: agency, dtype: int64

# %% [markdown]
# # Drilling down on specific agencies and requests
#
# We select a few agencies and search in their request files some of the most common requests by **title** as well as some of the most denials.

# %% [markdown]
# ## DOH: Vaccination certificates

# %%
df[df.agency=="DOH"].title.value_counts().head(20)
# Out:
# Vaccination Certificate           442
# Vaxcert                           292
# VaxCert                           141
# Vaccination Card                  138
# Vaccine Certificate               128
# Vaccination certificate           115
# Lost Vaccination Card             113
# Lost Vaccine Card                  95
# VAXCERT                            81
# Vax Cert                           72
# Vax Certificate                    67
# Vaccination card                   61
# Vaccine certificate                58
# VACCINATION CERTIFICATE            58
# VaxCertPH                          50
# Vaxcert; incorrect middle name     48
# vaxcert                            46
# Vaccine Card                       40
# Vaxcertificate                     37
# vaccination certificate            36
# Name: title, dtype: int64

# %%
vax = ["Vaccination Certificate", "Vaxcert", "VaxCert", "Vaccination certificate", "Vax Cert", "VAXCERT", "VAX CERT", "Vax Certificate", "Vax certificate", "VACCINATION CERTIFICATE", "Vax cert", "VaxCertPH", "Vax Cert PH", "vax cert", "Vax cert request", "Vax Cert Request", "Vaccination Card", "Vax card", "vaccination card", "Vaccine certificate", "vaccine certificate"]
df_vax = df[df['title'].isin(vax)].reset_index(drop=True)
df_vax.count()
# Out:
# agency            1754
# date              1754
# title             1754
# status            1754
# purpose           1754
# period_covered    1754
# link              1318
# reason_denial      436
# dtype: int64

# %% [markdown]
# Interpretation: Over one in 10 DOH requests from 2016 were to request for vaccination certificates.

# %% [markdown]
# ## DSWD: Social amelioration program
#
# This is the P275-billion pandemic relief program by the government in 2020 that gave dole outs to poor families. The program were given in two tranches and were marred by significant delays and other irregularities.

# %%
sap = ["SAP", "SAP 2nd tranche", "Sap 2nd tranche", "Social Amelioration Program", "Social amelioration program", "sap 2nd tranche", "SAP 2nd tranche", "2nd tranche", "DSWD SAP", "SAP 2ND TRANCHE", "Sap 2nd Tranche", "SAP 1st tranche", "SAP first tranche", "SAP 1ST TRANCHE", "Sap"]
df_sap = df[df['title'].isin(sap)].reset_index(drop=True)
df_sap[df_sap.status=="DENIED"].head(10)
# Out:
#   agency       date                        title  status  \
# 0   DSWD 2020-04-09  Social amelioration program  DENIED
# 1   DSWD 2020-04-21                          Sap  DENIED
# 2   DSWD 2020-04-21  Social Amelioration Program  DENIED
# 3   DSWD 2020-04-23  Social Amelioration Program  DENIED
# 4   DSWD 2020-04-25  Social Amelioration Program  DENIED
# 5   DSWD 2020-04-27  Social Amelioration Program  DENIED
# 6   DSWD 2020-04-27                     DSWD SAP  DENIED
# 7   DSWD 2020-05-01  Social Amelioration Program  DENIED
# 8   DSWD 2020-05-01                          SAP  DENIED
# 9   DSWD 2020-05-03                          Sap  DENIED
#
#                                              purpose           period_covered  \
# 0                          Personal information only  04/09/2020 - 04/09/2020
# 1                                        Solo parent  04/08/2020 - 04/21/2020
# 2             Transparency purposes to my kabarangay  04/01/2020 - 04/21/2020
# 3                        Validation and Confirmation  04/23/2020 - 04/23/2020
# 4  To known the list of beneficiaries of Social A...  03/01/2020 - 04/25/2020
# 5                                       Transparency  04/19/2020 - 04/27/2020
# 6    To know the status of DSWD SAP in our Barangay.  04/27/2020 - 04/27/2020
# 7                        Social Amelioration Program  03/16/2020 - 04/30/2020
# 8                                    SAP APPLICATION  05/01/2020 - 05/01/2020
# 9          Applying for special amelioration program  03/21/2020 - 04/21/2020
#
#   link       reason_denial
# 0  NaN                   —
# 1  NaN                   —
# 2  NaN                   —
# 3  NaN                   —
# 4  NaN                   —
# 5  NaN                   —
# 6  NaN                   —
# 7  NaN  incomplete-request
# 8  NaN                   —
# 9  NaN                   —

# %% [markdown]
# Interpretation: Most requests for SAP were denied and were deemed an "invalid request."

# %%
df_sap.count()
#180 requests about SAP.
# Out:
# agency            182
# date              182
# title             182
# status            182
# purpose           182
# period_covered    182
# link                7
# reason_denial     175
# dtype: int64

# %% [markdown]
# ## OVP: Any type of "assistance"
#
# The office of former Vice President Leni Robredo is known for its **Angat Buhay** program that helps the poor.

# %%
df[df.agency=="OVP"].title.str.contains("assistance", regex=False, case=False).value_counts()
# Out:
# False    612
# True     440
# Name: title, dtype: int64

# %% [markdown]
# Interpretation: 40% of OVP FOI requests mention some form of "assistance".

# %% [markdown]
# ## BIR: Tax identification number or TIN
#
# Tax matters are generally protected by privacy laws in the Philippines. But that did not stop some people to request for them through FOI.

# %%
#df_final[df_final.title=="Income Tax Return"]
tax = ['Income Tax Return', 'ITR','BIR 2316', 'TIN Verification', 'TIN VERIFICATION', 'BIR Form 2316', 'Income tax return', 'TIN', 'INCOME TAX RETURN', 'Form 2316', 'TIN NUMBER', 'tin number', 'TIN verification', 'tax', 'tax records']
df_tax = df[df['title'].isin(tax)].reset_index(drop=True)
df_tax.tail(10)
# Out:
#      agency       date              title                  status  \
# 1668    BIR 2022-10-19           BIR 2316                  DENIED
# 1669    BIR 2022-10-21  Income Tax Return              SUCCESSFUL
# 1670    BIR 2022-10-22   TIN Verification                  DENIED
# 1671    BIR 2022-10-23          Form 2316              SUCCESSFUL
# 1672    BIR 2022-10-23          Form 2316  AWAITING CLARIFICATION
# 1673    BIR 2022-10-23  Income Tax Return  AWAITING CLARIFICATION
# 1674    BIR 2022-10-26  Income Tax Return                  DENIED
# 1675    BIR 2022-11-02  Income Tax Return              SUCCESSFUL
# 1676    BIR 2022-11-02  Income Tax Return              SUCCESSFUL
# 1677    BIR 2022-11-04  Income Tax Return              SUCCESSFUL
#
#                                                 purpose  \
# 1668  Pay evidence for each period of employment to ...
# 1669        Proof of income for credit card application
# 1670      Local employment (pre-employment requirement)
# 1671                     For application aboad purposes
# 1672                  For application to aboad purposes
# 1673                        Application for scholarship
# 1674                            Scholarship application
# 1675                                   Visa Application
# 1676  For my Credit Card Application and VISA Requir...
# 1677                                   Visa Application
#
#                period_covered  \
# 1668  01/01/2010 - 12/31/2016
# 1669  01/01/2021 - 09/30/2022
# 1670  02/10/2016 - 10/22/2022
# 1671  01/01/2015 - 05/31/2019
# 1672  01/01/2015 - 05/31/2019
# 1673  10/23/2022 - 10/23/2022
# 1674  09/01/2022 - 10/26/2022
# 1675  10/01/2018 - 10/31/2022
# 1676  01/01/2022 - 10/31/2022
# 1677  11/02/2021 - 11/04/2022
#
#                                                    link reason_denial
# 1668  https://www.foi.gov.ph/requests/aglzfmVmb2ktcG...           NaN
# 1669  https://www.foi.gov.ph/requests/aglzfmVmb2ktcG...           NaN
# 1670  https://www.foi.gov.ph/requests/aglzfmVmb2ktcG...           NaN
# 1671  https://www.foi.gov.ph/requests/aglzfmVmb2ktcG...           NaN
# 1672  https://www.foi.gov.ph/requests/aglzfmVmb2ktcG...           NaN
# 1673  https://www.foi.gov.ph/requests/aglzfmVmb2ktcG...           NaN
# 1674  https://www.foi.gov.ph/requests/aglzfmVmb2ktcG...           NaN
# 1675  https://www.foi.gov.ph/requests/aglzfmVmb2ktcG...           NaN
# 1676  https://www.foi.gov.ph/requests/aglzfmVmb2ktcG...           NaN
# 1677  https://www.foi.gov.ph/requests/aglzfmVmb2ktcG...           NaN

# %%
df_tax.status.value_counts()
# Out:
# DENIED                    743
# AWAITING CLARIFICATION    568
# SUCCESSFUL                121
# PENDING                   115
# ACCEPTED                   55
# PARTIALLY SUCCESSFUL       47
# REFERRED                   15
# CLOSED                      8
# PROCESSING                  5
# EXTENDED                    1
# Name: status, dtype: int64

# %%
df_tax.status.value_counts(normalize=True) *100
# Out:
# DENIED                    44.278903
# AWAITING CLARIFICATION    33.849821
# SUCCESSFUL                 7.210965
# PENDING                    6.853397
# ACCEPTED                   3.277712
# PARTIALLY SUCCESSFUL       2.800954
# REFERRED                   0.893921
# CLOSED                     0.476758
# PROCESSING                 0.297974
# EXTENDED                   0.059595
# Name: status, dtype: float64

# %% [markdown]
# # Top purpose of requests

# %%
df.purpose.value_counts(ascending=False).head(10)
# Out:
# Research                    12026
# Research and Development     6058
# Undergraduate Thesis         2740
# Thesis                       2704
# Architectural Thesis         2523
# Research and development     2405
# Academic Research            1034
# Thesis Research              1009
# research                      707
# Undergraduate Research        598
# Name: purpose, dtype: int64

# %% [markdown]
# ## For academic purposes

# %%
research = df.purpose.str.extractall(r'(.*\bresearch.+)', re.IGNORECASE)
research
# Out:
#                                                               0
#        match
# 1      0      Research work on urban and public history duri...
# 4      0                     Research and basis of authenticity
# 11     0                                 Research & Development
# 12     0                                         Research study
# 15     0                               Research and Development
# ...                                                         ...
# 151724 0                               Research and Development
# 151728 0                               Research and Development
# 151740 0                                      Research purposes
# 151741 0                                      RESEARCH PURPOSES
# 151742 0                                      RESEARCH PURPOSES
#
# [27999 rows x 1 columns]

# %%
thesis = df.purpose.str.extractall(r'(.*\bthesis.+)', re.IGNORECASE)
thesis
# Out:
#                                                               0
#        match
# 24     0      Architectural Thesis entitled Cagayan de Oro C...
# 27     0                          School Paper Research(Thesis)
# 30     0                                        Thesis Research
# 39     0      Research for Cebu City Development to be used ...
# 108    0                       Research / Possible Thesis Study
# ...                                                         ...
# 151684 0                          Architectural Thesis Research
# 151693 0                               For thesis purposes only
# 151709 0                                     For thesis writing
# 151721 0                           Architectural Thesis Writing
# 151743 0                                        Thesis Research
#
# [9426 rows x 1 columns]

# %%
academic = df.purpose.str.extractall(r'(.*\bacademic.+)', re.IGNORECASE)
academic
# Out:
#                                                        0
#        match
# 82     0                               Academic research
# 365    0                               Academic research
# 384    0                               Academic Research
# 457    0                               Academic research
# 463    0                               Academic Research
# ...                                                  ...
# 151636 0                  Plant Design/Academic Research
# 151657 0      Research is intended for Academic purposes
# 151698 0                                 Academic/Thesis
# 151700 0                               Academic Purposes
# 151714 0       Academic Purpose - Architectural Research
#
# [4195 rows x 1 columns]

# %%
research_2 = pd.concat([research, academic, thesis], ignore_index=True)
research_2.columns= ['purpose']
research_2
# Out:
#                                                  purpose
# 0      Research work on urban and public history duri...
# 1                     Research and basis of authenticity
# 2                                 Research & Development
# 3                                         Research study
# 4                               Research and Development
# ...                                                  ...
# 41615                      Architectural Thesis Research
# 41616                           For thesis purposes only
# 41617                                 For thesis writing
# 41618                       Architectural Thesis Writing
# 41619                                    Thesis Research
#
# [41620 rows x 1 columns]

# %%
# research_2 = research_2.merge(df, on='purpose')
# research_2.duplicated().value_counts()

# %%
#research_2[research_2.duplicated()]

# %% [markdown]
# ## For journalistic purposes

# %%
news = df.purpose.str.extractall(r'(.*\bnews.+)', re.IGNORECASE)
news
# Out:
#                                                               0
#        match
# 68     0                                           news article
# 74     0                                           news article
# 85     0                                            News report
# 210    0      This will be used for the verification of "new...
# 247    0                              Research and news article
# ...                                                         ...
# 139543 0                              Investigative News Report
# 139766 0                              Investigative News Report
# 140005 0      verification purposes. in support for news abo...
# 145105 0                                  Research, news report
# 148334 0                                   News article writing
#
# [336 rows x 1 columns]

# %%
media = df.purpose.str.extractall(r'(.*\bmedia.+)', re.IGNORECASE)

# %%
journalism = pd.concat([news, media], ignore_index=True)
journalism.columns= ['purpose']
journalism
# Out:
#                                                purpose
# 0                                         news article
# 1                                         news article
# 2                                          News report
# 3    This will be used for the verification of "new...
# 4                            Research and news article
# ..                                                 ...
# 556  Academic research in COMM 120 (Laws on Communi...
# 557  Academic research in COMM 120 (Laws on Communi...
# 558                                     Media coverage
# 559                                     Media coverage
# 560  To stop public shaming on social media and on ...
#
# [561 rows x 1 columns]

# %%
journalism = journalism.merge(df, on='purpose')
journalism.duplicated().sum()
# Out:
# 1960

# %%
journalism = journalism.drop_duplicates().reset_index(drop=True)
journalism
# Out:
#                                                purpose agency       date  \
# 0                                         news article    PNP 2016-11-27
# 1                                         news article    PNP 2016-11-27
# 2                                          News report    DBM 2016-11-28
# 3                                          News report   PCOO 2017-01-27
# 4                                          News report   PDEA 2017-11-21
# ..                                                 ...    ...        ...
# 546  Academic research in COMM 120 (Laws on Communi...   DOTr 2022-10-08
# 547  Academic research in COMM 120 (Laws on Communi...   DOTr 2022-10-08
# 548                                     Media coverage    PNP 2022-10-11
# 549                                     Media coverage    PNP 2022-10-11
# 550  To stop public shaming on social media and on ...    NPC 2022-10-13
#
#                                                  title  \
# 0                                        oplan tokhang
# 1    PNP Region 9 Director Billy Beltran and PNP Ge...
# 2    Cost of President Duterte's trip to Laos, Chin...
# 3    Cost of each of President Duterte's foreign tr...
# 4                            Statistics on drug prices
# ..                                                 ...
# 546  Proposed developments for the construction of ...
# 547  Proposed developments for the construction of ...
# 548          The homicide case of Randel Valdez Balnek
# 549          The homicide case of Randel Valdez Balnek
# 550                    Harassing by an online loan app
#
#                      status           period_covered  \
# 0                SUCCESSFUL  07/01/2016 - 11/02/2016
# 1                    DENIED  06/01/2016 - 07/02/2016
# 2                    DENIED  09/05/2016 - 11/23/2016
# 3                    DENIED  09/05/2016 - 12/17/2016
# 4                    DENIED  07/01/2016 - 11/21/2017
# ..                      ...                      ...
# 546  AWAITING CLARIFICATION  02/01/2019 - 10/07/2022
# 547                 PENDING  02/01/2019 - 10/07/2022
# 548              SUCCESSFUL  10/06/2022 - 10/08/2022
# 549              PROCESSING  10/06/2022 - 10/08/2022
# 550                 PENDING  09/01/2022 - 10/13/2022
#
#                                                   link       reason_denial
# 0                                                  NaN                   —
# 1                                                  NaN  incomplete-request
# 2                                                  NaN                   —
# 3                                                  NaN        wrong-agency
# 4                                                  NaN                   —
# ..                                                 ...                 ...
# 546  https://www.foi.gov.ph/requests/aglzfmVmb2ktcG...                 NaN
# 547  https://www.foi.gov.ph/requests/aglzfmVmb2ktcG...                 NaN
# 548  https://www.foi.gov.ph/requests/aglzfmVmb2ktcG...                 NaN
# 549  https://www.foi.gov.ph/requests/aglzfmVmb2ktcG...                 NaN
# 550  https://www.foi.gov.ph/requests/aglzfmVmb2ktcG...                 NaN
#
# [551 rows x 8 columns]

# %% [markdown]
# # Know each agencies' performance
#
# Just changed the name of the agency in brackets.

# %%
df[df.agency=="OP"]
#There were some requests for SALN.
# Out:
#        agency       date                                              title  \
# 2567       OP 2017-12-01  Total cost/expenses for the foreign trips of P...
# 2595       OP 2017-12-04  Cost of President Duterte's foreign trips in h...
# 2603       OP 2017-12-05  Updates on the appeals of suspended and closed...
# 2703       OP 2017-12-24                    2018 General Appropriations Act
# 2720       OP 2017-12-30                     Executive Order 126 dated 1959
# 3026       OP 2018-01-31     NSC Group Photos with Living Former Presidents
# 3168       OP 2018-02-11  Documentary proof or evidence of President Dut...
# 3179       OP 2018-02-11  What is the counterpart of the CIA in the Phil...
# 3183       OP 2018-02-11  Breakdown of War Materiel used by the AFP in t...
# 3227       OP 2018-02-13               Actual Expenses of ASEAN 2017 budget
# 3470       OP 2018-03-03  Impact of OFW remittances on the Philippine Ec...
# 3481       OP 2018-03-04                                 Appointment Papers
# 75704      OP 2021-09-29    Statement of Assets, Liabilities, and Net Worth
# 77091      OP 2021-10-07  Statement of Assets, Liabilities, and Net Wort...
# 77146      OP 2021-10-07  Statement of Assets, Liabilities, and Net Wort...
# 78928      OP 2021-10-18  Accomplishments and Negative Impact of late Fe...
# 83986      OP 2021-11-15  PRESIDENTIAL SINCE 1965 BUDGET FROM START OF T...
# 87339      OP 2021-12-03             National Budget from Marcos Presidency
# 87347      OP 2021-12-03  You money building you steal everything you fo...
# 96801      OP 2022-02-08          Government Directory from 1900 to present
# 106210     OP 2022-03-19                       SALN - Agnes Joyce G. Bailen
# 109376     OP 2022-04-01                                            IRR for
# 110110     OP 2022-04-04  List of places visited by President Rodrigo Ro...
# 116319     OP 2022-05-04  Budget ni President Marcos sa loob ng 20 years...
# 128838     OP 2022-07-27            IRR of Executive Order No. 249, s. 1987
# 134057     OP 2022-08-23                           Presidential Decree 1158
# 137752     OP 2022-09-07                                          EO No. 77
# 142291     OP 2022-09-29  Request for list of Newly appointed Undersecre...
# 142322     OP 2022-09-29    Lot Technical Description - La Trinidad Benguet
# 142935     OP 2022-10-03  Request for list of Newly appointed Undersecre...
# 143030     OP 2022-10-03  Request for the Official Portraits of Presiden...
# 146790     OP 2022-10-18  List of President Bong Bong Marcos' Travels fr...
# 150791     OP 2022-11-02  Data regarding Executive Order No. 6, series o...
# 150900     OP 2022-11-02  Number of Complaints received through the 8888...
#
#          status                                            purpose  \
# 2567    PENDING  For research purposes for my year-end report f...
# 2595    PENDING                                      News research
# 2603    PENDING                                           Research
# 2703    PENDING  Factual basis in research and review of certai...
# 2720    PENDING                                            HISTORY
# 3026    PENDING                     Research and Archive purposes.
# 3168    PENDING                Research for Graduate School class.
# 3179    PENDING                                           Research
# 3183    PENDING                Research for Graduate School class.
# 3227    PENDING                                  Research purposes
# 3470    PENDING                                 Practical Research
# 3481    PENDING                       Personal Reference / Inquiry
# 75704   PENDING               Research and other academic purposes
# 77091   PENDING                     Academic and Research purposes
# 77146   PENDING                     Academic and Research Purposes
# 78928   PENDING                           Research and Development
# 83986   PENDING  I Want to do a small study for my own educatio...
# 87339   PENDING                              For Research Purposes
# 87347   PENDING  Pera lahat records justices Icc criminal court...
# 96801   PENDING                             Undergraduate Research
# 106210  PENDING  Research and development - voter education, kn...
# 109376  PENDING  To be used as part of document for the entitle...
# 110110  PENDING                           Research and Development
# 116319  PENDING                                           RESEARCH
# 128838  PENDING  Information request on behalf of library resea...
# 134057  PENDING                                           Research
# 137752  PENDING                         For clarify of information
# 142291  PENDING                           Research and Development
# 142322  PENDING         Conduct of Academic Architectural Research
# 142935  PENDING                           Research and Development
# 143030  PENDING               Educational and Informative Purposes
# 146790  PENDING                                For Academic Report
# 150791  PENDING                             For Research Purposes.
# 150900  PENDING     This is for research purposes, for our thesis.
#
#                  period_covered  \
# 2567    01/01/2017 - 12/01/2017
# 2595    07/01/2016 - 07/01/2017
# 2603    02/02/2017 - 12/05/2017
# 2703    12/24/2017 - 12/24/2017
# 2720    12/30/2017 - 12/30/2017
# 3026    07/27/2016 - 07/27/2016
# 3168    03/28/1945 - 02/11/2018
# 3179    02/11/2018 - 02/11/2018
# 3183    05/23/2017 - 11/23/2017
# 3227    01/01/2017 - 01/01/2018
# 3470    02/25/2018 - 03/03/2018
# 3481    06/30/2016 - 03/04/2018
# 75704   01/01/2018 - 12/31/2020
# 77091   01/01/2018 - 10/01/2020
# 77146   01/01/2018 - 10/01/2020
# 78928   09/21/1972 - 09/21/1986
# 83986   12/30/1965 - 11/14/2021
# 87339   12/30/1965 - 12/02/2021
# 87347   12/01/2021 - 12/01/2021
# 96801   01/01/1900 - 01/01/2022
# 106210  01/01/2021 - 12/31/2021
# 109376  05/01/2021 - 10/30/2021
# 110110  06/01/2016 - 04/02/2022
# 116319  05/01/2022 - 05/04/2022
# 128838  01/01/1987 - 12/31/2021
# 134057  06/03/1977 - 01/01/1998
# 137752  09/06/2022 - 09/06/2022
# 142291  07/01/2022 - 09/28/2022
# 142322  11/11/1914 - 09/28/2022
# 142935  06/01/2022 - 10/03/2022
# 143030  01/01/1899 - 10/02/2022
# 146790  06/30/2022 - 10/08/2022
# 150791  08/30/2016 - 10/30/2016
# 150900  08/30/2016 - 10/30/2022
#
#                                                      link reason_denial
# 2567                                                  NaN             —
# 2595                                                  NaN             —
# 2603                                                  NaN             —
# 2703                                                  NaN             —
# 2720                                                  NaN             —
# 3026                                                  NaN             —
# 3168                                                  NaN             —
# 3179                                                  NaN             —
# 3183                                                  NaN             —
# 3227                                                  NaN             —
# 3470                                                  NaN             —
# 3481                                                  NaN             —
# 75704                                                 NaN             —
# 77091                                                 NaN             —
# 77146                                                 NaN             —
# 78928                                                 NaN             —
# 83986                                                 NaN             —
# 87339                                                 NaN             —
# 87347                                                 NaN             —
# 96801   https://www.foi.gov.ph/requests/aglzfmVmb2ktcG...           NaN
# 106210  https://www.foi.gov.ph/requests/aglzfmVmb2ktcG...           NaN
# 109376  https://www.foi.gov.ph/requests/aglzfmVmb2ktcG...           NaN
# 110110  https://www.foi.gov.ph/requests/aglzfmVmb2ktcG...           NaN
# 116319  https://www.foi.gov.ph/requests/aglzfmVmb2ktcG...           NaN
# 128838  https://www.foi.gov.ph/requests/aglzfmVmb2ktcG...           NaN
# 134057  https://www.foi.gov.ph/requests/aglzfmVmb2ktcG...           NaN
# 137752  https://www.foi.gov.ph/requests/aglzfmVmb2ktcG...           NaN
# 142291  https://www.foi.gov.ph/requests/aglzfmVmb2ktcG...           NaN
# 142322  https://www.foi.gov.ph/requests/aglzfmVmb2ktcG...           NaN
# 142935  https://www.foi.gov.ph/requests/aglzfmVmb2ktcG...           NaN
# 143030  https://www.foi.gov.ph/requests/aglzfmVmb2ktcG...           NaN
# 146790  https://www.foi.gov.ph/requests/aglzfmVmb2ktcG...           NaN
# 150791  https://www.foi.gov.ph/requests/aglzfmVmb2ktcG...           NaN
# 150900  https://www.foi.gov.ph/requests/aglzfmVmb2ktcG...           NaN

# %% [markdown]
# ## Government contracts

# %%
contract = ['contract', 'contracts', 'audit', 'audit report', 'Audit report', 'Audit Report', 'Contract', 'Contracts', 'loan agreement', 'Agreements', 'Agreement', 'agreement', 'agreements']
df_contract = df[df['title'].isin(contract)].reset_index(drop=True)
df_contract.head(7)
# Out:
#   agency       date         title    status  \
# 0   LRTA 2019-03-29      Contract    DENIED
# 1    DFA 2021-03-14  Audit Report    DENIED
# 2   PPPC 2022-06-19     Contracts    DENIED
# 3    LTO 2022-06-19      Contract   PENDING
# 4    LRA 2022-06-19      Contract   PENDING
# 5   PPPC 2022-06-19     Contracts   PENDING
# 6   PPPC 2022-06-19     Contracts  ACCEPTED
#
#                                purpose           period_covered  \
# 0  For own personal use or information  01/01/2018 - 12/31/2018
# 1                     Research Purpose  01/01/2018 - 07/30/2020
# 2             Research and Development  06/19/2020 - 06/19/2022
# 3                             Research  06/19/2020 - 06/19/2022
# 4                             Research  06/19/2020 - 06/19/2022
# 5             Research and Development  06/19/2020 - 06/19/2022
# 6             Research and Development  06/19/2020 - 06/19/2022
#
#                                                 link  \
# 0                                                NaN
# 1                                                NaN
# 2  https://www.foi.gov.ph/requests/aglzfmVmb2ktcG...
# 3  https://www.foi.gov.ph/requests/aglzfmVmb2ktcG...
# 4  https://www.foi.gov.ph/requests/aglzfmVmb2ktcG...
# 5  https://www.foi.gov.ph/requests/aglzfmVmb2ktcG...
# 6  https://www.foi.gov.ph/requests/aglzfmVmb2ktcG...
#
#                   reason_denial
# 0                             —
# 1  information-available-online
# 2                           NaN
# 3                           NaN
# 4                           NaN
# 5                           NaN
# 6                           NaN

# %% [markdown]
# ## Top reasons for denial
#
# Applicable only to data as of December 2021.

# %%
df.reason_denial.value_counts(dropna=False)
#"-" means it's not applicable since the request was not denied.
# Out:
# —                               77314
# NaN                             60984
# wrong-agency                     6980
# incomplete-request               2764
# invalid-request                  2084
# information-available-online     1620
# exceptions                          2
# privacy                             1
# Name: reason_denial, dtype: int64

# %%
df[df.reason_denial=='wrong-agency'].tail(10)
# Out:
#       agency       date                                              title  \
# 89730   CHED 2021-12-18                                 Request for laptop
# 89765   DOTr 2021-12-18          Kalibo International Airport Informations
# 89806    NTC 2021-12-19  Requesting for Individual/Company name uses th...
# 89808     PH 2021-12-19                            Vaccination Certificate
# 89812     PH 2021-12-19                             VaccinationCertificate
# 90063   DENR 2021-12-21  Certificate of ancestral domain title in Sioco...
# 90256   CHED 2021-12-23                              Registration Form 001
# 90381    NAP 2021-12-27                                       Birth Record
# 90567    DAR 2021-12-28         CLUP and Zoning Ordinance of Angono, Rizal
# 90733    DOJ 2021-12-31                                        INFORMATION
#
#        status                                            purpose  \
# 89730  DENIED            Educational and future career purposes.
# 89765  DENIED                                Research for Thesis
# 89806  DENIED  All my contacts got an sms blast from this num...
# 89808  DENIED                                          To Travel
# 89812  DENIED                                          To travel
# 90063  DENIED  To verify that who is the head of CADT in Siti...
# 90256  DENIED                            Employment Requirements
# 90381  DENIED                                SSS Funeral Benefit
# 90567  DENIED                                           Research
# 90733  DENIED                         RESOLUTION AND INFORMATION
#
#                 period_covered link reason_denial
# 89730  11/26/2021 - 12/18/2021  NaN  wrong-agency
# 89765  12/18/2021 - 12/18/2021  NaN  wrong-agency
# 89806  12/19/2021 - 12/19/2021  NaN  wrong-agency
# 89808  06/14/2021 - 07/12/2021  NaN  wrong-agency
# 89812  06/14/2021 - 07/12/2021  NaN  wrong-agency
# 90063  12/21/2021 - 12/21/2021  NaN  wrong-agency
# 90256  01/01/2018 - 12/23/2021  NaN  wrong-agency
# 90381  07/09/1943 - 07/09/1945  NaN  wrong-agency
# 90567  12/28/2021 - 12/28/2021  NaN  wrong-agency
# 90733  11/19/2021 - 12/31/2021  NaN  wrong-agency

# %%
df.status.value_counts()
# Out:
# SUCCESSFUL                54375
# DENIED                    33842
# PENDING                   26497
# ACCEPTED                  11229
# PARTIALLY SUCCESSFUL       9898
# AWAITING CLARIFICATION     5604
# REFERRED                   3913
# CLOSED                     3464
# PROCESSING                 2852
# EXTENDED                     75
# Name: status, dtype: int64

# %% [markdown]
# # SALN requests, anyone?
#
# Stands for "Statements of Assets, Liabilities and Net Worth" filed by public officials every year.

# %%
df.title.str.contains("SALN", regex=False, case=False).value_counts()
# Out:
# False    151454
# True        292
# Name: title, dtype: int64

# %% [markdown]
# Over 200 requests using the exact words "SALN" on the FOI portal. Below, we use a regex pattern to screen this more.

# %%
saln = df.title.str.extractall(r'(.*\bSALN.+)', re.IGNORECASE)
saln.columns= ['title']
#374 requests mentioning SALN.

# %%
saln = saln.merge(df, on='title')
saln
# Out:
#                                                  title agency       date  \
# 0                              SALN of Bongbong Marcos   DOTr 2016-11-25
# 1    SALN of the following: Ronnan Y. Pado, Ernani ...    DOF 2016-12-05
# 2    SALN of Niño Maximino A. Lazaro Municipal Coun...    DOF 2016-12-17
# 3    The SALNs of each of the cabinet members of th...   PCOO 2016-12-23
# 4    The SALNs of Presidents Aquino and Duterte's C...   PCOO 2017-01-18
# ..                                                 ...    ...        ...
# 482         SALN of Gerald Bantag as employee of BuCor    DOJ 2022-10-28
# 483         SALN of Gerald Bantag as employee of BuCor    DOJ 2022-10-28
# 484         SALN of Gerald Bantag as employee of BuCor  BUCOR 2022-10-28
# 485         SALN of Gerald Bantag as employee of BuCor  BUCOR 2022-10-28
# 486         SALN of Gerald Bantag as employee of BuCor    DOJ 2022-10-28
#
#          status                            purpose           period_covered  \
# 0        DENIED      School Paper Research(Thesis)  11/25/2016 - 11/25/2016
# 1        DENIED                       Transparency  12/31/2015 - 12/31/2015
# 2        DENIED                 Public Information  07/01/2013 - 12/31/2015
# 3    SUCCESSFUL  news reporting/public information  06/30/2016 - 12/23/2016
# 4    SUCCESSFUL                           Research  06/30/2016 - 06/30/2016
# ..          ...                                ...                      ...
# 482     PENDING                  Academic research  01/01/2019 - 10/28/2022
# 483  SUCCESSFUL                  Academic research  01/01/2019 - 10/28/2022
# 484      DENIED                  Academic research  01/01/2019 - 10/28/2022
# 485     PENDING                  Academic research  01/01/2019 - 10/28/2022
# 486     PENDING                  Academic research  01/01/2019 - 10/28/2022
#
#                                                   link       reason_denial
# 0                                                  NaN        wrong-agency
# 1                                                  NaN  incomplete-request
# 2                                                  NaN        wrong-agency
# 3                                                  NaN                   —
# 4                                                  NaN                   —
# ..                                                 ...                 ...
# 482  https://www.foi.gov.ph/requests/aglzfmVmb2ktcG...                 NaN
# 483  https://www.foi.gov.ph/requests/aglzfmVmb2ktcG...                 NaN
# 484  https://www.foi.gov.ph/requests/aglzfmVmb2ktcG...                 NaN
# 485  https://www.foi.gov.ph/requests/aglzfmVmb2ktcG...                 NaN
# 486  https://www.foi.gov.ph/requests/aglzfmVmb2ktcG...                 NaN
#
# [487 rows x 8 columns]

# %%
saln = saln.drop_duplicates()
saln
# Out:
#                                                  title agency       date  \
# 0                              SALN of Bongbong Marcos   DOTr 2016-11-25
# 1    SALN of the following: Ronnan Y. Pado, Ernani ...    DOF 2016-12-05
# 2    SALN of Niño Maximino A. Lazaro Municipal Coun...    DOF 2016-12-17
# 3    The SALNs of each of the cabinet members of th...   PCOO 2016-12-23
# 4    The SALNs of Presidents Aquino and Duterte's C...   PCOO 2017-01-18
# ..                                                 ...    ...        ...
# 468          SALN of Gerald Bantag as employee of BJMP   BJMP 2022-10-28
# 471         SALN of Gerald Bantag as employee of BuCor    DOJ 2022-10-28
# 472         SALN of Gerald Bantag as employee of BuCor  BUCOR 2022-10-28
# 473         SALN of Gerald Bantag as employee of BuCor  BUCOR 2022-10-28
# 474         SALN of Gerald Bantag as employee of BuCor    DOJ 2022-10-28
#
#          status                            purpose           period_covered  \
# 0        DENIED      School Paper Research(Thesis)  11/25/2016 - 11/25/2016
# 1        DENIED                       Transparency  12/31/2015 - 12/31/2015
# 2        DENIED                 Public Information  07/01/2013 - 12/31/2015
# 3    SUCCESSFUL  news reporting/public information  06/30/2016 - 12/23/2016
# 4    SUCCESSFUL                           Research  06/30/2016 - 06/30/2016
# ..          ...                                ...                      ...
# 468    ACCEPTED                  Academic Research  01/01/2014 - 10/28/2022
# 471  SUCCESSFUL                  Academic research  01/01/2019 - 10/28/2022
# 472      DENIED                  Academic research  01/01/2019 - 10/28/2022
# 473     PENDING                  Academic research  01/01/2019 - 10/28/2022
# 474     PENDING                  Academic research  01/01/2019 - 10/28/2022
#
#                                                   link       reason_denial
# 0                                                  NaN        wrong-agency
# 1                                                  NaN  incomplete-request
# 2                                                  NaN        wrong-agency
# 3                                                  NaN                   —
# 4                                                  NaN                   —
# ..                                                 ...                 ...
# 468  https://www.foi.gov.ph/requests/aglzfmVmb2ktcG...                 NaN
# 471  https://www.foi.gov.ph/requests/aglzfmVmb2ktcG...                 NaN
# 472  https://www.foi.gov.ph/requests/aglzfmVmb2ktcG...                 NaN
# 473  https://www.foi.gov.ph/requests/aglzfmVmb2ktcG...                 NaN
# 474  https://www.foi.gov.ph/requests/aglzfmVmb2ktcG...                 NaN
#
# [237 rows x 8 columns]

# %%
saln.to_csv('saln.csv')

# %%
df[df.agency=="OVP"].title.str.extractall(r'(.*\bSALN.+)', re.IGNORECASE).value_counts().sum()
#66 requests for the SALN of the Vice President.
# Out:
# 77

# %% [markdown]
# ## Drug war

# %%
drug_war = df.title.str.extractall(r'(.*\bdrug war.+)', re.IGNORECASE)

# %%
war_on_drugs = df.title.str.extractall(r'(.*\bwar on drugs.+)', re.IGNORECASE)

# %%
drugs = pd.concat([drug_war, war_on_drugs], ignore_index=True)
drugs
# Out:
#                                                     0
# 0                      Impact of Drug War on Children
# 1               DOJ drug war panel preliminary report
# 2                    Data breakdown of drug war cases
# 3                                    Drug war orphans
# 4                                    Drug war orphans
# 5                                    Drug war orphans
# 6                                    Drug war orphans
# 7                                    Drug war orphans
# 8   Statistics on war on drugs nationwide AND, spe...
# 9                          War On Drugs/Oplan Tokhang
# 10                   DSWD - War on Drugs Intervention
# 11  Status of War on Drugs Program Implementation ...
# 12  Statistics on war on drugs nationwide and, spe...

# %%
drugs.columns= ['title']

# %%
drugs = drugs.merge(df, on='title')
drugs.head(10)
# Out:
#                                    title agency_x     date_x  status_x  \
# 0         Impact of Drug War on Children     DSWD 2020-03-02    DENIED
# 1  DOJ drug war panel preliminary report      DOJ 2021-06-14    DENIED
# 2       Data breakdown of drug war cases      DOJ 2021-06-21  ACCEPTED
# 3                       Drug war orphans      PNP 2022-08-10  ACCEPTED
# 4                       Drug war orphans      PNP 2022-08-10  ACCEPTED
# 5                       Drug war orphans      PNP 2022-08-10  ACCEPTED
# 6                       Drug war orphans      PNP 2022-08-10  ACCEPTED
# 7                       Drug war orphans      PNP 2022-08-10  ACCEPTED
# 8                       Drug war orphans      PSA 2022-08-10   PENDING
# 9                       Drug war orphans      PSA 2022-08-10   PENDING
#
#                        purpose_x         period_covered_x  \
# 0              academic research  06/01/2016 - 03/02/2020
# 1               For media report  06/01/2020 - 02/01/2021
# 2  For media research and report  06/01/2016 - 05/31/2020
# 3           Undergraduate Thesis  06/01/2014 - 08/10/2022
# 4           Undergraduate Thesis  06/01/2014 - 08/10/2022
# 5           Undergraduate Thesis  06/01/2014 - 08/10/2022
# 6           Undergraduate Thesis  06/01/2014 - 08/10/2022
# 7           Undergraduate Thesis  06/01/2014 - 08/10/2022
# 8           Undergraduate Thesis  06/01/2014 - 08/10/2022
# 9           Undergraduate Thesis  06/01/2014 - 08/10/2022
#
#                                               link_x reason_denial_x agency_y  \
# 0                                                NaN               —     DSWD
# 1                                                NaN               —      DOJ
# 2                                                NaN               —      DOJ
# 3  https://www.foi.gov.ph/requests/aglzfmVmb2ktcG...             NaN      PNP
# 4  https://www.foi.gov.ph/requests/aglzfmVmb2ktcG...             NaN      PSA
# 5  https://www.foi.gov.ph/requests/aglzfmVmb2ktcG...             NaN      PNP
# 6  https://www.foi.gov.ph/requests/aglzfmVmb2ktcG...             NaN     DSWD
# 7  https://www.foi.gov.ph/requests/aglzfmVmb2ktcG...             NaN      PSA
# 8  https://www.foi.gov.ph/requests/aglzfmVmb2ktcG...             NaN      PNP
# 9  https://www.foi.gov.ph/requests/aglzfmVmb2ktcG...             NaN      PSA
#
#       date_y              status_y                      purpose_y  \
# 0 2020-03-02                DENIED              academic research
# 1 2021-06-14                DENIED               For media report
# 2 2021-06-21              ACCEPTED  For media research and report
# 3 2022-08-10              ACCEPTED           Undergraduate Thesis
# 4 2022-08-10               PENDING           Undergraduate Thesis
# 5 2022-08-10            SUCCESSFUL           Undergraduate Thesis
# 6 2022-08-10            PROCESSING           Undergraduate thesis
# 7 2022-08-10  PARTIALLY SUCCESSFUL           Undergraduate Thesis
# 8 2022-08-10              ACCEPTED           Undergraduate Thesis
# 9 2022-08-10               PENDING           Undergraduate Thesis
#
#           period_covered_y                                             link_y  \
# 0  06/01/2016 - 03/02/2020                                                NaN
# 1  06/01/2020 - 02/01/2021                                                NaN
# 2  06/01/2016 - 05/31/2020                                                NaN
# 3  06/01/2014 - 08/10/2022  https://www.foi.gov.ph/requests/aglzfmVmb2ktcG...
# 4  06/01/2014 - 08/10/2022  https://www.foi.gov.ph/requests/aglzfmVmb2ktcG...
# 5  06/01/2014 - 08/10/2022  https://www.foi.gov.ph/requests/aglzfmVmb2ktcG...
# 6  06/01/2014 - 08/10/2022  https://www.foi.gov.ph/requests/aglzfmVmb2ktcG...
# 7  06/01/2014 - 08/10/2022  https://www.foi.gov.ph/requests/aglzfmVmb2ktcG...
# 8  06/01/2014 - 08/10/2022  https://www.foi.gov.ph/requests/aglzfmVmb2ktcG...
# 9  06/01/2014 - 08/10/2022  https://www.foi.gov.ph/requests/aglzfmVmb2ktcG...
#
#   reason_denial_y           status_code
# 0               —                     0
# 1               —                     0
# 2               —              ACCEPTED
# 3             NaN              ACCEPTED
# 4             NaN               PENDING
# 5             NaN                     1
# 6             NaN            PROCESSING
# 7             NaN  PARTIALLY SUCCESSFUL
# 8             NaN              ACCEPTED
# 9             NaN               PENDING

# %% [markdown]
# ## Track request numbers through time
#
# ### By month

# %%
month_query = df.resample('M', on='date').title.count().to_frame().reset_index()
month_query.tail()
# Out:
#          date  title
# 68 2022-07-31   4723
# 69 2022-08-31   6615
# 70 2022-09-30   6349
# 71 2022-10-31   7785
# 72 2022-11-30   1386

# %%
(
    ggplot(month_query, aes(x="date", y="title")) + 
    geom_col(color="blue", stat="identity") + 
    geom_smooth()+
    theme(figure_size=(15,7), axis_ticks_length=10) + 
    labs(title="FOI requests peak in 2021")
)
# Out:
# /opt/homebrew/lib/python3.10/site-packages/plotnine/stats/smoothers.py:309: PlotnineWarning: Confidence intervals are not yet implemented for lowess smoothings.
# <ggplot: (686301172)>

# %%
month_query = df.resample('M', on='date').title.count().sort_values(ascending=False)
month_query.head(10)
#Largest number of FOI requests recorded in February 2022.
# Out:
# date
# 2022-03-31    7837
# 2022-10-31    7785
# 2022-08-31    6615
# 2022-09-30    6349
# 2022-04-30    6326
# 2022-02-28    6218
# 2021-10-31    5481
# 2021-11-30    5349
# 2022-06-30    5050
# 2021-09-30    4917
# Name: title, dtype: int64

# %% [markdown]
# ### By year

# %%
year_query = df.resample('A', on='date').title.count().to_frame().reset_index()
year_query
# Out:
#         date  title
# 0 2016-12-31    311
# 1 2017-12-31   2413
# 2 2018-12-31   6484
# 3 2019-12-31  13489
# 4 2020-12-31  25588
# 5 2021-12-31  42478
# 6 2022-12-31  60983

# %%
(
    ggplot(year_query, aes(x="date", y="title")) + 
    geom_col(color="blue", stat='identity') + 
    theme(figure_size=(15,7), axis_ticks_length=10) + 
    labs(title="Rising FOI requests")
)
# Out:
# <ggplot: (686282990)>

# %% [markdown]
# ## Year-on-year change shows slowing down increase in FOI requests

# %%
df.resample('A', on='date').title.count().pct_change() * 100
#2016 started in September. 2022 as of few weeks of January.
# Out:
# date
# 2016-12-31           NaN
# 2017-12-31    675.884244
# 2018-12-31    168.711148
# 2019-12-31    108.035163
# 2020-12-31     89.695307
# 2021-12-31     66.007504
# 2022-12-31     43.563727
# Freq: A-DEC, Name: title, dtype: float64

# %% [markdown]
# ## Percentage of denied each month

# %%
denied = df[df.status=='DENIED'].resample('M', on='date').agency.count().to_frame().reset_index()
deny = denied.merge(month_query, how='inner', on='date') #merge denied df with year_query
deny.columns= ['date', 'denials', 'total_requests'] #rename columns

# %%
deny ['pct_denied'] = (deny.denials / deny.total_requests) * 100
deny.pct_denied.round(2)
deny
# Out:
#          date  denials  total_requests  pct_denied
# 0  2016-11-30       45             117   38.461538
# 1  2016-12-31       75             194   38.659794
# 2  2017-01-31       41              93   44.086022
# 3  2017-02-28       44             127   34.645669
# 4  2017-03-31      126             222   56.756757
# ..        ...      ...             ...         ...
# 68 2022-07-31      878            4723   18.589879
# 69 2022-08-31     1342            6615   20.287226
# 70 2022-09-30      934            6349   14.710978
# 71 2022-10-31      828            7785   10.635838
# 72 2022-11-30      213            1386   15.367965
#
# [73 rows x 4 columns]

# %%
(
    ggplot(deny, aes(x="date", y="pct_denied")) + 
    geom_col(color="red", stat='identity') + 
    theme(figure_size=(15,7), axis_ticks_length=10) + 
    labs(title="Denied")
)
# Out:
# <ggplot: (686444776)>

# %% [markdown]
# ## Percentage pending

# %%
pending = df[df.status=='PENDING'].resample('M', on='date').agency.count().to_frame().reset_index()
pending = denied.merge(month_query, how='inner', on='date') #merge denied df with year_query
pending.columns= ['date', 'pending_stat', 'total_requests'] #rename columns

# %%
pending ['pct_pending'] = (pending.pending_stat / pending.total_requests) * 100
pending.pct_pending.round(2)
pending
# Out:
#          date  pending_stat  total_requests  pct_pending
# 0  2016-11-30            45             117    38.461538
# 1  2016-12-31            75             194    38.659794
# 2  2017-01-31            41              93    44.086022
# 3  2017-02-28            44             127    34.645669
# 4  2017-03-31           126             222    56.756757
# ..        ...           ...             ...          ...
# 68 2022-07-31           878            4723    18.589879
# 69 2022-08-31          1342            6615    20.287226
# 70 2022-09-30           934            6349    14.710978
# 71 2022-10-31           828            7785    10.635838
# 72 2022-11-30           213            1386    15.367965
#
# [73 rows x 4 columns]

# %%
(
    ggplot(pending, aes(x="date", y="pct_pending")) + 
    geom_col(color="orange", stat='identity') + 
    theme(figure_size=(15,7), axis_ticks_length=10) + 
    labs(title="Pending")
)
# Out:
# <ggplot: (686563734)>

# %% [markdown]
# ## Percentage closed
#
# These are requests which were closed after 60 days of non-response from the requestor when the FOI officer asked for clarification of the request.

# %%
closed = df[df.status=='CLOSED'].resample('M', on='date').agency.count().to_frame().reset_index()
close = closed.merge(month_query, how='inner', on='date') #merge closed df with year_query
close.columns= ['date', 'closures', 'total_requests'] #rename columns

# %%
close.head()
# Out:
#         date  closures  total_requests
# 0 2016-11-30        13             117
# 1 2016-12-31        31             194
# 2 2017-01-31         7              93
# 3 2017-02-28        11             127
# 4 2017-03-31         7             222

# %%
close ['pct_closed'] = (close.closures / close.total_requests) * 100
close.head()
# Out:
#         date  closures  total_requests  pct_closed
# 0 2016-11-30        13             117   11.111111
# 1 2016-12-31        31             194   15.979381
# 2 2017-01-31         7              93    7.526882
# 3 2017-02-28        11             127    8.661417
# 4 2017-03-31         7             222    3.153153

# %%
(
    ggplot(close, aes(x="date", y="pct_closed")) + 
    geom_col(color="yellow", stat='identity') + 
    theme(figure_size=(15,7), axis_ticks_length=10) + 
    labs(title="Closed")
)
# Out:
# <ggplot: (705988428)>

# %% [markdown]
# ## Percentage approved

# %%
approved = df[df.status=='ACCEPTED'].resample('M', on='date').agency.count().to_frame().reset_index()
approve = approved.merge(month_query, how='inner', on='date') #merge approved df with year_query
approve.columns= ['date', 'approvals', 'total_requests'] #rename columns
approve
# Out:
#          date  approvals  total_requests
# 0  2016-11-30         13             117
# 1  2016-12-31          3             194
# 2  2017-01-31          1              93
# 3  2017-02-28          4             127
# 4  2017-03-31          9             222
# ..        ...        ...             ...
# 68 2022-07-31        404            4723
# 69 2022-08-31        696            6615
# 70 2022-09-30        933            6349
# 71 2022-10-31       1127            7785
# 72 2022-11-30        199            1386
#
# [73 rows x 3 columns]

# %%
approve ['pct_approve'] = (approve.approvals / approve.total_requests) * 100
approve
# Out:
#          date  approvals  total_requests  pct_approve
# 0  2016-11-30         13             117    11.111111
# 1  2016-12-31          3             194     1.546392
# 2  2017-01-31          1              93     1.075269
# 3  2017-02-28          4             127     3.149606
# 4  2017-03-31          9             222     4.054054
# ..        ...        ...             ...          ...
# 68 2022-07-31        404            4723     8.553885
# 69 2022-08-31        696            6615    10.521542
# 70 2022-09-30        933            6349    14.695228
# 71 2022-10-31       1127            7785    14.476557
# 72 2022-11-30        199            1386    14.357864
#
# [73 rows x 4 columns]

# %%
(
    ggplot(approve, aes(x="date", y="pct_approve")) + 
    geom_col(color="blue", stat='identity') + 
    geom_smooth()+
    theme(figure_size=(15,7), axis_ticks_length=10) + 
    labs(title="Approved")
)
# Out:
# /opt/homebrew/lib/python3.10/site-packages/plotnine/stats/smoothers.py:309: PlotnineWarning: Confidence intervals are not yet implemented for lowess smoothings.
# <ggplot: (705955795)>

# %%
df[df.status=="DENIED"].resample('D', on='date').agency.count().mean()
# Out:
# 15.573861021629083

# %% [markdown]
# ## Regression
#
# Our questions are:
#
# - What are the odds that your FOI request will be denied if your purpose is for media use?
# - Which agency is more likely to deny an FOI request?

# %%
df.status.value_counts()
# Out:
# SUCCESSFUL                54375
# DENIED                    33842
# PENDING                   26497
# ACCEPTED                  11229
# PARTIALLY SUCCESSFUL       9898
# AWAITING CLARIFICATION     5604
# REFERRED                   3913
# CLOSED                     3464
# PROCESSING                 2852
# EXTENDED                     75
# Name: status, dtype: int64

# %%
df['status_code'] = df.status.replace({'SUCCESSFUL' or 'PARTIALLY SUCCESSFUL': 1, 'DENIED': 0})

# %%
df
# Out:
#         agency       date                                              title  \
# 0         DICT 2016-11-25  Projects to be implemented by the DICT for the...
# 1          NAP 2016-11-25  Juan Arellano Drawings and Plans of Plaza Impr...
# 2          PNP 2016-11-25  Number of robbery, rape and riding in tandem c...
# 3          PSA 2016-11-25         Ethnographic Population in the Philippines
# 4         PCOO 2016-11-25                                           Agencies
# ...        ...        ...                                                ...
# 151744     PNP 2022-11-07                                    CICL CALABARZON
# 151745     PNP 2022-11-07                                      CICL REGION 3
# 151746  NAMRIA 2022-11-07  Climate Disaster Risk Assessment of San Juan B...
# 151747     NBI 2022-11-07                                        ONLINE SCAM
# 151748    DOLE 2022-11-07                                             Thesis
#
#             status                                            purpose  \
# 0         ACCEPTED                                           Research
# 1       SUCCESSFUL  Research work on urban and public history duri...
# 2           CLOSED                                           Research
# 3       SUCCESSFUL                                           Research
# 4           DENIED                 Research and basis of authenticity
# ...            ...                                                ...
# 151744     PENDING                               Architectural Thesis
# 151745     PENDING                               Architectural Thesis
# 151746     PENDING                               Architectural Thesis
# 151747     PENDING                                           Personal
# 151748     PENDING                                           Research
#
#                  period_covered  \
# 0       11/25/2016 - 11/25/2016
# 1       01/01/1930 - 12/31/1950
# 2       06/01/2006 - 11/01/2016
# 3       11/25/2000 - 11/25/2016
# 4       07/01/2016 - 11/25/2016
# ...                         ...
# 151744  11/07/2022 - 11/07/2022
# 151745  11/07/2022 - 11/07/2022
# 151746  11/07/2022 - 11/07/2022
# 151747  11/06/2022 - 11/07/2022
# 151748  10/28/2021 - 10/28/2021
#
#                                                      link reason_denial  \
# 0                                                     NaN             —
# 1                                                     NaN             —
# 2                                                     NaN             —
# 3                                                     NaN             —
# 4                                                     NaN             —
# ...                                                   ...           ...
# 151744  https://www.foi.gov.ph/requests/aglzfmVmb2ktcG...           NaN
# 151745  https://www.foi.gov.ph/requests/aglzfmVmb2ktcG...           NaN
# 151746  https://www.foi.gov.ph/requests/aglzfmVmb2ktcG...           NaN
# 151747  https://www.foi.gov.ph/requests/aglzfmVmb2ktcG...           NaN
# 151748  https://www.foi.gov.ph/requests/aglzfmVmb2ktcG...           NaN
#
#        status_code
# 0         ACCEPTED
# 1                1
# 2           CLOSED
# 3                1
# 4                0
# ...            ...
# 151744     PENDING
# 151745     PENDING
# 151746     PENDING
# 151747     PENDING
# 151748     PENDING
#
# [151749 rows x 9 columns]
