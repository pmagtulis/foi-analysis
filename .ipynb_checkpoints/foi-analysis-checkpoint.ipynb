# %% [markdown]
# # FOI requests data analysis
#
# As of March 10, 2023, PST
#
# In this notebook, we use the CSV file generated by the auto-scraper to make our analysis of FOI requests.
#
# Remember that the **foi-ph-scraper** ideally scrapes new information from the website every Sunday of the week. The file generated is in a separate repository, which I will just read in here.
#
# **Note**: There were some weeks in 2022 when the scraper failed to run because the website was down. I'm still in the process of looking into entries that were missed. So far, the scraper runs every three days and fetches 3,000 entries every time. This ensures that new entries (and some old ones are collected). We drop the duplicates in the cleaning process.

# %%
import pandas as pd
import re
import requests
from plotnine import *
pd.set_option("display.max_columns", None)

# %% [markdown]
# ## Read df and clean it
#
# Read through the CSV, remove unnecessary columns, look for NaN values and duplicates, convert to datetime before you go through the data.

# %%
df = pd.read_csv('foi_final.csv')
df.tail(10)
# Out:
# /var/folders/00/cqb74mkn60g_hf2zk42fy8_m0000gp/T/ipykernel_12651/1295593880.py:1: DtypeWarning: Columns (7,8) have mixed types. Specify dtype option on import or set low_memory=False.
#         Unnamed: 0 agency        date  \
# 177500      177500    PSA  2023-03-10
# 177501      177501    NAP  2023-03-10
# 177502      177502   DPWH  2023-03-10
# 177503      177503    PNR  2023-03-10
# 177504      177504   CAAP  2023-03-10
# 177505      177505    PSA  2023-03-10
# 177506      177506   MMDA  2023-03-10
# 177507      177507    PSA  2023-03-10
# 177508      177508    NTC  2023-03-10
# 177509      177509    NTC  2023-03-10
#
#                                                     title  \
# 177500                   Recent Data of PH Elections 2022
# 177501                              Deed of absolute Sale
# 177502         Traffic Counts (AADT) in Northern Mindanao
# 177503  Train Station Design Standards for Commuter Rails
# 177504  Bukidnon Domestic Airport Type and Projected P...
# 177505  Number of employed veterinarians under governm...
# 177506                 Contingency Plan of Las Pinas City
# 177507  Floor Plan of Las Pinas Disaster Risk Reductio...
# 177508                     block my phone 358680937886817
# 177509                                     block my phone
#
#                       status                             purpose  \
# 177500               PENDING                            Research
# 177501                DENIED   Tracing of land title attachments
# 177502               PENDING                Architectural Thesia
# 177503               PENDING                Architectural Thesis
# 177504               PENDING                Architectural Thesis
# 177505               PENDING  Academic Research (thesis writing)
# 177506               PENDING                            Research
# 177507               PENDING                            Research
# 177508  PARTIALLY SUCCESSFUL                      block my phone
# 177509  PARTIALLY SUCCESSFUL               please block my phone
#
#                  period_covered  \
# 177500  03/10/2023 - 03/10/2023
# 177501  02/01/1968 - 12/31/1968
# 177502  03/10/2023 - 03/10/2023
# 177503  03/10/2023 - 03/10/2023
# 177504  03/10/2023 - 03/10/2023
# 177505  01/01/2022 - 01/01/2023
# 177506  01/01/2016 - 11/21/2022
# 177507  01/01/2016 - 11/21/2022
# 177508  11/05/2022 - 01/01/2023
# 177509  11/05/2022 - 01/01/2023
#
#                                                      link reason_denial
# 177500  https://www.foi.gov.ph/requests/aglzfmVmb2ktcG...           NaN
# 177501  https://www.foi.gov.ph/requests/aglzfmVmb2ktcG...           NaN
# 177502  https://www.foi.gov.ph/requests/aglzfmVmb2ktcG...           NaN
# 177503  https://www.foi.gov.ph/requests/aglzfmVmb2ktcG...           NaN
# 177504  https://www.foi.gov.ph/requests/aglzfmVmb2ktcG...           NaN
# 177505  https://www.foi.gov.ph/requests/aglzfmVmb2ktcG...           NaN
# 177506  https://www.foi.gov.ph/requests/aglzfmVmb2ktcG...           NaN
# 177507  https://www.foi.gov.ph/requests/aglzfmVmb2ktcG...           NaN
# 177508  https://www.foi.gov.ph/requests/aglzfmVmb2ktcG...           NaN
# 177509  https://www.foi.gov.ph/requests/aglzfmVmb2ktcG...           NaN

# %% [markdown]
# ## Drop 'Unnamed' column

# %%
df=df.drop('Unnamed: 0', axis=1)
df
# Out:
#        agency        date                                              title  \
# 0         DBM  2016-11-25  Cebu City Goverment Projects and Speding for 2016
# 1         DBM  2016-11-25  The Budget for local government buildings proj...
# 2         DOH  2016-11-25  Incidence of diarrhea, constipation, and respi...
# 3         PNP  2016-11-25       Crime Statatistics and Programs to Combat it
# 4        PCGG  2016-11-25  HIRING GOVERNMENT CAREER EMPLOYEES (RANK AND F...
# ...       ...         ...                                                ...
# 177505    PSA  2023-03-10  Number of employed veterinarians under governm...
# 177506   MMDA  2023-03-10                 Contingency Plan of Las Pinas City
# 177507    PSA  2023-03-10  Floor Plan of Las Pinas Disaster Risk Reductio...
# 177508    NTC  2023-03-10                     block my phone 358680937886817
# 177509    NTC  2023-03-10                                     block my phone
#
#                       status  \
# 0                   ACCEPTED
# 1                   ACCEPTED
# 2       PARTIALLY SUCCESSFUL
# 3                     CLOSED
# 4                     DENIED
# ...                      ...
# 177505               PENDING
# 177506               PENDING
# 177507               PENDING
# 177508  PARTIALLY SUCCESSFUL
# 177509  PARTIALLY SUCCESSFUL
#
#                                                   purpose  \
# 0       Research for Cebu City Development to be used ...
# 1       Architectural Thesis entitled Cagayan de Oro C...
# 2                                                Research
# 3                                            School Paper
# 4                                      PUBLIC INFORMATION
# ...                                                   ...
# 177505                 Academic Research (thesis writing)
# 177506                                           Research
# 177507                                           Research
# 177508                                     block my phone
# 177509                              please block my phone
#
#                  period_covered  \
# 0       01/01/2016 - 11/25/2016
# 1       11/25/2015 - 11/25/2016
# 2       11/25/2010 - 11/25/2016
# 3       01/01/2000 - 11/25/2016
# 4       11/25/2016 - 11/25/2016
# ...                         ...
# 177505  01/01/2022 - 01/01/2023
# 177506  01/01/2016 - 11/21/2022
# 177507  01/01/2016 - 11/21/2022
# 177508  11/05/2022 - 01/01/2023
# 177509  11/05/2022 - 01/01/2023
#
#                                                      link reason_denial
# 0                                                     NaN             —
# 1                                                     NaN             —
# 2                                                     NaN             —
# 3                                                     NaN             —
# 4                                                     NaN             —
# ...                                                   ...           ...
# 177505  https://www.foi.gov.ph/requests/aglzfmVmb2ktcG...           NaN
# 177506  https://www.foi.gov.ph/requests/aglzfmVmb2ktcG...           NaN
# 177507  https://www.foi.gov.ph/requests/aglzfmVmb2ktcG...           NaN
# 177508  https://www.foi.gov.ph/requests/aglzfmVmb2ktcG...           NaN
# 177509  https://www.foi.gov.ph/requests/aglzfmVmb2ktcG...           NaN
#
# [177510 rows x 8 columns]

# %% [markdown]
# ## Convert to datetime

# %%
df.dtypes
# Out:
# agency            object
# date              object
# title             object
# status            object
# purpose           object
# period_covered    object
# link              object
# reason_denial     object
# dtype: object

# %%
df.date = pd.to_datetime(df.date)

# %%
df.dtypes
# Out:
# agency                    object
# date              datetime64[ns]
# title                     object
# status                    object
# purpose                   object
# period_covered            object
# link                      object
# reason_denial             object
# dtype: object

# %% [markdown]
# ## Check for duplicates
#
# There are some duplicates found, but let's check. Remember, we only drop the duplicates if they are the same across **all columns**. Otherwise, we keep them, especially if the same requests are filed with different agencies.

# %%
df.duplicated().sum() #duplicates across all rows
# Out:
# 0

# %%
df.duplicated(subset=['title', 'agency', 'purpose']).value_counts()
# Out:
# False    151097
# True      26413
# dtype: int64

# %%
duplicated = df[df.duplicated(subset=['title', 'agency', 'purpose'], keep='first')]
duplicated
# Out:
#           agency       date  \
# 183          DOH 2016-12-09
# 197          DOH 2016-12-09
# 198          PSA 2016-12-09
# 204          DOH 2016-12-09
# 214          DOH 2016-12-09
# ...          ...        ...
# 177454      FNRI 2023-03-09
# 177486      BSWM 2023-03-09
# 177487  DENR EMB 2023-03-09
# 177489       DOH 2023-03-09
# 177497       PNP 2023-03-09
#
#                                                     title   status  \
# 183                           Global Youth Tobacco Survey   CLOSED
# 197     National, regional, and provincial data on the...   CLOSED
# 198     National, regional, and provincial data on the...   DENIED
# 204     National, regional, and provincial data on the...   CLOSED
# 214     National, regional, and provincial data on the...   CLOSED
# ...                                                   ...      ...
# 177454                    Zamboanga City Nutrition Status  PENDING
# 177486                       Soil Standard and Parameters  PENDING
# 177487     Healthcare Waste Generation Rate in Pasay City  PENDING
# 177489          List of DOH Accredited Siphoning Services  PENDING
# 177497  suspect margareth rillo convicted criminal per...   DENIED
#
#                                                   purpose  \
# 183                                              Research
# 197                                              Research
# 198                                              Research
# 204                                              Research
# 214                                              Research
# ...                                                   ...
# 177454                                             Thesis
# 177486                                           Research
# 177487                                             Thesis
# 177489                           Research and Development
# 177497  Police Blotter Report for suspect margareth ri...
#
#                    period_covered  \
# 183       01/02/2007 - 12/30/2007
# 197       01/02/2005 - 12/31/2015
# 198     01/02/2005 - Invalid date
# 204       01/02/2005 - 01/02/2015
# 214       01/01/2005 - 12/31/2015
# ...                           ...
# 177454    03/07/2023 - 03/07/2023
# 177486    03/05/2023 - 03/06/2023
# 177487    01/01/2018 - 03/09/2023
# 177489    03/08/2020 - 03/08/2023
# 177497    01/01/2018 - 03/09/2023
#
#                                                      link reason_denial
# 183                                                   NaN             —
# 197                                                   NaN             —
# 198                                                   NaN  wrong-agency
# 204                                                   NaN             —
# 214                                                   NaN             —
# ...                                                   ...           ...
# 177454  https://www.foi.gov.ph/requests/aglzfmVmb2ktcG...           NaN
# 177486  https://www.foi.gov.ph/requests/aglzfmVmb2ktcG...           NaN
# 177487  https://www.foi.gov.ph/requests/aglzfmVmb2ktcG...           NaN
# 177489  https://www.foi.gov.ph/requests/aglzfmVmb2ktcG...           NaN
# 177497  https://www.foi.gov.ph/requests/aglzfmVmb2ktcG...           NaN
#
# [26413 rows x 8 columns]

# %%
# duplicated.to_csv('duplicates.csv', index=False)

# %% [markdown]
# ## Looking into the NaNs
#
# We look for null values and whether they account for significant number of the data.

# %%
df.isna().sum()
# Out:
# agency                3
# date                  0
# title                 3
# status                0
# purpose               6
# period_covered        0
# link              90765
# reason_denial     86745
# dtype: int64

# %% [markdown]
# Interpretation: The **link** column have nearly 91,000 null values. This is because a large part of the data in our df came from an existing CSV maintained by the government. The same goes for **reason_denial.**
#
# You can find the CSV here: https://docs.google.com/spreadsheets/d/1kblO1_-gL65qXu_EJJBvc59UUHBQ7K3c/edit?fbclid=IwAR332h3xXbevTcnDiKQwKWldsod3kPP3J0T9_5NSXALgFI7XZPyIxMuqXg0#gid=875187444
#
# The data is updated quarterly. We merged this data early on with the scraped data from the website.

# %% [markdown]
# ## Analysis
#
# Now that we have all the requests contained in one file, we can now analyze them, still using pandas.

# %% [markdown]
# ## How much of the requests are granted or denied?

# %%
df.status.value_counts(normalize=True) *100
# Out:
# SUCCESSFUL                33.048842
# DENIED                    20.977410
# PENDING                   19.979156
# ACCEPTED                   8.227142
# PARTIALLY SUCCESSFUL       6.613712
# AWAITING CLARIFICATION     3.980057
# REFERRED                   2.912512
# PROCESSING                 2.246071
# CLOSED                     1.951439
# EXTENDED                   0.063658
# Name: status, dtype: float64

# %%
(
    ggplot(df) + 
    geom_bar(aes(x="status")) + 
    theme(figure_size=(15,7), axis_ticks_length=10) + 
    labs(title="Over 1 in 4 FOI requests denied")
)
# Out:
# <ggplot: (399993829)>

# %% [markdown]
# Note: We are still seeking clarification from PCOO on what **CLOSED** means. Meanwhile, over one in four FOI requests are denied by agencies. Over half are **successful** or **partially sucessful**.

# %% [markdown]
# ## Which agencies get the most FOI requests?

# %%
df.agency.value_counts().head(10)
# Out:
# DOH      17905
# PSA      10488
# DepEd     7232
# BIR       7204
# DOLE      6801
# NTC       5981
# DSWD      5757
# SSS       5625
# NBI       4764
# DPWH      4495
# Name: agency, dtype: int64

# %% [markdown]
# The Department of Health, Philippine Statistics Authority and the labor department get the most requests.

# %% [markdown]
# ## Which agencies deny the most requests?
#
# The Bureau of Internal Revenue tops the list, although a deeper probe would show most of the denials were a result of requests for personal tax records, which are not for public consumption.

# %%
df[df.status=="DENIED"].agency.value_counts().head(10)
# Out:
# BIR     3693
# DSWD    3189
# NBI     2240
# DENR    1524
# DOH     1320
# DTI     1302
# DOTr     940
# DOLE     906
# PNP      877
# HDMF     845
# Name: agency, dtype: int64

# %% [markdown]
# # Drilling down on specific agencies and requests
#
# We select a few agencies and search in their request files some of the most common requests by **title** as well as some of the most denials.

# %% [markdown]
# ## DOH: Vaccination certificates

# %%
df[df.agency=="DOH"].title.value_counts().head(20)
# Out:
# Vaccination Certificate           479
# Vaxcert                           330
# VaxCert                           152
# Vaccination Card                  151
# Vaccine Certificate               141
# Lost Vaccination Card             136
# Vaccination certificate           122
# Lost Vaccine Card                 113
# VAXCERT                            89
# Vax Cert                           77
# Vax Certificate                    73
# Vaccination card                   69
# Vaccine certificate                65
# VACCINATION CERTIFICATE            63
# VaxCertPH                          53
# vaxcert                            50
# Vaxcert; incorrect middle name     49
# Vaccine Card                       48
# Vaxcertificate                     40
# Vaccine card                       38
# Name: title, dtype: int64

# %%
vax = ["Vaccination Certificate", "Vaxcert", "VaxCert", "Vaccination certificate", "Vax Cert", "VAXCERT", "VAX CERT", "Vax Certificate", "Vax certificate", "VACCINATION CERTIFICATE", "Vax cert", "VaxCertPH", "Vax Cert PH", "vax cert", "Vax cert request", "Vax Cert Request", "Vaccination Card", "Vax card", "vaccination card", "Vaccine certificate", "vaccine certificate"]
df_vax = df[df['title'].isin(vax)].reset_index(drop=True)
df_vax.count()
# Out:
# agency            1930
# date              1930
# title             1930
# status            1930
# purpose           1930
# period_covered    1930
# link              1494
# reason_denial      436
# dtype: int64

# %% [markdown]
# Interpretation: Over one in 10 DOH requests from 2016 were to request for vaccination certificates.

# %% [markdown]
# ## DSWD: Social amelioration program
#
# This is the P275-billion pandemic relief program by the government in 2020 that gave dole outs to poor families. The program were given in two tranches and were marred by significant delays and other irregularities.

# %%
sap = ["SAP", "SAP 2nd tranche", "Sap 2nd tranche", "Social Amelioration Program", "Social amelioration program", "sap 2nd tranche", "SAP 2nd tranche", "2nd tranche", "DSWD SAP", "SAP 2ND TRANCHE", "Sap 2nd Tranche", "SAP 1st tranche", "SAP first tranche", "SAP 1ST TRANCHE", "Sap"]
df_sap = df[df['title'].isin(sap)].reset_index(drop=True)
df_sap[df_sap.status=="DENIED"].head(10)
# Out:
#   agency       date                        title  status  \
# 0   DSWD 2020-04-09  Social amelioration program  DENIED
# 1   DSWD 2020-04-21                          Sap  DENIED
# 2   DSWD 2020-04-21  Social Amelioration Program  DENIED
# 3   DSWD 2020-04-23  Social Amelioration Program  DENIED
# 4   DSWD 2020-04-25  Social Amelioration Program  DENIED
# 5   DSWD 2020-04-27  Social Amelioration Program  DENIED
# 6   DSWD 2020-04-27                     DSWD SAP  DENIED
# 7   DSWD 2020-05-01                          SAP  DENIED
# 8   DSWD 2020-05-01  Social Amelioration Program  DENIED
# 9   DSWD 2020-05-03                          Sap  DENIED
#
#                                              purpose           period_covered  \
# 0                          Personal information only  04/09/2020 - 04/09/2020
# 1                                        Solo parent  04/08/2020 - 04/21/2020
# 2             Transparency purposes to my kabarangay  04/01/2020 - 04/21/2020
# 3                        Validation and Confirmation  04/23/2020 - 04/23/2020
# 4  To known the list of beneficiaries of Social A...  03/01/2020 - 04/25/2020
# 5                                       Transparency  04/19/2020 - 04/27/2020
# 6    To know the status of DSWD SAP in our Barangay.  04/27/2020 - 04/27/2020
# 7                                    SAP APPLICATION  05/01/2020 - 05/01/2020
# 8                        Social Amelioration Program  03/16/2020 - 04/30/2020
# 9          Applying for special amelioration program  03/21/2020 - 04/21/2020
#
#   link       reason_denial
# 0  NaN                   —
# 1  NaN                   —
# 2  NaN                   —
# 3  NaN                   —
# 4  NaN                   —
# 5  NaN                   —
# 6  NaN                   —
# 7  NaN                   —
# 8  NaN  incomplete-request
# 9  NaN                   —

# %% [markdown]
# Interpretation: Most requests for SAP were denied and were deemed an "invalid request."

# %%
df_sap.count()
#180 requests about SAP.
# Out:
# agency            182
# date              182
# title             182
# status            182
# purpose           182
# period_covered    182
# link                7
# reason_denial     175
# dtype: int64

# %% [markdown]
# ## OVP: Any type of "assistance"
#
# The office of former Vice President Leni Robredo is known for its **Angat Buhay** program that helps the poor.

# %%
df[df.agency=="OVP"].title.str.contains("assistance", regex=False, case=False).value_counts()
# Out:
# False    628
# True     465
# Name: title, dtype: int64

# %% [markdown]
# Interpretation: 40% of OVP FOI requests mention some form of "assistance".

# %% [markdown]
# ## BIR: Tax identification number or TIN
#
# Tax matters are generally protected by privacy laws in the Philippines. But that did not stop some people to request for them through FOI.

# %%
#df_final[df_final.title=="Income Tax Return"]
tax = ['Income Tax Return', 'ITR','BIR 2316', 'TIN Verification', 'TIN VERIFICATION', 'BIR Form 2316', 'Income tax return', 'TIN', 'INCOME TAX RETURN', 'Form 2316', 'TIN NUMBER', 'tin number', 'TIN verification', 'tax', 'tax records']
df_tax = df[df['title'].isin(tax)].reset_index(drop=True)
df_tax.tail(10)
# Out:
#      agency       date              title                status  \
# 1805    BIR 2023-03-04           BIR 2316               PENDING
# 1806    BIR 2023-03-04           BIR 2316  PARTIALLY SUCCESSFUL
# 1807    BIR 2023-03-04  Income Tax Return  PARTIALLY SUCCESSFUL
# 1808    BIR 2023-03-04           BIR 2316                DENIED
# 1809    BIR 2023-03-05  Income Tax Return                DENIED
# 1810    BIR 2023-03-05  Income Tax Return                DENIED
# 1811    BIR 2023-03-06  Income Tax Return               PENDING
# 1812    BIR 2023-03-06                TIN                DENIED
# 1813    BIR 2023-03-06  Income Tax Return                DENIED
# 1814    BIR 2023-03-06                TIN               PENDING
#
#                                                 purpose  \
# 1805                                           For Loan
# 1806                                           For Loan
# 1807                                       Loan Purpose
# 1808                              Proof of tax payments
# 1809                            Scholarship Requirement
# 1810                Requirement on Car Loan Application
# 1811                            Credit Card Application
# 1812  to know that they really the person in of the ...
# 1813                            Credit Card Application
# 1814  to know that they really the person in of the ...
#
#                period_covered  \
# 1805  01/01/2022 - 02/28/2023
# 1806  01/01/2022 - 02/28/2023
# 1807  01/01/2022 - 01/01/2023
# 1808  01/01/2010 - 12/31/2017
# 1809  03/05/2022 - 03/05/2023
# 1810  03/01/2022 - 03/01/2023
# 1811  09/15/2022 - 02/28/2023
# 1812  03/06/2023 - 03/06/2023
# 1813  09/15/2022 - 02/28/2023
# 1814  03/06/2023 - 03/06/2023
#
#                                                    link reason_denial
# 1805  https://www.foi.gov.ph/requests/aglzfmVmb2ktcG...           NaN
# 1806  https://www.foi.gov.ph/requests/aglzfmVmb2ktcG...           NaN
# 1807  https://www.foi.gov.ph/requests/aglzfmVmb2ktcG...           NaN
# 1808  https://www.foi.gov.ph/requests/aglzfmVmb2ktcG...           NaN
# 1809  https://www.foi.gov.ph/requests/aglzfmVmb2ktcG...           NaN
# 1810  https://www.foi.gov.ph/requests/aglzfmVmb2ktcG...           NaN
# 1811  https://www.foi.gov.ph/requests/aglzfmVmb2ktcG...           NaN
# 1812  https://www.foi.gov.ph/requests/aglzfmVmb2ktcG...           NaN
# 1813  https://www.foi.gov.ph/requests/aglzfmVmb2ktcG...           NaN
# 1814  https://www.foi.gov.ph/requests/aglzfmVmb2ktcG...           NaN

# %%
df_tax.status.value_counts()
# Out:
# DENIED                    790
# AWAITING CLARIFICATION    597
# PENDING                   147
# SUCCESSFUL                136
# ACCEPTED                   61
# PARTIALLY SUCCESSFUL       54
# REFERRED                   15
# CLOSED                      8
# PROCESSING                  6
# EXTENDED                    1
# Name: status, dtype: int64

# %%
df_tax.status.value_counts(normalize=True) *100
# Out:
# DENIED                    43.526171
# AWAITING CLARIFICATION    32.892562
# PENDING                    8.099174
# SUCCESSFUL                 7.493113
# ACCEPTED                   3.360882
# PARTIALLY SUCCESSFUL       2.975207
# REFERRED                   0.826446
# CLOSED                     0.440771
# PROCESSING                 0.330579
# EXTENDED                   0.055096
# Name: status, dtype: float64

# %% [markdown]
# # Top purpose of requests

# %%
df.purpose.value_counts(ascending=False).head(10)
# Out:
# Research                    14025
# Research and Development     7204
# Thesis                       3400
# Undergraduate Thesis         3319
# Architectural Thesis         3295
# Research and development     2832
# Academic Research            1212
# Thesis Research              1070
# research                      817
# Undergraduate Research        723
# Name: purpose, dtype: int64

# %% [markdown]
# ## For academic purposes

# %%
research = df.purpose.str.extractall(r'(.*\bresearch.+)', re.IGNORECASE)
research
# Out:
#                                                               0
#        match
# 0      0      Research for Cebu City Development to be used ...
# 6      0                               Research and Development
# 8      0                               Research and development
# 15     0      Research for alternative solution in EDSA Traf...
# 27     0                          School Paper Research(Thesis)
# ...                                                         ...
# 177488 0                                  FOR RESEARCH PURPOSES
# 177489 0                               Research and Development
# 177496 0                               Research and development
# 177498 0      Research, development, and publication for PSA...
# 177505 0                     Academic Research (thesis writing)
#
# [32892 rows x 1 columns]

# %%
thesis = df.purpose.str.extractall(r'(.*\bthesis.+)', re.IGNORECASE)
thesis
# Out:
#                                                               0
#        match
# 0      0      Research for Cebu City Development to be used ...
# 1      0      Architectural Thesis entitled Cagayan de Oro C...
# 27     0                          School Paper Research(Thesis)
# 29     0                                        Thesis Research
# 97     0                       Research / Possible Thesis Study
# ...                                                         ...
# 177383 0                                        Thesis purposes
# 177417 0                          Research for Thesis Reference
# 177434 0      Undergraduate Thesis for Monitoring Ground Def...
# 177456 0                   For my Architectural Thesis Research
# 177505 0                     Academic Research (thesis writing)
#
# [10960 rows x 1 columns]

# %%
academic = df.purpose.str.extractall(r'(.*\bacademic.+)', re.IGNORECASE)
academic
# Out:
#                                                               0
#        match
# 91     0                                      Academic research
# 365    0                                      Academic research
# 385    0                                      Academic Research
# 458    0                                      Academic research
# 464    0                                      Academic Research
# ...                                                         ...
# 177168 0                                  For Academic Purposes
# 177227 0           Academic Purposes - Modelling and Simulation
# 177228 0           Academic Purposes - Modelling and Simulation
# 177412 0      Modelling and Simulation Research Paper - Acad...
# 177505 0                     Academic Research (thesis writing)
#
# [4998 rows x 1 columns]

# %%
research_2 = pd.concat([research, academic, thesis], ignore_index=True)
research_2.columns= ['purpose']
research_2
# Out:
#                                                  purpose
# 0      Research for Cebu City Development to be used ...
# 1                               Research and Development
# 2                               Research and development
# 3      Research for alternative solution in EDSA Traf...
# 4                          School Paper Research(Thesis)
# ...                                                  ...
# 48845                                    Thesis purposes
# 48846                      Research for Thesis Reference
# 48847  Undergraduate Thesis for Monitoring Ground Def...
# 48848               For my Architectural Thesis Research
# 48849                 Academic Research (thesis writing)
#
# [48850 rows x 1 columns]

# %%
# research_2 = research_2.merge(df, on='purpose')
# research_2.duplicated().value_counts()

# %%
#research_2[research_2.duplicated()]

# %% [markdown]
# ## For journalistic purposes

# %%
news = df.purpose.str.extractall(r'(.*\bnews.+)', re.IGNORECASE)
news
# Out:
#                                                               0
#        match
# 76     0                                           news article
# 77     0                                           news article
# 89     0                                            News report
# 184    0      This will be used for the verification of "new...
# 249    0                              Research and news article
# ...                                                         ...
# 176394 0                                            News report
# 176520 0                                            News report
# 176580 0                                            news report
# 176764 0      News Feature Writing for Development Journalis...
# 176818 0      News Feature Writing for Development Journalis...
#
# [372 rows x 1 columns]

# %%
media = df.purpose.str.extractall(r'(.*\bmedia.+)', re.IGNORECASE)

# %%
journalism = pd.concat([news, media], ignore_index=True)
journalism.columns= ['purpose']
journalism
# Out:
#                                                purpose
# 0                                         news article
# 1                                         news article
# 2                                          News report
# 3    This will be used for the verification of "new...
# 4                            Research and news article
# ..                                                 ...
# 622  Report the scam, Block the social media and Re...
# 623                                 Media and research
# 624                        Consumer and Media Research
# 625                        Consumer and Media Research
# 626                        Consumer and Media Research
#
# [627 rows x 1 columns]

# %%
journalism = journalism.merge(df, on='purpose')
journalism.duplicated().sum()
# Out:
# 2126

# %%
journalism = journalism.drop_duplicates().reset_index(drop=True)
journalism
# Out:
#                                                purpose agency       date  \
# 0                                         news article    PNP 2016-11-27
# 1                                         news article    PNP 2016-11-27
# 2                                          News report    DBM 2016-11-28
# 3                                          News report   PCOO 2017-01-27
# 4                                          News report   PDEA 2017-11-21
# ..                                                 ...    ...        ...
# 612  Report the scam, Block the social media and Re...  AMLCS 2023-01-31
# 613                                 Media and research    DND 2023-02-15
# 614                        Consumer and Media Research   DOTr 2023-02-16
# 615                        Consumer and Media Research   MMDA 2023-02-16
# 616                        Consumer and Media Research   DOTr 2023-02-16
#
#                                                  title  \
# 0                                        oplan tokhang
# 1    PNP Region 9 Director Billy Beltran and PNP Ge...
# 2    Cost of President Duterte's trip to Laos, Chin...
# 3    Cost of each of President Duterte's foreign tr...
# 4                            Statistics on drug prices
# ..                                                 ...
# 612             Cybersecurity Solutions Scam via Gcash
# 613  Appointment papers of Carlito Galvez Jr. Gener...
# 614                             MRT 3 (EDSA) Commuters
# 615                       Commuters Along EDSA and MRT
# 616                             MRT 3 (EDSA) Commuters
#
#                      status           period_covered  \
# 0                SUCCESSFUL  07/01/2016 - 11/02/2016
# 1                    DENIED  06/01/2016 - 07/02/2016
# 2                    DENIED  09/05/2016 - 11/23/2016
# 3                    DENIED  09/05/2016 - 12/17/2016
# 4                    DENIED  07/01/2016 - 11/21/2017
# ..                      ...                      ...
# 612                 PENDING  01/14/2023 - 01/17/2023
# 613                 PENDING  01/01/2023 - 01/31/2023
# 614  AWAITING CLARIFICATION  01/01/2022 - 12/31/2022
# 615    PARTIALLY SUCCESSFUL  01/01/2022 - 12/31/2022
# 616                 PENDING  01/01/2022 - 12/31/2022
#
#                                                   link       reason_denial
# 0                                                  NaN                   —
# 1                                                  NaN  incomplete-request
# 2                                                  NaN                   —
# 3                                                  NaN        wrong-agency
# 4                                                  NaN                   —
# ..                                                 ...                 ...
# 612  https://www.foi.gov.ph/requests/aglzfmVmb2ktcG...                 NaN
# 613  https://www.foi.gov.ph/requests/aglzfmVmb2ktcG...                 NaN
# 614  https://www.foi.gov.ph/requests/aglzfmVmb2ktcG...                 NaN
# 615  https://www.foi.gov.ph/requests/aglzfmVmb2ktcG...                 NaN
# 616  https://www.foi.gov.ph/requests/aglzfmVmb2ktcG...                 NaN
#
# [617 rows x 8 columns]

# %% [markdown]
# # Know each agencies' performance
#
# Just changed the name of the agency in brackets.

# %%
df[df.agency=="OP"]
#There were some requests for SALN.
# Out:
#        agency       date                                              title  \
# 2561       OP 2017-12-01  Total cost/expenses for the foreign trips of P...
# 2586       OP 2017-12-04  Cost of President Duterte's foreign trips in h...
# 2609       OP 2017-12-05  Updates on the appeals of suspended and closed...
# 2703       OP 2017-12-24                    2018 General Appropriations Act
# 2721       OP 2017-12-30                     Executive Order 126 dated 1959
# 3034       OP 2018-01-31     NSC Group Photos with Living Former Presidents
# 3166       OP 2018-02-11  What is the counterpart of the CIA in the Phil...
# 3170       OP 2018-02-11  Breakdown of War Materiel used by the AFP in t...
# 3182       OP 2018-02-11  Documentary proof or evidence of President Dut...
# 3207       OP 2018-02-13               Actual Expenses of ASEAN 2017 budget
# 3462       OP 2018-03-03  Impact of OFW remittances on the Philippine Ec...
# 3473       OP 2018-03-04                                 Appointment Papers
# 75535      OP 2021-09-29    Statement of Assets, Liabilities, and Net Worth
# 76965      OP 2021-10-07  Statement of Assets, Liabilities, and Net Wort...
# 77024      OP 2021-10-07  Statement of Assets, Liabilities, and Net Wort...
# 78800      OP 2021-10-18  Accomplishments and Negative Impact of late Fe...
# 83892      OP 2021-11-15  PRESIDENTIAL SINCE 1965 BUDGET FROM START OF T...
# 87258      OP 2021-12-03             National Budget from Marcos Presidency
# 87266      OP 2021-12-03  You money building you steal everything you fo...
# 96571      OP 2022-02-08          Government Directory from 1900 to present
# 106285     OP 2022-03-19                       SALN - Agnes Joyce G. Bailen
# 109535     OP 2022-04-01                                            IRR for
# 110067     OP 2022-04-04  List of places visited by President Rodrigo Ro...
# 116155     OP 2022-05-04  Budget ni President Marcos sa loob ng 20 years...
# 128927     OP 2022-07-27            IRR of Executive Order No. 249, s. 1987
# 134157     OP 2022-08-23                           Presidential Decree 1158
# 137730     OP 2022-09-07                                          EO No. 77
# 142172     OP 2022-09-29    Lot Technical Description - La Trinidad Benguet
# 142196     OP 2022-09-29  Request for list of Newly appointed Undersecre...
# 142824     OP 2022-10-03  Request for the Official Portraits of Presiden...
# 143038     OP 2022-10-03  Request for list of Newly appointed Undersecre...
# 146929     OP 2022-10-18  List of President Bong Bong Marcos' Travels fr...
# 150519     OP 2022-11-02  Data regarding Executive Order No. 6, series o...
# 150601     OP 2022-11-02  Number of Complaints received through the 8888...
# 157076     OP 2022-11-25  Executive Order of President Ferdinand Marcos Jr.
# 171888     OP 2023-02-15  List of Vacancies Office of the Philippine Pre...
# 173463     OP 2023-02-21                         Notice of Case Resolutions
# 174254     OP 2023-02-23  List of directory of financial and medical ass...
#
#          status                                            purpose  \
# 2561    PENDING  For research purposes for my year-end report f...
# 2586    PENDING                                      News research
# 2609    PENDING                                           Research
# 2703    PENDING  Factual basis in research and review of certai...
# 2721    PENDING                                            HISTORY
# 3034    PENDING                     Research and Archive purposes.
# 3166    PENDING                                           Research
# 3170    PENDING                Research for Graduate School class.
# 3182    PENDING                Research for Graduate School class.
# 3207    PENDING                                  Research purposes
# 3462    PENDING                                 Practical Research
# 3473    PENDING                       Personal Reference / Inquiry
# 75535   PENDING               Research and other academic purposes
# 76965   PENDING                     Academic and Research purposes
# 77024   PENDING                     Academic and Research Purposes
# 78800   PENDING                           Research and Development
# 83892   PENDING  I Want to do a small study for my own educatio...
# 87258   PENDING                              For Research Purposes
# 87266   PENDING  Pera lahat records justices Icc criminal court...
# 96571   PENDING                             Undergraduate Research
# 106285  PENDING  Research and development - voter education, kn...
# 109535  PENDING  To be used as part of document for the entitle...
# 110067  PENDING                           Research and Development
# 116155  PENDING                                           RESEARCH
# 128927  PENDING  Information request on behalf of library resea...
# 134157  PENDING                                           Research
# 137730  PENDING                         For clarify of information
# 142172  PENDING         Conduct of Academic Architectural Research
# 142196  PENDING                           Research and Development
# 142824  PENDING               Educational and Informative Purposes
# 143038  PENDING                           Research and Development
# 146929  PENDING                                For Academic Report
# 150519  PENDING                             For Research Purposes.
# 150601  PENDING     This is for research purposes, for our thesis.
# 157076  PENDING                 As a reference for Christmas Bonus
# 171888  PENDING                                         Job Search
# 173463  PENDING  For submission to AO 25 Secretariat regarding ...
# 174254  PENDING                                           Research
#
#                  period_covered  \
# 2561    01/01/2017 - 12/01/2017
# 2586    07/01/2016 - 07/01/2017
# 2609    02/02/2017 - 12/05/2017
# 2703    12/24/2017 - 12/24/2017
# 2721    12/30/2017 - 12/30/2017
# 3034    07/27/2016 - 07/27/2016
# 3166    02/11/2018 - 02/11/2018
# 3170    05/23/2017 - 11/23/2017
# 3182    03/28/1945 - 02/11/2018
# 3207    01/01/2017 - 01/01/2018
# 3462    02/25/2018 - 03/03/2018
# 3473    06/30/2016 - 03/04/2018
# 75535   01/01/2018 - 12/31/2020
# 76965   01/01/2018 - 10/01/2020
# 77024   01/01/2018 - 10/01/2020
# 78800   09/21/1972 - 09/21/1986
# 83892   12/30/1965 - 11/14/2021
# 87258   12/30/1965 - 12/02/2021
# 87266   12/01/2021 - 12/01/2021
# 96571   01/01/1900 - 01/01/2022
# 106285  01/01/2021 - 12/31/2021
# 109535  05/01/2021 - 10/30/2021
# 110067  06/01/2016 - 04/02/2022
# 116155  05/01/2022 - 05/04/2022
# 128927  01/01/1987 - 12/31/2021
# 134157  06/03/1977 - 01/01/1998
# 137730  09/06/2022 - 09/06/2022
# 142172  11/11/1914 - 09/28/2022
# 142196  07/01/2022 - 09/28/2022
# 142824  01/01/1899 - 10/02/2022
# 143038  06/01/2022 - 10/03/2022
# 146929  06/30/2022 - 10/08/2022
# 150519  08/30/2016 - 10/30/2016
# 150601  08/30/2016 - 10/30/2022
# 157076  11/24/2022 - 11/24/2022
# 171888  02/14/2023 - 02/14/2023
# 173463  01/01/2022 - 12/31/2022
# 174254  05/02/2022 - 02/21/2023
#
#                                                      link reason_denial
# 2561                                                  NaN             —
# 2586                                                  NaN             —
# 2609                                                  NaN             —
# 2703                                                  NaN             —
# 2721                                                  NaN             —
# 3034                                                  NaN             —
# 3166                                                  NaN             —
# 3170                                                  NaN             —
# 3182                                                  NaN             —
# 3207                                                  NaN             —
# 3462                                                  NaN             —
# 3473                                                  NaN             —
# 75535                                                 NaN             —
# 76965                                                 NaN             —
# 77024                                                 NaN             —
# 78800                                                 NaN             —
# 83892                                                 NaN             —
# 87258                                                 NaN             —
# 87266                                                 NaN             —
# 96571   https://www.foi.gov.ph/requests/aglzfmVmb2ktcG...           NaN
# 106285  https://www.foi.gov.ph/requests/aglzfmVmb2ktcG...           NaN
# 109535  https://www.foi.gov.ph/requests/aglzfmVmb2ktcG...           NaN
# 110067  https://www.foi.gov.ph/requests/aglzfmVmb2ktcG...           NaN
# 116155  https://www.foi.gov.ph/requests/aglzfmVmb2ktcG...           NaN
# 128927  https://www.foi.gov.ph/requests/aglzfmVmb2ktcG...           NaN
# 134157  https://www.foi.gov.ph/requests/aglzfmVmb2ktcG...           NaN
# 137730  https://www.foi.gov.ph/requests/aglzfmVmb2ktcG...           NaN
# 142172  https://www.foi.gov.ph/requests/aglzfmVmb2ktcG...           NaN
# 142196  https://www.foi.gov.ph/requests/aglzfmVmb2ktcG...           NaN
# 142824  https://www.foi.gov.ph/requests/aglzfmVmb2ktcG...           NaN
# 143038  https://www.foi.gov.ph/requests/aglzfmVmb2ktcG...           NaN
# 146929  https://www.foi.gov.ph/requests/aglzfmVmb2ktcG...           NaN
# 150519  https://www.foi.gov.ph/requests/aglzfmVmb2ktcG...           NaN
# 150601  https://www.foi.gov.ph/requests/aglzfmVmb2ktcG...           NaN
# 157076  https://www.foi.gov.ph/requests/aglzfmVmb2ktcG...           NaN
# 171888  https://www.foi.gov.ph/requests/aglzfmVmb2ktcG...           NaN
# 173463  https://www.foi.gov.ph/requests/aglzfmVmb2ktcG...           NaN
# 174254  https://www.foi.gov.ph/requests/aglzfmVmb2ktcG...           NaN

# %% [markdown]
# ## Government contracts

# %%
contract = ['contract', 'contracts', 'audit', 'audit report', 'Audit report', 'Audit Report', 'Contract', 'Contracts', 'loan agreement', 'Agreements', 'Agreement', 'agreement', 'agreements']
df_contract = df[df['title'].isin(contract)].reset_index(drop=True)
df_contract.head(7)
# Out:
#   agency       date         title    status  \
# 0   LRTA 2019-03-29      Contract    DENIED
# 1    DFA 2021-03-14  Audit Report    DENIED
# 2   PPPC 2022-06-19     Contracts  ACCEPTED
# 3    LRA 2022-06-19      Contract   PENDING
# 4    LTO 2022-06-19      Contract   PENDING
# 5   PPPC 2022-06-19     Contracts    DENIED
# 6   PPPC 2022-06-19     Contracts   PENDING
#
#                                purpose           period_covered  \
# 0  For own personal use or information  01/01/2018 - 12/31/2018
# 1                     Research Purpose  01/01/2018 - 07/30/2020
# 2             Research and Development  06/19/2020 - 06/19/2022
# 3                             Research  06/19/2020 - 06/19/2022
# 4                             Research  06/19/2020 - 06/19/2022
# 5             Research and Development  06/19/2020 - 06/19/2022
# 6             Research and Development  06/19/2020 - 06/19/2022
#
#                                                 link  \
# 0                                                NaN
# 1                                                NaN
# 2  https://www.foi.gov.ph/requests/aglzfmVmb2ktcG...
# 3  https://www.foi.gov.ph/requests/aglzfmVmb2ktcG...
# 4  https://www.foi.gov.ph/requests/aglzfmVmb2ktcG...
# 5  https://www.foi.gov.ph/requests/aglzfmVmb2ktcG...
# 6  https://www.foi.gov.ph/requests/aglzfmVmb2ktcG...
#
#                   reason_denial
# 0                             —
# 1  information-available-online
# 2                           NaN
# 3                           NaN
# 4                           NaN
# 5                           NaN
# 6                           NaN

# %% [markdown]
# ## Top reasons for denial
#
# Applicable only to data as of December 2021.

# %%
df.reason_denial.value_counts(dropna=False)
#"-" means it's not applicable since the request was not denied.
# Out:
# NaN                             86745
# —                               77314
# wrong-agency                     6980
# incomplete-request               2764
# invalid-request                  2084
# information-available-online     1620
# exceptions                          2
# privacy                             1
# Name: reason_denial, dtype: int64

# %%
df[df.reason_denial=='wrong-agency'].tail(10)
# Out:
#       agency       date                                              title  \
# 89758   CHED 2021-12-18                                 Request for laptop
# 89769   DOTr 2021-12-18        Car Makers' Market Share in the Philippines
# 89839    NTC 2021-12-19  Requesting for Individual/Company name uses th...
# 89843     PH 2021-12-19                            Vaccination Certificate
# 89856     PH 2021-12-19                             VaccinationCertificate
# 90021   DENR 2021-12-21  Certificate of ancestral domain title in Sioco...
# 90206   CHED 2021-12-23                              Registration Form 001
# 90443    NAP 2021-12-27                                       Birth Record
# 90537    DAR 2021-12-28         CLUP and Zoning Ordinance of Angono, Rizal
# 90751    DOJ 2021-12-31                                        INFORMATION
#
#        status                                            purpose  \
# 89758  DENIED            Educational and future career purposes.
# 89769  DENIED                                             thesis
# 89839  DENIED  All my contacts got an sms blast from this num...
# 89843  DENIED                                          To Travel
# 89856  DENIED                                          To travel
# 90021  DENIED  To verify that who is the head of CADT in Siti...
# 90206  DENIED                            Employment Requirements
# 90443  DENIED                                SSS Funeral Benefit
# 90537  DENIED                                           Research
# 90751  DENIED                         RESOLUTION AND INFORMATION
#
#                 period_covered link reason_denial
# 89758  11/26/2021 - 12/18/2021  NaN  wrong-agency
# 89769  01/01/2016 - 12/01/2021  NaN  wrong-agency
# 89839  12/19/2021 - 12/19/2021  NaN  wrong-agency
# 89843  06/14/2021 - 07/12/2021  NaN  wrong-agency
# 89856  06/14/2021 - 07/12/2021  NaN  wrong-agency
# 90021  12/21/2021 - 12/21/2021  NaN  wrong-agency
# 90206  01/01/2018 - 12/23/2021  NaN  wrong-agency
# 90443  07/09/1943 - 07/09/1945  NaN  wrong-agency
# 90537  12/28/2021 - 12/28/2021  NaN  wrong-agency
# 90751  11/19/2021 - 12/31/2021  NaN  wrong-agency

# %%
df.status.value_counts()
# Out:
# SUCCESSFUL                58665
# DENIED                    37237
# PENDING                   35465
# ACCEPTED                  14604
# PARTIALLY SUCCESSFUL      11740
# AWAITING CLARIFICATION     7065
# REFERRED                   5170
# PROCESSING                 3987
# CLOSED                     3464
# EXTENDED                    113
# Name: status, dtype: int64

# %% [markdown]
# # SALN requests, anyone?
#
# Stands for "Statements of Assets, Liabilities and Net Worth" filed by public officials every year.

# %%
df.title.str.contains("SALN", regex=False, case=False).value_counts()
# Out:
# False    177209
# True        298
# Name: title, dtype: int64

# %% [markdown]
# Over 200 requests using the exact words "SALN" on the FOI portal. Below, we use a regex pattern to screen this more.

# %%
saln = df.title.str.extractall(r'(.*\bSALN.+)', re.IGNORECASE)
saln.columns= ['title']
#374 requests mentioning SALN.

# %%
saln = saln.merge(df, on='title')
saln
# Out:
#                                                  title agency       date  \
# 0                              SALN of Bongbong Marcos   DOTr 2016-11-25
# 1    SALN of the following: Ronnan Y. Pado, Ernani ...    DOF 2016-12-05
# 2    SALN of Niño Maximino A. Lazaro Municipal Coun...    DOF 2016-12-17
# 3    The SALNs of each of the cabinet members of th...   PCOO 2016-12-23
# 4    The SALNs of Presidents Aquino and Duterte's C...   PCOO 2017-01-18
# ..                                                 ...    ...        ...
# 490                 ITR and SALN of Barangay Officials    BIR 2022-12-09
# 491                 ITR and SALN of Barangay Officials    BIR 2022-12-09
# 492                 ITR and SALN of Barangay Officials    BIR 2022-12-09
# 493  SALNs of Gerald Quietaleg Bantag, SJO2 Ricardo...   BJMP 2023-01-09
# 494                      SALNs of BANAG, ZULUETA ET AL   DILG 2023-01-30
#
#          status                                            purpose  \
# 0        DENIED                      School Paper Research(Thesis)
# 1        DENIED                                       Transparency
# 2        DENIED                                 Public Information
# 3    SUCCESSFUL                  news reporting/public information
# 4    SUCCESSFUL                                           Research
# ..          ...                                                ...
# 490      DENIED                      Accountability & Transparency
# 491     PENDING                      Accountability & Transparency
# 492      DENIED                      Accountability & Transparency
# 493    ACCEPTED  For legal research in connection with the murd...
# 494     PENDING                        Legal Research and Vlogging
#
#               period_covered  \
# 0    11/25/2016 - 11/25/2016
# 1    12/31/2015 - 12/31/2015
# 2    07/01/2013 - 12/31/2015
# 3    06/30/2016 - 12/23/2016
# 4    06/30/2016 - 06/30/2016
# ..                       ...
# 490  01/01/2018 - 12/09/2022
# 491  01/01/2018 - 12/09/2022
# 492  01/01/2018 - 12/09/2022
# 493  01/08/2010 - 01/08/2023
# 494  01/01/2010 - 12/31/2022
#
#                                                   link       reason_denial
# 0                                                  NaN        wrong-agency
# 1                                                  NaN  incomplete-request
# 2                                                  NaN        wrong-agency
# 3                                                  NaN                   —
# 4                                                  NaN                   —
# ..                                                 ...                 ...
# 490  https://www.foi.gov.ph/requests/aglzfmVmb2ktcG...                 NaN
# 491  https://www.foi.gov.ph/requests/aglzfmVmb2ktcG...                 NaN
# 492  https://www.foi.gov.ph/requests/aglzfmVmb2ktcG...                 NaN
# 493  https://www.foi.gov.ph/requests/aglzfmVmb2ktcG...                 NaN
# 494  https://www.foi.gov.ph/requests/aglzfmVmb2ktcG...                 NaN
#
# [495 rows x 8 columns]

# %%
saln = saln.drop_duplicates()
saln
# Out:
#                                                  title agency       date  \
# 0                              SALN of Bongbong Marcos   DOTr 2016-11-25
# 1    SALN of the following: Ronnan Y. Pado, Ernani ...    DOF 2016-12-05
# 2    SALN of Niño Maximino A. Lazaro Municipal Coun...    DOF 2016-12-17
# 3    The SALNs of each of the cabinet members of th...   PCOO 2016-12-23
# 4    The SALNs of Presidents Aquino and Duterte's C...   PCOO 2017-01-18
# ..                                                 ...    ...        ...
# 488                ITR and SALN of Baranggay Officials   DILG 2022-12-09
# 489                 ITR and SALN of Barangay Officials    BIR 2022-12-09
# 490                 ITR and SALN of Barangay Officials    BIR 2022-12-09
# 493  SALNs of Gerald Quietaleg Bantag, SJO2 Ricardo...   BJMP 2023-01-09
# 494                      SALNs of BANAG, ZULUETA ET AL   DILG 2023-01-30
#
#          status                                            purpose  \
# 0        DENIED                      School Paper Research(Thesis)
# 1        DENIED                                       Transparency
# 2        DENIED                                 Public Information
# 3    SUCCESSFUL                  news reporting/public information
# 4    SUCCESSFUL                                           Research
# ..          ...                                                ...
# 488     PENDING                   Accountability and Transparency.
# 489     PENDING                      Accountability & Transparency
# 490      DENIED                      Accountability & Transparency
# 493    ACCEPTED  For legal research in connection with the murd...
# 494     PENDING                        Legal Research and Vlogging
#
#               period_covered  \
# 0    11/25/2016 - 11/25/2016
# 1    12/31/2015 - 12/31/2015
# 2    07/01/2013 - 12/31/2015
# 3    06/30/2016 - 12/23/2016
# 4    06/30/2016 - 06/30/2016
# ..                       ...
# 488  01/01/2018 - 12/09/2022
# 489  01/01/2018 - 12/09/2022
# 490  01/01/2018 - 12/09/2022
# 493  01/08/2010 - 01/08/2023
# 494  01/01/2010 - 12/31/2022
#
#                                                   link       reason_denial
# 0                                                  NaN        wrong-agency
# 1                                                  NaN  incomplete-request
# 2                                                  NaN        wrong-agency
# 3                                                  NaN                   —
# 4                                                  NaN                   —
# ..                                                 ...                 ...
# 488  https://www.foi.gov.ph/requests/aglzfmVmb2ktcG...                 NaN
# 489  https://www.foi.gov.ph/requests/aglzfmVmb2ktcG...                 NaN
# 490  https://www.foi.gov.ph/requests/aglzfmVmb2ktcG...                 NaN
# 493  https://www.foi.gov.ph/requests/aglzfmVmb2ktcG...                 NaN
# 494  https://www.foi.gov.ph/requests/aglzfmVmb2ktcG...                 NaN
#
# [243 rows x 8 columns]

# %%
# saln.to_csv('saln.csv')

# %%
df[df.agency=="OVP"].title.str.extractall(r'(.*\bSALN.+)', re.IGNORECASE).value_counts().sum()
#66 requests for the SALN of the Vice President.
# Out:
# 78

# %% [markdown]
# ## Drug war

# %%
drug_war = df.title.str.extractall(r'(.*\bdrug war.+)', re.IGNORECASE)

# %%
war_on_drugs = df.title.str.extractall(r'(.*\bwar on drugs.+)', re.IGNORECASE)

# %%
drugs = pd.concat([drug_war, war_on_drugs], ignore_index=True)
drugs
# Out:
#                                                     0
# 0                      Impact of Drug War on Children
# 1               DOJ drug war panel preliminary report
# 2                    Data breakdown of drug war cases
# 3                                    Drug war orphans
# 4                                    Drug war orphans
# 5                                    Drug war orphans
# 6                                    Drug war orphans
# 7                                    Drug war orphans
# 8   Statistics on war on drugs nationwide AND, spe...
# 9                          War On Drugs/Oplan Tokhang
# 10                   DSWD - War on Drugs Intervention
# 11  Status of War on Drugs Program Implementation ...
# 12  Statistics on war on drugs nationwide and, spe...

# %%
drugs.columns= ['title']

# %%
drugs = drugs.merge(df, on='title')
drugs.head(10)
# Out:
#                                    title agency       date  \
# 0         Impact of Drug War on Children   DSWD 2020-03-02
# 1  DOJ drug war panel preliminary report    DOJ 2021-06-14
# 2       Data breakdown of drug war cases    DOJ 2021-06-21
# 3                       Drug war orphans   DSWD 2022-08-10
# 4                       Drug war orphans    PNP 2022-08-10
# 5                       Drug war orphans    PSA 2022-08-10
# 6                       Drug war orphans    PNP 2022-08-10
# 7                       Drug war orphans    PSA 2022-08-10
# 8                       Drug war orphans   DSWD 2022-08-10
# 9                       Drug war orphans    PNP 2022-08-10
#
#                  status                        purpose  \
# 0                DENIED              academic research
# 1                DENIED               For media report
# 2              ACCEPTED  For media research and report
# 3            PROCESSING           Undergraduate thesis
# 4              ACCEPTED           Undergraduate Thesis
# 5               PENDING           Undergraduate Thesis
# 6            SUCCESSFUL           Undergraduate Thesis
# 7  PARTIALLY SUCCESSFUL           Undergraduate Thesis
# 8            PROCESSING           Undergraduate thesis
# 9              ACCEPTED           Undergraduate Thesis
#
#             period_covered                                               link  \
# 0  06/01/2016 - 03/02/2020                                                NaN
# 1  06/01/2020 - 02/01/2021                                                NaN
# 2  06/01/2016 - 05/31/2020                                                NaN
# 3  06/01/2014 - 08/10/2022  https://www.foi.gov.ph/requests/aglzfmVmb2ktcG...
# 4  06/01/2014 - 08/10/2022  https://www.foi.gov.ph/requests/aglzfmVmb2ktcG...
# 5  06/01/2014 - 08/10/2022  https://www.foi.gov.ph/requests/aglzfmVmb2ktcG...
# 6  06/01/2014 - 08/10/2022  https://www.foi.gov.ph/requests/aglzfmVmb2ktcG...
# 7  06/01/2014 - 08/10/2022  https://www.foi.gov.ph/requests/aglzfmVmb2ktcG...
# 8  06/01/2014 - 08/10/2022  https://www.foi.gov.ph/requests/aglzfmVmb2ktcG...
# 9  06/01/2014 - 08/10/2022  https://www.foi.gov.ph/requests/aglzfmVmb2ktcG...
#
#   reason_denial
# 0             —
# 1             —
# 2             —
# 3           NaN
# 4           NaN
# 5           NaN
# 6           NaN
# 7           NaN
# 8           NaN
# 9           NaN

# %% [markdown]
# ## Track request numbers through time
#
# ### By month

# %%
month_query = df.resample('M', on='date').title.count().to_frame().reset_index()
month_query.tail(20)
# Out:
#          date  title
# 57 2021-08-31   3202
# 58 2021-09-30   4917
# 59 2021-10-31   5481
# 60 2021-11-30   5349
# 61 2021-12-31   4004
# 62 2022-01-31   4514
# 63 2022-02-28   6218
# 64 2022-03-31   7837
# 65 2022-04-30   6326
# 66 2022-05-31   4180
# 67 2022-06-30   5050
# 68 2022-07-31   4723
# 69 2022-08-31   6615
# 70 2022-09-30   6349
# 71 2022-10-31   7785
# 72 2022-11-30   7758
# 73 2022-12-31   4953
# 74 2023-01-31   5515
# 75 2023-02-28   7045
# 76 2023-03-31   1876

# %%
(
    ggplot(month_query, aes(x="date", y="title")) + 
    geom_col(color="blue", stat="identity") + 
    geom_smooth()+
    theme(figure_size=(15,7), axis_ticks_length=10) + 
    labs(title="FOI requests peak")
)
# Out:
# /opt/homebrew/lib/python3.10/site-packages/plotnine/stats/smoothers.py:309: PlotnineWarning: Confidence intervals are not yet implemented for lowess smoothings.
# <ggplot: (400080863)>

# %%
month_query = df.resample('M', on='date').title.count().sort_values(ascending=False)
month_query.head(10)
#Largest number of FOI requests recorded in February 2022.
# Out:
# date
# 2022-03-31    7837
# 2022-10-31    7785
# 2022-11-30    7758
# 2023-02-28    7045
# 2022-08-31    6615
# 2022-09-30    6349
# 2022-04-30    6326
# 2022-02-28    6218
# 2023-01-31    5515
# 2021-10-31    5481
# Name: title, dtype: int64

# %% [markdown]
# ### By year

# %%
year_query = df.resample('A', on='date').title.count().to_frame().reset_index()
year_query
# Out:
#         date  title
# 0 2016-12-31    311
# 1 2017-12-31   2413
# 2 2018-12-31   6484
# 3 2019-12-31  13489
# 4 2020-12-31  25588
# 5 2021-12-31  42478
# 6 2022-12-31  72308
# 7 2023-12-31  14436

# %%
(
    ggplot(year_query, aes(x="date", y="title")) + 
    geom_col(color="blue", stat='identity') + 
    theme(figure_size=(15,7), axis_ticks_length=10) + 
    labs(title="Rising FOI requests")
)
# Out:
# <ggplot: (400091587)>

# %% [markdown]
# ## Year-on-year change shows slowing down increase in FOI requests

# %%
df.resample('A', on='date').title.count().pct_change() * 100
#2016 started in September. 2022 as of few weeks of January.
# Out:
# date
# 2016-12-31           NaN
# 2017-12-31    675.884244
# 2018-12-31    168.711148
# 2019-12-31    108.035163
# 2020-12-31     89.695307
# 2021-12-31     66.007504
# 2022-12-31     70.224587
# 2023-12-31    -80.035404
# Freq: A-DEC, Name: title, dtype: float64

# %% [markdown]
# ## Percentage of denied each month

# %%
denied = df[df.status=='DENIED'].resample('M', on='date').agency.count().to_frame().reset_index()
deny = denied.merge(month_query, how='inner', on='date') #merge denied df with year_query
deny.columns= ['date', 'denials', 'total_requests'] #rename columns

# %%
deny ['pct_denied'] = (deny.denials / deny.total_requests) * 100
deny.pct_denied.round(2)
deny
# Out:
#          date  denials  total_requests  pct_denied
# 0  2016-11-30       45             117   38.461538
# 1  2016-12-31       75             194   38.659794
# 2  2017-01-31       41              93   44.086022
# 3  2017-02-28       44             127   34.645669
# 4  2017-03-31      126             222   56.756757
# ..        ...      ...             ...         ...
# 72 2022-11-30      957            7758   12.335654
# 73 2022-12-31      687            4953   13.870382
# 74 2023-01-31      693            5515   12.565730
# 75 2023-02-28     1034            7045   14.677076
# 76 2023-03-31      237            1876   12.633262
#
# [77 rows x 4 columns]

# %%
(
    ggplot(deny, aes(x="date", y="pct_denied")) + 
    geom_col(color="red", stat='identity') + 
    theme(figure_size=(15,7), axis_ticks_length=10) + 
    labs(title="Denied")
)
# Out:
# <ggplot: (400092103)>

# %% [markdown]
# ## Percentage pending

# %%
pending = df[df.status=='PENDING'].resample('M', on='date').agency.count().to_frame().reset_index()
pending = pending.merge(month_query, how='inner', on='date') #merge denied df with year_query
pending.columns= ['date', 'pending_stat', 'total_requests'] #rename columns

# %%
pending ['pct_pending'] = (pending.pending_stat / pending.total_requests) * 100
pending.pct_pending.round(2)
pending
# Out:
#          date  pending_stat  total_requests  pct_pending
# 0  2017-01-31             2              93     2.150538
# 1  2017-02-28             4             127     3.149606
# 2  2017-03-31             6             222     2.702703
# 3  2017-04-30             5             102     4.901961
# 4  2017-05-31             3             139     2.158273
# ..        ...           ...             ...          ...
# 70 2022-11-30          2943            7758    37.935035
# 71 2022-12-31          1552            4953    31.334545
# 72 2023-01-31          1742            5515    31.586582
# 73 2023-02-28          2595            7045    36.834634
# 74 2023-03-31           815            1876    43.443497
#
# [75 rows x 4 columns]

# %%
# pending.to_csv('pending.csv')

# %%
(
    ggplot(pending, aes(x="date", y="pct_pending")) + 
    geom_col(color="orange", stat='identity') + 
    theme(figure_size=(15,7), axis_ticks_length=10) + 
    labs(title="Pending")
)
# Out:
# <ggplot: (400138153)>

# %% [markdown]
# ## Percentage closed
#
# These are requests which were closed after 60 days of non-response from the requestor when the FOI officer asked for clarification of the request.

# %%
closed = df[df.status=='CLOSED'].resample('M', on='date').agency.count().to_frame().reset_index()
close = closed.merge(month_query, how='inner', on='date') #merge closed df with year_query
close.columns= ['date', 'closures', 'total_requests'] #rename columns

# %%
close.head()
# Out:
#         date  closures  total_requests
# 0 2016-11-30        13             117
# 1 2016-12-31        31             194
# 2 2017-01-31         7              93
# 3 2017-02-28        11             127
# 4 2017-03-31         7             222

# %%
close ['pct_closed'] = (close.closures / close.total_requests) * 100
close.head()
# Out:
#         date  closures  total_requests  pct_closed
# 0 2016-11-30        13             117   11.111111
# 1 2016-12-31        31             194   15.979381
# 2 2017-01-31         7              93    7.526882
# 3 2017-02-28        11             127    8.661417
# 4 2017-03-31         7             222    3.153153

# %%
(
    ggplot(close, aes(x="date", y="pct_closed")) + 
    geom_col(color="yellow", stat='identity') + 
    theme(figure_size=(15,7), axis_ticks_length=10) + 
    labs(title="Closed")
)
# Out:
# <ggplot: (400544564)>

# %% [markdown]
# ## Percentage approved

# %%
approved = df[df.status=='ACCEPTED'].resample('M', on='date').agency.count().to_frame().reset_index()
approve = approved.merge(month_query, how='inner', on='date') #merge approved df with year_query
approve.columns= ['date', 'approvals', 'total_requests'] #rename columns
approve
# Out:
#          date  approvals  total_requests
# 0  2016-11-30         13             117
# 1  2016-12-31          3             194
# 2  2017-01-31          1              93
# 3  2017-02-28          4             127
# 4  2017-03-31          9             222
# ..        ...        ...             ...
# 72 2022-11-30       1112            7758
# 73 2022-12-31        670            4953
# 74 2023-01-31        755            5515
# 75 2023-02-28        856            7045
# 76 2023-03-31        181            1876
#
# [77 rows x 3 columns]

# %%
approve ['pct_approve'] = (approve.approvals / approve.total_requests) * 100
approve
# Out:
#          date  approvals  total_requests  pct_approve
# 0  2016-11-30         13             117    11.111111
# 1  2016-12-31          3             194     1.546392
# 2  2017-01-31          1              93     1.075269
# 3  2017-02-28          4             127     3.149606
# 4  2017-03-31          9             222     4.054054
# ..        ...        ...             ...          ...
# 72 2022-11-30       1112            7758    14.333591
# 73 2022-12-31        670            4953    13.527155
# 74 2023-01-31        755            5515    13.689937
# 75 2023-02-28        856            7045    12.150461
# 76 2023-03-31        181            1876     9.648188
#
# [77 rows x 4 columns]

# %%
(
    ggplot(approve, aes(x="date", y="pct_approve")) + 
    geom_col(color="blue", stat='identity') + 
    geom_smooth()+
    theme(figure_size=(15,7), axis_ticks_length=10) + 
    labs(title="Approved")
)
# Out:
# /opt/homebrew/lib/python3.10/site-packages/plotnine/stats/smoothers.py:309: PlotnineWarning: Confidence intervals are not yet implemented for lowess smoothings.
# <ggplot: (400475281)>

# %%
df[df.status=="DENIED"].resample('D', on='date').agency.count().mean()
# Out:
# 16.211144971702222

# %% [markdown]
# ## Regression
#
# Our questions are:
#
# - What are the odds that your FOI request will be denied if your purpose is for media use?
# - Which agency is more likely to deny an FOI request?

# %%
df.status.value_counts()
# Out:
# SUCCESSFUL                58665
# DENIED                    37237
# PENDING                   35465
# ACCEPTED                  14604
# PARTIALLY SUCCESSFUL      11740
# AWAITING CLARIFICATION     7065
# REFERRED                   5170
# PROCESSING                 3987
# CLOSED                     3464
# EXTENDED                    113
# Name: status, dtype: int64

# %%
df['status_code'] = df.status.replace({'SUCCESSFUL' or 'PARTIALLY SUCCESSFUL': 1, 'DENIED': 0})

# %%
df
# Out:
#        agency       date                                              title  \
# 0         DBM 2016-11-25  Cebu City Goverment Projects and Speding for 2016
# 1         DBM 2016-11-25  The Budget for local government buildings proj...
# 2         DOH 2016-11-25  Incidence of diarrhea, constipation, and respi...
# 3         PNP 2016-11-25       Crime Statatistics and Programs to Combat it
# 4        PCGG 2016-11-25  HIRING GOVERNMENT CAREER EMPLOYEES (RANK AND F...
# ...       ...        ...                                                ...
# 177505    PSA 2023-03-10  Number of employed veterinarians under governm...
# 177506   MMDA 2023-03-10                 Contingency Plan of Las Pinas City
# 177507    PSA 2023-03-10  Floor Plan of Las Pinas Disaster Risk Reductio...
# 177508    NTC 2023-03-10                     block my phone 358680937886817
# 177509    NTC 2023-03-10                                     block my phone
#
#                       status  \
# 0                   ACCEPTED
# 1                   ACCEPTED
# 2       PARTIALLY SUCCESSFUL
# 3                     CLOSED
# 4                     DENIED
# ...                      ...
# 177505               PENDING
# 177506               PENDING
# 177507               PENDING
# 177508  PARTIALLY SUCCESSFUL
# 177509  PARTIALLY SUCCESSFUL
#
#                                                   purpose  \
# 0       Research for Cebu City Development to be used ...
# 1       Architectural Thesis entitled Cagayan de Oro C...
# 2                                                Research
# 3                                            School Paper
# 4                                      PUBLIC INFORMATION
# ...                                                   ...
# 177505                 Academic Research (thesis writing)
# 177506                                           Research
# 177507                                           Research
# 177508                                     block my phone
# 177509                              please block my phone
#
#                  period_covered  \
# 0       01/01/2016 - 11/25/2016
# 1       11/25/2015 - 11/25/2016
# 2       11/25/2010 - 11/25/2016
# 3       01/01/2000 - 11/25/2016
# 4       11/25/2016 - 11/25/2016
# ...                         ...
# 177505  01/01/2022 - 01/01/2023
# 177506  01/01/2016 - 11/21/2022
# 177507  01/01/2016 - 11/21/2022
# 177508  11/05/2022 - 01/01/2023
# 177509  11/05/2022 - 01/01/2023
#
#                                                      link reason_denial  \
# 0                                                     NaN             —
# 1                                                     NaN             —
# 2                                                     NaN             —
# 3                                                     NaN             —
# 4                                                     NaN             —
# ...                                                   ...           ...
# 177505  https://www.foi.gov.ph/requests/aglzfmVmb2ktcG...           NaN
# 177506  https://www.foi.gov.ph/requests/aglzfmVmb2ktcG...           NaN
# 177507  https://www.foi.gov.ph/requests/aglzfmVmb2ktcG...           NaN
# 177508  https://www.foi.gov.ph/requests/aglzfmVmb2ktcG...           NaN
# 177509  https://www.foi.gov.ph/requests/aglzfmVmb2ktcG...           NaN
#
#                  status_code
# 0                   ACCEPTED
# 1                   ACCEPTED
# 2       PARTIALLY SUCCESSFUL
# 3                     CLOSED
# 4                          0
# ...                      ...
# 177505               PENDING
# 177506               PENDING
# 177507               PENDING
# 177508  PARTIALLY SUCCESSFUL
# 177509  PARTIALLY SUCCESSFUL
#
# [177510 rows x 9 columns]
