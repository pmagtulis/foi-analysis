# %% [markdown]
# # FOI requests data analysis
#
# As of January 10, 2023, PST
#
# In this notebook, we use the CSV file generated by the auto-scraper to make our analysis of FOI requests.
#
# Remember that the **foi-ph-scraper** ideally scrapes new information from the website every Sunday of the week. The file generated is in a separate repository, which I will just read in here.
#
# **Note**: There were some weeks in 2022 when the scraper failed to run because the website was down. I'm still in the process of looking into entries that were missed. So far, the scraper runs every three days and fetches 3,000 entries every time. This ensures that new entries (and some old ones are collected). We drop the duplicates in the cleaning process.

# %%
import pandas as pd
import re
import requests
from plotnine import *
pd.set_option("display.max_columns", None)

# %% [markdown]
# ## Read df and clean it
#
# Read through the CSV, remove unnecessary columns, look for NaN values and duplicates, convert to datetime before you go through the data.

# %%
df = pd.read_csv('foi_final.csv')
df.tail(10)
# Out:
# /var/folders/00/cqb74mkn60g_hf2zk42fy8_m0000gp/T/ipykernel_4330/1295593880.py:1: DtypeWarning: Columns (7,8) have mixed types. Specify dtype option on import or set low_memory=False.
#         Unnamed: 0 agency        date  \
# 164277      164277    DOH  2023-01-10
# 164278      164278    DOJ  2023-01-10
# 164279      164279     BI  2023-01-10
# 164280      164280    NBI  2023-01-10
# 164281      164281   CHED  2023-01-10
# 164282      164282    LMB  2023-01-10
# 164283      164283  DepEd  2023-01-10
# 164284      164284    DOJ  2023-01-10
# 164285      164285    DOH  2023-01-10
# 164286      164286    NAP  2023-01-10
#
#                                                     title    status  \
# 164277                      Non vaccinated Covid patients   PENDING
# 164278                            Civil Case Verification   PENDING
# 164279                                   13A Cancellation   PENDING
# 164280                                           Scamming   PENDING
# 164281                               Transcript of record  ACCEPTED
# 164282   pinpoint location of property in pagbilao quezon   PENDING
# 164283                                           Form 137   PENDING
# 164284  margareth rillo suspect for murder and dreaded...   PENDING
# 164285          3,127 Covid Cases for 1st week of January   PENDING
# 164286  Ernesto J Valentin extrajudicial settlement am...   PENDING
#
#                                                   purpose  \
# 164277  Transparency request to the agency on how they...
# 164278                             Research & Development
# 164279                              13A visa cancellation
# 164280                       I want my money back pleased
# 164281                                Requesting of T.O.R
# 164282                        Aide intent to buy property
# 164283                                 for college abroad
# 164284  Lifetime Permanent Banned Blacklist Order and ...
# 164285  Request for transparency on the respective agency
# 164286                         for transfer of land title
#
#                  period_covered  \
# 164277  01/01/2023 - 01/08/2023
# 164278  10/01/2022 - 01/09/2023
# 164279  12/01/2022 - 01/10/2023
# 164280  01/09/2023 - 01/10/2023
# 164281  01/01/2023 - 01/02/2023
# 164282  01/10/2023 - 01/10/2023
# 164283  01/01/2009 - 05/01/2013
# 164284  01/01/2018 - 01/10/2023
# 164285  01/01/2023 - 01/08/2023
# 164286  01/01/2002 - 12/12/2002
#
#                                                      link reason_denial
# 164277  https://www.foi.gov.ph/requests/aglzfmVmb2ktcG...           NaN
# 164278  https://www.foi.gov.ph/requests/aglzfmVmb2ktcG...           NaN
# 164279  https://www.foi.gov.ph/requests/aglzfmVmb2ktcG...           NaN
# 164280  https://www.foi.gov.ph/requests/aglzfmVmb2ktcG...           NaN
# 164281  https://www.foi.gov.ph/requests/aglzfmVmb2ktcG...           NaN
# 164282  https://www.foi.gov.ph/requests/aglzfmVmb2ktcG...           NaN
# 164283  https://www.foi.gov.ph/requests/aglzfmVmb2ktcG...           NaN
# 164284  https://www.foi.gov.ph/requests/aglzfmVmb2ktcG...           NaN
# 164285  https://www.foi.gov.ph/requests/aglzfmVmb2ktcG...           NaN
# 164286  https://www.foi.gov.ph/requests/aglzfmVmb2ktcG...           NaN

# %% [markdown]
# ## Drop 'Unnamed' column

# %%
df=df.drop('Unnamed: 0', axis=1)
df
# Out:
#        agency        date                                              title  \
# 0         DBM  2016-11-25  Manampalataya Royalty Fee to the Philippine Go...
# 1        PCOO  2016-11-25                                               eFOI
# 2        DOTr  2016-11-25                            SALN of Bongbong Marcos
# 3        PCOO  2016-11-25                                    Agencies in FOI
# 4         DBM  2016-11-25           Bataan Nuclaer Power Plant Annual Budget
# ...       ...         ...                                                ...
# 164282    LMB  2023-01-10   pinpoint location of property in pagbilao quezon
# 164283  DepEd  2023-01-10                                           Form 137
# 164284    DOJ  2023-01-10  margareth rillo suspect for murder and dreaded...
# 164285    DOH  2023-01-10          3,127 Covid Cases for 1st week of January
# 164286    NAP  2023-01-10  Ernesto J Valentin extrajudicial settlement am...
#
#             status                                            purpose  \
# 0           DENIED                                       Transparency
# 1           DENIED                                      Clarification
# 2           DENIED                      School Paper Research(Thesis)
# 3       SUCCESSFUL                                            R and D
# 4           DENIED                                    Thesis Research
# ...            ...                                                ...
# 164282     PENDING                        Aide intent to buy property
# 164283     PENDING                                 for college abroad
# 164284     PENDING  Lifetime Permanent Banned Blacklist Order and ...
# 164285     PENDING  Request for transparency on the respective agency
# 164286     PENDING                         for transfer of land title
#
#                  period_covered  \
# 0       11/25/2005 - 11/25/2016
# 1       11/25/2016 - 11/25/2016
# 2       11/25/2016 - 11/25/2016
# 3       11/25/2016 - 11/25/2016
# 4       01/01/2015 - 11/25/2016
# ...                         ...
# 164282  01/10/2023 - 01/10/2023
# 164283  01/01/2009 - 05/01/2013
# 164284  01/01/2018 - 01/10/2023
# 164285  01/01/2023 - 01/08/2023
# 164286  01/01/2002 - 12/12/2002
#
#                                                      link reason_denial
# 0                                                     NaN             —
# 1                                                     NaN             —
# 2                                                     NaN  wrong-agency
# 3                                                     NaN             —
# 4                                                     NaN             —
# ...                                                   ...           ...
# 164282  https://www.foi.gov.ph/requests/aglzfmVmb2ktcG...           NaN
# 164283  https://www.foi.gov.ph/requests/aglzfmVmb2ktcG...           NaN
# 164284  https://www.foi.gov.ph/requests/aglzfmVmb2ktcG...           NaN
# 164285  https://www.foi.gov.ph/requests/aglzfmVmb2ktcG...           NaN
# 164286  https://www.foi.gov.ph/requests/aglzfmVmb2ktcG...           NaN
#
# [164287 rows x 8 columns]

# %% [markdown]
# ## Convert to datetime

# %%
df.dtypes
# Out:
# agency            object
# date              object
# title             object
# status            object
# purpose           object
# period_covered    object
# link              object
# reason_denial     object
# dtype: object

# %%
df.date = pd.to_datetime(df.date)

# %%
df.dtypes
# Out:
# agency                    object
# date              datetime64[ns]
# title                     object
# status                    object
# purpose                   object
# period_covered            object
# link                      object
# reason_denial             object
# dtype: object

# %% [markdown]
# ## Check for duplicates
#
# There are some duplicates found, but let's check. Remember, we only drop the duplicates if they are the same across **all columns**. Otherwise, we keep them, especially if the same requests are filed with different agencies.

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df[df.duplicated()]
# Out:
# Empty DataFrame
# Columns: [agency, date, title, status, purpose, period_covered, link, reason_denial]
# Index: []

# %% [markdown]
# ## Looking into the NaNs
#
# We look for null values and whether they account for significant number of the data.

# %%
df.isna().sum()
# Out:
# agency                1
# date                  0
# title                 3
# status                0
# purpose               6
# period_covered        0
# link              90765
# reason_denial     73522
# dtype: int64

# %% [markdown]
# Interpretation: The **link** column have nearly 91,000 null values. This is because a large part of the data in our df came from an existing CSV maintained by the government. The same goes for **reason_denial.**
#
# You can find the CSV here: https://docs.google.com/spreadsheets/d/1kblO1_-gL65qXu_EJJBvc59UUHBQ7K3c/edit?fbclid=IwAR332h3xXbevTcnDiKQwKWldsod3kPP3J0T9_5NSXALgFI7XZPyIxMuqXg0#gid=875187444
#
# The data is updated quarterly. We merged this data early on with the scraped data from the website.

# %% [markdown]
# ## Analysis
#
# Now that we have all the requests contained in one file, we can now analyze them, still using pandas.

# %% [markdown]
# ## How much of the requests are granted or denied?

# %%
df.status.value_counts(normalize=True) *100
# Out:
# SUCCESSFUL                34.374601
# DENIED                    21.547049
# PENDING                   18.739766
# ACCEPTED                   7.923329
# PARTIALLY SUCCESSFUL       6.582383
# AWAITING CLARIFICATION     3.818318
# REFERRED                   2.747022
# CLOSED                     2.108505
# PROCESSING                 2.102418
# EXTENDED                   0.056608
# Name: status, dtype: float64

# %%
(
    ggplot(df) + 
    geom_bar(aes(x="status")) + 
    theme(figure_size=(15,7), axis_ticks_length=10) + 
    labs(title="Over 1 in 4 FOI requests denied")
)
# Out:
# <ggplot: (678902301)>

# %% [markdown]
# Note: We are still seeking clarification from PCOO on what **CLOSED** means. Meanwhile, over one in four FOI requests are denied by agencies. Over half are **successful** or **partially sucessful**.

# %% [markdown]
# ## Which agencies get the most FOI requests?

# %%
df.agency.value_counts().head(10)
# Out:
# DOH      16502
# PSA       9604
# BIR       6783
# DepEd     6704
# DOLE      6597
# SSS       5462
# DSWD      5431
# NTC       5207
# OWWA      4381
# DPWH      4118
# Name: agency, dtype: int64

# %% [markdown]
# The Department of Health, Philippine Statistics Authority and the labor department get the most requests.

# %% [markdown]
# ## Which agencies deny the most requests?
#
# The Bureau of Internal Revenue tops the list, although a deeper probe would show most of the denials were a result of requests for personal tax records, which are not for public consumption.

# %%
df[df.status=="DENIED"].agency.value_counts().head(10)
# Out:
# BIR     3552
# DSWD    3113
# NBI     1968
# DENR    1471
# DOH     1258
# DTI     1245
# DOTr     906
# DOLE     887
# HDMF     830
# PNP      776
# Name: agency, dtype: int64

# %% [markdown]
# # Drilling down on specific agencies and requests
#
# We select a few agencies and search in their request files some of the most common requests by **title** as well as some of the most denials.

# %% [markdown]
# ## DOH: Vaccination certificates

# %%
df[df.agency=="DOH"].title.value_counts().head(20)
# Out:
# Vaccination Certificate           456
# Vaxcert                           306
# VaxCert                           149
# Vaccination Card                  142
# Vaccine Certificate               137
# Lost Vaccination Card             127
# Vaccination certificate           115
# Lost Vaccine Card                  99
# VAXCERT                            82
# Vax Cert                           72
# Vax Certificate                    69
# Vaccination card                   64
# Vaccine certificate                62
# VACCINATION CERTIFICATE            59
# VaxCertPH                          53
# Vaxcert; incorrect middle name     49
# vaxcert                            46
# Vaccine Card                       46
# Vaxcertificate                     37
# vaccination certificate            36
# Name: title, dtype: int64

# %%
vax = ["Vaccination Certificate", "Vaxcert", "VaxCert", "Vaccination certificate", "Vax Cert", "VAXCERT", "VAX CERT", "Vax Certificate", "Vax certificate", "VACCINATION CERTIFICATE", "Vax cert", "VaxCertPH", "Vax Cert PH", "vax cert", "Vax cert request", "Vax Cert Request", "Vaccination Card", "Vax card", "vaccination card", "Vaccine certificate", "vaccine certificate"]
df_vax = df[df['title'].isin(vax)].reset_index(drop=True)
df_vax.count()
# Out:
# agency            1817
# date              1817
# title             1817
# status            1817
# purpose           1817
# period_covered    1817
# link              1381
# reason_denial      436
# dtype: int64

# %% [markdown]
# Interpretation: Over one in 10 DOH requests from 2016 were to request for vaccination certificates.

# %% [markdown]
# ## DSWD: Social amelioration program
#
# This is the P275-billion pandemic relief program by the government in 2020 that gave dole outs to poor families. The program were given in two tranches and were marred by significant delays and other irregularities.

# %%
sap = ["SAP", "SAP 2nd tranche", "Sap 2nd tranche", "Social Amelioration Program", "Social amelioration program", "sap 2nd tranche", "SAP 2nd tranche", "2nd tranche", "DSWD SAP", "SAP 2ND TRANCHE", "Sap 2nd Tranche", "SAP 1st tranche", "SAP first tranche", "SAP 1ST TRANCHE", "Sap"]
df_sap = df[df['title'].isin(sap)].reset_index(drop=True)
df_sap[df_sap.status=="DENIED"].head(10)
# Out:
#   agency       date                        title  status  \
# 0   DSWD 2020-04-09  Social amelioration program  DENIED
# 1   DSWD 2020-04-21  Social Amelioration Program  DENIED
# 2   DSWD 2020-04-21                          Sap  DENIED
# 3   DSWD 2020-04-23  Social Amelioration Program  DENIED
# 4   DSWD 2020-04-25  Social Amelioration Program  DENIED
# 5   DSWD 2020-04-27  Social Amelioration Program  DENIED
# 6   DSWD 2020-04-27                     DSWD SAP  DENIED
# 7   DSWD 2020-05-01  Social Amelioration Program  DENIED
# 8   DSWD 2020-05-01                          SAP  DENIED
# 9   DSWD 2020-05-03                          Sap  DENIED
#
#                                              purpose           period_covered  \
# 0                          Personal information only  04/09/2020 - 04/09/2020
# 1             Transparency purposes to my kabarangay  04/01/2020 - 04/21/2020
# 2                                        Solo parent  04/08/2020 - 04/21/2020
# 3                        Validation and Confirmation  04/23/2020 - 04/23/2020
# 4  To known the list of beneficiaries of Social A...  03/01/2020 - 04/25/2020
# 5                                       Transparency  04/19/2020 - 04/27/2020
# 6    To know the status of DSWD SAP in our Barangay.  04/27/2020 - 04/27/2020
# 7                        Social Amelioration Program  03/16/2020 - 04/30/2020
# 8                                    SAP APPLICATION  05/01/2020 - 05/01/2020
# 9          Applying for special amelioration program  03/21/2020 - 04/21/2020
#
#   link       reason_denial
# 0  NaN                   —
# 1  NaN                   —
# 2  NaN                   —
# 3  NaN                   —
# 4  NaN                   —
# 5  NaN                   —
# 6  NaN                   —
# 7  NaN  incomplete-request
# 8  NaN                   —
# 9  NaN                   —

# %% [markdown]
# Interpretation: Most requests for SAP were denied and were deemed an "invalid request."

# %%
df_sap.count()
#180 requests about SAP.
# Out:
# agency            182
# date              182
# title             182
# status            182
# purpose           182
# period_covered    182
# link                7
# reason_denial     175
# dtype: int64

# %% [markdown]
# ## OVP: Any type of "assistance"
#
# The office of former Vice President Leni Robredo is known for its **Angat Buhay** program that helps the poor.

# %%
df[df.agency=="OVP"].title.str.contains("assistance", regex=False, case=False).value_counts()
# Out:
# False    615
# True     446
# Name: title, dtype: int64

# %% [markdown]
# Interpretation: 40% of OVP FOI requests mention some form of "assistance".

# %% [markdown]
# ## BIR: Tax identification number or TIN
#
# Tax matters are generally protected by privacy laws in the Philippines. But that did not stop some people to request for them through FOI.

# %%
#df_final[df_final.title=="Income Tax Return"]
tax = ['Income Tax Return', 'ITR','BIR 2316', 'TIN Verification', 'TIN VERIFICATION', 'BIR Form 2316', 'Income tax return', 'TIN', 'INCOME TAX RETURN', 'Form 2316', 'TIN NUMBER', 'tin number', 'TIN verification', 'tax', 'tax records']
df_tax = df[df['title'].isin(tax)].reset_index(drop=True)
df_tax.tail(10)
# Out:
#      agency       date              title                  status  \
# 1732    BIR 2023-01-04                ITR                 PENDING
# 1733    BIR 2023-01-04  Income Tax Return                  DENIED
# 1734    BIR 2023-01-04                ITR              SUCCESSFUL
# 1735    BIR 2023-01-04  Income Tax Return                 PENDING
# 1736    BIR 2023-01-06                ITR                  DENIED
# 1737    BIR 2023-01-06                ITR                 PENDING
# 1738    BIR 2023-01-07          Form 2316                  DENIED
# 1739    BIR 2023-01-08  Income Tax Return                ACCEPTED
# 1740    BIR 2023-01-09  Income Tax Return  AWAITING CLARIFICATION
# 1741    BIR 2023-01-09                ITR    PARTIALLY SUCCESSFUL
#
#                     purpose           period_covered  \
# 1732        Job Application  01/04/2022 - 01/04/2023
# 1733            Visa/Travel  01/01/2022 - 12/31/2022
# 1734        Job Application  01/04/2022 - 01/04/2023
# 1735            Visa/Travel  01/01/2022 - 12/31/2022
# 1736       Visa application  01/01/2014 - 12/31/2021
# 1737       Visa application  01/01/2014 - 12/31/2021
# 1738      For loan purposes  07/04/2022 - 12/05/2022
# 1739       Visa application  01/01/2019 - 12/31/2022
# 1740        Personal Filing  01/01/2021 - 12/31/2021
# 1741  Requirements purposes  01/01/2021 - 01/09/2023
#
#                                                    link reason_denial
# 1732  https://www.foi.gov.ph/requests/aglzfmVmb2ktcG...           NaN
# 1733  https://www.foi.gov.ph/requests/aglzfmVmb2ktcG...           NaN
# 1734  https://www.foi.gov.ph/requests/aglzfmVmb2ktcG...           NaN
# 1735  https://www.foi.gov.ph/requests/aglzfmVmb2ktcG...           NaN
# 1736  https://www.foi.gov.ph/requests/aglzfmVmb2ktcG...           NaN
# 1737  https://www.foi.gov.ph/requests/aglzfmVmb2ktcG...           NaN
# 1738  https://www.foi.gov.ph/requests/aglzfmVmb2ktcG...           NaN
# 1739  https://www.foi.gov.ph/requests/aglzfmVmb2ktcG...           NaN
# 1740  https://www.foi.gov.ph/requests/aglzfmVmb2ktcG...           NaN
# 1741  https://www.foi.gov.ph/requests/aglzfmVmb2ktcG...           NaN

# %%
df_tax.status.value_counts()
# Out:
# DENIED                    765
# AWAITING CLARIFICATION    578
# SUCCESSFUL                132
# PENDING                   129
# ACCEPTED                   58
# PARTIALLY SUCCESSFUL       51
# REFERRED                   15
# CLOSED                      8
# PROCESSING                  5
# EXTENDED                    1
# Name: status, dtype: int64

# %%
df_tax.status.value_counts(normalize=True) *100
# Out:
# DENIED                    43.915040
# AWAITING CLARIFICATION    33.180253
# SUCCESSFUL                 7.577497
# PENDING                    7.405281
# ACCEPTED                   3.329506
# PARTIALLY SUCCESSFUL       2.927669
# REFERRED                   0.861079
# CLOSED                     0.459242
# PROCESSING                 0.287026
# EXTENDED                   0.057405
# Name: status, dtype: float64

# %% [markdown]
# # Top purpose of requests

# %%
df.purpose.value_counts(ascending=False).head(10)
# Out:
# Research                    13003
# Research and Development     6631
# Thesis                       3060
# Undergraduate Thesis         3012
# Architectural Thesis         2887
# Research and development     2638
# Academic Research            1161
# Thesis Research              1038
# research                      752
# Undergraduate Research        651
# Name: purpose, dtype: int64

# %% [markdown]
# ## For academic purposes

# %%
research = df.purpose.str.extractall(r'(.*\bresearch.+)', re.IGNORECASE)
research
# Out:
#                                                               0
#        match
# 2      0                          School Paper Research(Thesis)
# 8      0      Research work on urban and public history duri...
# 10     0                       Research and General Information
# 11     0                     Research and basis of authenticity
# 13     0                                 Research & Development
# ...                                                         ...
# 164234 0                               Research and development
# 164256 0                               Research and Development
# 164265 0                               Research and Development
# 164269 0                      Research Paper in Master's Degree
# 164278 0                                 Research & Development
#
# [30532 rows x 1 columns]

# %%
thesis = df.purpose.str.extractall(r'(.*\bthesis.+)', re.IGNORECASE)
thesis
# Out:
#                                                               0
#        match
# 2      0                          School Paper Research(Thesis)
# 4      0                                        Thesis Research
# 24     0      Architectural Thesis entitled Cagayan de Oro C...
# 42     0      Research for Cebu City Development to be used ...
# 107    0                       Research / Possible Thesis Study
# ...                                                         ...
# 164106 0                   Research Thesis for Graduate Studies
# 164136 0                                        Thesis research
# 164149 0                               Research/Thesis Purposes
# 164169 0                                       Thesis/ Research
# 164238 0                                        Thesis research
#
# [10214 rows x 1 columns]

# %%
academic = df.purpose.str.extractall(r'(.*\bacademic.+)', re.IGNORECASE)
academic
# Out:
#                                             0
#        match
# 83     0                    Academic research
# 365    0                    Academic research
# 388    0                    Academic Research
# 457    0                    Academic research
# 463    0                    Academic Research
# ...                                       ...
# 164011 0               academic purposes only
# 164013 0            For ICES academic records
# 164023 0            For ICES academic records
# 164101 0      Education and Academic Research
# 164192 0                    Academic Research
#
# [4708 rows x 1 columns]

# %%
research_2 = pd.concat([research, academic, thesis], ignore_index=True)
research_2.columns= ['purpose']
research_2
# Out:
#                                                  purpose
# 0                          School Paper Research(Thesis)
# 1      Research work on urban and public history duri...
# 2                       Research and General Information
# 3                     Research and basis of authenticity
# 4                                 Research & Development
# ...                                                  ...
# 45449               Research Thesis for Graduate Studies
# 45450                                    Thesis research
# 45451                           Research/Thesis Purposes
# 45452                                   Thesis/ Research
# 45453                                    Thesis research
#
# [45454 rows x 1 columns]

# %%
# research_2 = research_2.merge(df, on='purpose')
# research_2.duplicated().value_counts()

# %%
#research_2[research_2.duplicated()]

# %% [markdown]
# ## For journalistic purposes

# %%
news = df.purpose.str.extractall(r'(.*\bnews.+)', re.IGNORECASE)
news
# Out:
#                                                               0
#        match
# 68     0                                           news article
# 69     0                                           news article
# 86     0                                            News report
# 213    0      This will be used for the verification of "new...
# 249    0                              Research and news article
# ...                                                         ...
# 159910 0                                 news research for GMA7
# 160051 0                                 news research for GMA7
# 162473 0      The data you will provide us will be used as b...
# 163664 0             data request to be used n GMA7's newscasts
# 163699 0             data request to be used n GMA7's newscasts
#
# [349 rows x 1 columns]

# %%
media = df.purpose.str.extractall(r'(.*\bmedia.+)', re.IGNORECASE)

# %%
journalism = pd.concat([news, media], ignore_index=True)
journalism.columns= ['purpose']
journalism
# Out:
#                                                purpose
# 0                                         news article
# 1                                         news article
# 2                                          News report
# 3    This will be used for the verification of "new...
# 4                            Research and news article
# ..                                                 ...
# 588  File a report to the person resulting to a rec...
# 589  File a report to the person resulting to a rec...
# 590  To Stop OLA harassment, Illegal accessing of m...
# 591  To Stop OLA harassment, Illegal accessing of m...
# 592  To Stop OLA harassment, Illegal accessing of m...
#
# [593 rows x 1 columns]

# %%
journalism = journalism.merge(df, on='purpose')
journalism.duplicated().sum()
# Out:
# 2064

# %%
journalism = journalism.drop_duplicates().reset_index(drop=True)
journalism
# Out:
#                                                purpose agency       date  \
# 0                                         news article    PNP 2016-11-27
# 1                                         news article    PNP 2016-11-27
# 2                                          News report    DBM 2016-11-28
# 3                                          News report   PCOO 2017-01-27
# 4                                          News report   PDEA 2017-11-21
# ..                                                 ...    ...        ...
# 578  To Stop OLA harassment, Illegal accessing of m...    SEC 2022-12-11
# 579  File a report to the person resulting to a rec...    NBI 2022-12-11
# 580  File a report to the person resulting to a rec...    NBI 2022-12-11
# 581  To Stop OLA harassment, Illegal accessing of m...    NPC 2022-12-11
# 582  To Stop OLA harassment, Illegal accessing of m...    NBI 2022-12-11
#
#                                                  title      status  \
# 0    PNP Region 9 Director Billy Beltran and PNP Ge...      DENIED
# 1                                        oplan tokhang  SUCCESSFUL
# 2    Cost of President Duterte's trip to Laos, Chin...      DENIED
# 3    Cost of each of President Duterte's foreign tr...      DENIED
# 4                            Statistics on drug prices      DENIED
# ..                                                 ...         ...
# 578  Complaint on OLA Harrassment, breach of my dat...    ACCEPTED
# 579     Facebook Scammer and payment is done via GCASH      DENIED
# 580     Facebook Scammer and payment is done via GCASH     PENDING
# 581  Complaint on OLA Harrassment, breach of my dat...     PENDING
# 582  Complaint on OLA Harrassment, breach of my dat...     PENDING
#
#               period_covered  \
# 0    06/01/2016 - 07/02/2016
# 1    07/01/2016 - 11/02/2016
# 2    09/05/2016 - 11/23/2016
# 3    09/05/2016 - 12/17/2016
# 4    07/01/2016 - 11/21/2017
# ..                       ...
# 578  11/27/2022 - 12/11/2022
# 579  12/09/2022 - 12/11/2022
# 580  12/09/2022 - 12/11/2022
# 581  11/27/2022 - 12/11/2022
# 582  11/27/2022 - 12/11/2022
#
#                                                   link       reason_denial
# 0                                                  NaN  incomplete-request
# 1                                                  NaN                   —
# 2                                                  NaN                   —
# 3                                                  NaN        wrong-agency
# 4                                                  NaN                   —
# ..                                                 ...                 ...
# 578  https://www.foi.gov.ph/requests/aglzfmVmb2ktcG...                 NaN
# 579  https://www.foi.gov.ph/requests/aglzfmVmb2ktcG...                 NaN
# 580  https://www.foi.gov.ph/requests/aglzfmVmb2ktcG...                 NaN
# 581  https://www.foi.gov.ph/requests/aglzfmVmb2ktcG...                 NaN
# 582  https://www.foi.gov.ph/requests/aglzfmVmb2ktcG...                 NaN
#
# [583 rows x 8 columns]

# %% [markdown]
# # Know each agencies' performance
#
# Just changed the name of the agency in brackets.

# %%
df[df.agency=="OP"]
#There were some requests for SALN.
# Out:
#        agency       date                                              title  \
# 2570       OP 2017-12-01  Total cost/expenses for the foreign trips of P...
# 2594       OP 2017-12-04  Cost of President Duterte's foreign trips in h...
# 2604       OP 2017-12-05  Updates on the appeals of suspended and closed...
# 2703       OP 2017-12-24                    2018 General Appropriations Act
# 2720       OP 2017-12-30                     Executive Order 126 dated 1959
# 3026       OP 2018-01-31     NSC Group Photos with Living Former Presidents
# 3169       OP 2018-02-11  Documentary proof or evidence of President Dut...
# 3178       OP 2018-02-11  Breakdown of War Materiel used by the AFP in t...
# 3182       OP 2018-02-11  What is the counterpart of the CIA in the Phil...
# 3220       OP 2018-02-13               Actual Expenses of ASEAN 2017 budget
# 3470       OP 2018-03-03  Impact of OFW remittances on the Philippine Ec...
# 3480       OP 2018-03-04                                 Appointment Papers
# 75701      OP 2021-09-29    Statement of Assets, Liabilities, and Net Worth
# 77088      OP 2021-10-07  Statement of Assets, Liabilities, and Net Wort...
# 77147      OP 2021-10-07  Statement of Assets, Liabilities, and Net Wort...
# 78927      OP 2021-10-18  Accomplishments and Negative Impact of late Fe...
# 83982      OP 2021-11-15  PRESIDENTIAL SINCE 1965 BUDGET FROM START OF T...
# 87338      OP 2021-12-03             National Budget from Marcos Presidency
# 87346      OP 2021-12-03  You money building you steal everything you fo...
# 96803      OP 2022-02-08          Government Directory from 1900 to present
# 106201     OP 2022-03-19                       SALN - Agnes Joyce G. Bailen
# 109339     OP 2022-04-01                                            IRR for
# 109986     OP 2022-04-04  List of places visited by President Rodrigo Ro...
# 116299     OP 2022-05-04  Budget ni President Marcos sa loob ng 20 years...
# 128846     OP 2022-07-27            IRR of Executive Order No. 249, s. 1987
# 134054     OP 2022-08-23                           Presidential Decree 1158
# 137750     OP 2022-09-07                                          EO No. 77
# 142288     OP 2022-09-29  Request for list of Newly appointed Undersecre...
# 142325     OP 2022-09-29    Lot Technical Description - La Trinidad Benguet
# 142934     OP 2022-10-03  Request for list of Newly appointed Undersecre...
# 143029     OP 2022-10-03  Request for the Official Portraits of Presiden...
# 146787     OP 2022-10-18  List of President Bong Bong Marcos' Travels fr...
# 150744     OP 2022-11-02  Number of Complaints received through the 8888...
# 150782     OP 2022-11-02  Data regarding Executive Order No. 6, series o...
# 157175     OP 2022-11-25  Executive Order of President Ferdinand Marcos Jr.
#
#          status                                            purpose  \
# 2570    PENDING  For research purposes for my year-end report f...
# 2594    PENDING                                      News research
# 2604    PENDING                                           Research
# 2703    PENDING  Factual basis in research and review of certai...
# 2720    PENDING                                            HISTORY
# 3026    PENDING                     Research and Archive purposes.
# 3169    PENDING                Research for Graduate School class.
# 3178    PENDING                Research for Graduate School class.
# 3182    PENDING                                           Research
# 3220    PENDING                                  Research purposes
# 3470    PENDING                                 Practical Research
# 3480    PENDING                       Personal Reference / Inquiry
# 75701   PENDING               Research and other academic purposes
# 77088   PENDING                     Academic and Research purposes
# 77147   PENDING                     Academic and Research Purposes
# 78927   PENDING                           Research and Development
# 83982   PENDING  I Want to do a small study for my own educatio...
# 87338   PENDING                              For Research Purposes
# 87346   PENDING  Pera lahat records justices Icc criminal court...
# 96803   PENDING                             Undergraduate Research
# 106201  PENDING  Research and development - voter education, kn...
# 109339  PENDING  To be used as part of document for the entitle...
# 109986  PENDING                           Research and Development
# 116299  PENDING                                           RESEARCH
# 128846  PENDING  Information request on behalf of library resea...
# 134054  PENDING                                           Research
# 137750  PENDING                         For clarify of information
# 142288  PENDING                           Research and Development
# 142325  PENDING         Conduct of Academic Architectural Research
# 142934  PENDING                           Research and Development
# 143029  PENDING               Educational and Informative Purposes
# 146787  PENDING                                For Academic Report
# 150744  PENDING     This is for research purposes, for our thesis.
# 150782  PENDING                             For Research Purposes.
# 157175  PENDING                 As a reference for Christmas Bonus
#
#                  period_covered  \
# 2570    01/01/2017 - 12/01/2017
# 2594    07/01/2016 - 07/01/2017
# 2604    02/02/2017 - 12/05/2017
# 2703    12/24/2017 - 12/24/2017
# 2720    12/30/2017 - 12/30/2017
# 3026    07/27/2016 - 07/27/2016
# 3169    03/28/1945 - 02/11/2018
# 3178    05/23/2017 - 11/23/2017
# 3182    02/11/2018 - 02/11/2018
# 3220    01/01/2017 - 01/01/2018
# 3470    02/25/2018 - 03/03/2018
# 3480    06/30/2016 - 03/04/2018
# 75701   01/01/2018 - 12/31/2020
# 77088   01/01/2018 - 10/01/2020
# 77147   01/01/2018 - 10/01/2020
# 78927   09/21/1972 - 09/21/1986
# 83982   12/30/1965 - 11/14/2021
# 87338   12/30/1965 - 12/02/2021
# 87346   12/01/2021 - 12/01/2021
# 96803   01/01/1900 - 01/01/2022
# 106201  01/01/2021 - 12/31/2021
# 109339  05/01/2021 - 10/30/2021
# 109986  06/01/2016 - 04/02/2022
# 116299  05/01/2022 - 05/04/2022
# 128846  01/01/1987 - 12/31/2021
# 134054  06/03/1977 - 01/01/1998
# 137750  09/06/2022 - 09/06/2022
# 142288  07/01/2022 - 09/28/2022
# 142325  11/11/1914 - 09/28/2022
# 142934  06/01/2022 - 10/03/2022
# 143029  01/01/1899 - 10/02/2022
# 146787  06/30/2022 - 10/08/2022
# 150744  08/30/2016 - 10/30/2022
# 150782  08/30/2016 - 10/30/2016
# 157175  11/24/2022 - 11/24/2022
#
#                                                      link reason_denial
# 2570                                                  NaN             —
# 2594                                                  NaN             —
# 2604                                                  NaN             —
# 2703                                                  NaN             —
# 2720                                                  NaN             —
# 3026                                                  NaN             —
# 3169                                                  NaN             —
# 3178                                                  NaN             —
# 3182                                                  NaN             —
# 3220                                                  NaN             —
# 3470                                                  NaN             —
# 3480                                                  NaN             —
# 75701                                                 NaN             —
# 77088                                                 NaN             —
# 77147                                                 NaN             —
# 78927                                                 NaN             —
# 83982                                                 NaN             —
# 87338                                                 NaN             —
# 87346                                                 NaN             —
# 96803   https://www.foi.gov.ph/requests/aglzfmVmb2ktcG...           NaN
# 106201  https://www.foi.gov.ph/requests/aglzfmVmb2ktcG...           NaN
# 109339  https://www.foi.gov.ph/requests/aglzfmVmb2ktcG...           NaN
# 109986  https://www.foi.gov.ph/requests/aglzfmVmb2ktcG...           NaN
# 116299  https://www.foi.gov.ph/requests/aglzfmVmb2ktcG...           NaN
# 128846  https://www.foi.gov.ph/requests/aglzfmVmb2ktcG...           NaN
# 134054  https://www.foi.gov.ph/requests/aglzfmVmb2ktcG...           NaN
# 137750  https://www.foi.gov.ph/requests/aglzfmVmb2ktcG...           NaN
# 142288  https://www.foi.gov.ph/requests/aglzfmVmb2ktcG...           NaN
# 142325  https://www.foi.gov.ph/requests/aglzfmVmb2ktcG...           NaN
# 142934  https://www.foi.gov.ph/requests/aglzfmVmb2ktcG...           NaN
# 143029  https://www.foi.gov.ph/requests/aglzfmVmb2ktcG...           NaN
# 146787  https://www.foi.gov.ph/requests/aglzfmVmb2ktcG...           NaN
# 150744  https://www.foi.gov.ph/requests/aglzfmVmb2ktcG...           NaN
# 150782  https://www.foi.gov.ph/requests/aglzfmVmb2ktcG...           NaN
# 157175  https://www.foi.gov.ph/requests/aglzfmVmb2ktcG...           NaN

# %% [markdown]
# ## Government contracts

# %%
contract = ['contract', 'contracts', 'audit', 'audit report', 'Audit report', 'Audit Report', 'Contract', 'Contracts', 'loan agreement', 'Agreements', 'Agreement', 'agreement', 'agreements']
df_contract = df[df['title'].isin(contract)].reset_index(drop=True)
df_contract.head(7)
# Out:
#   agency       date         title    status  \
# 0   LRTA 2019-03-29      Contract    DENIED
# 1    DFA 2021-03-14  Audit Report    DENIED
# 2   PPPC 2022-06-19     Contracts    DENIED
# 3    LTO 2022-06-19      Contract   PENDING
# 4    LRA 2022-06-19      Contract   PENDING
# 5   PPPC 2022-06-19     Contracts   PENDING
# 6   PPPC 2022-06-19     Contracts  ACCEPTED
#
#                                purpose           period_covered  \
# 0  For own personal use or information  01/01/2018 - 12/31/2018
# 1                     Research Purpose  01/01/2018 - 07/30/2020
# 2             Research and Development  06/19/2020 - 06/19/2022
# 3                             Research  06/19/2020 - 06/19/2022
# 4                             Research  06/19/2020 - 06/19/2022
# 5             Research and Development  06/19/2020 - 06/19/2022
# 6             Research and Development  06/19/2020 - 06/19/2022
#
#                                                 link  \
# 0                                                NaN
# 1                                                NaN
# 2  https://www.foi.gov.ph/requests/aglzfmVmb2ktcG...
# 3  https://www.foi.gov.ph/requests/aglzfmVmb2ktcG...
# 4  https://www.foi.gov.ph/requests/aglzfmVmb2ktcG...
# 5  https://www.foi.gov.ph/requests/aglzfmVmb2ktcG...
# 6  https://www.foi.gov.ph/requests/aglzfmVmb2ktcG...
#
#                   reason_denial
# 0                             —
# 1  information-available-online
# 2                           NaN
# 3                           NaN
# 4                           NaN
# 5                           NaN
# 6                           NaN

# %% [markdown]
# ## Top reasons for denial
#
# Applicable only to data as of December 2021.

# %%
df.reason_denial.value_counts(dropna=False)
#"-" means it's not applicable since the request was not denied.
# Out:
# —                               77314
# NaN                             73522
# wrong-agency                     6980
# incomplete-request               2764
# invalid-request                  2084
# information-available-online     1620
# exceptions                          2
# privacy                             1
# Name: reason_denial, dtype: int64

# %%
df[df.reason_denial=='wrong-agency'].tail(10)
# Out:
#       agency       date                                              title  \
# 89729   CHED 2021-12-18                                 Request for laptop
# 89763   DOTr 2021-12-18          Kalibo International Airport Informations
# 89806    NTC 2021-12-19  Requesting for Individual/Company name uses th...
# 89809     PH 2021-12-19                             VaccinationCertificate
# 89821     PH 2021-12-19                            Vaccination Certificate
# 90063   DENR 2021-12-21  Certificate of ancestral domain title in Sioco...
# 90256   CHED 2021-12-23                              Registration Form 001
# 90383    NAP 2021-12-27                                       Birth Record
# 90540    DAR 2021-12-28         CLUP and Zoning Ordinance of Angono, Rizal
# 90733    DOJ 2021-12-31                                        INFORMATION
#
#        status                                            purpose  \
# 89729  DENIED            Educational and future career purposes.
# 89763  DENIED                                Research for Thesis
# 89806  DENIED  All my contacts got an sms blast from this num...
# 89809  DENIED                                          To travel
# 89821  DENIED                                          To Travel
# 90063  DENIED  To verify that who is the head of CADT in Siti...
# 90256  DENIED                            Employment Requirements
# 90383  DENIED                                SSS Funeral Benefit
# 90540  DENIED                                           Research
# 90733  DENIED                         RESOLUTION AND INFORMATION
#
#                 period_covered link reason_denial
# 89729  11/26/2021 - 12/18/2021  NaN  wrong-agency
# 89763  12/18/2021 - 12/18/2021  NaN  wrong-agency
# 89806  12/19/2021 - 12/19/2021  NaN  wrong-agency
# 89809  06/14/2021 - 07/12/2021  NaN  wrong-agency
# 89821  06/14/2021 - 07/12/2021  NaN  wrong-agency
# 90063  12/21/2021 - 12/21/2021  NaN  wrong-agency
# 90256  01/01/2018 - 12/23/2021  NaN  wrong-agency
# 90383  07/09/1943 - 07/09/1945  NaN  wrong-agency
# 90540  12/28/2021 - 12/28/2021  NaN  wrong-agency
# 90733  11/19/2021 - 12/31/2021  NaN  wrong-agency

# %%
df.status.value_counts()
# Out:
# SUCCESSFUL                56473
# DENIED                    35399
# PENDING                   30787
# ACCEPTED                  13017
# PARTIALLY SUCCESSFUL      10814
# AWAITING CLARIFICATION     6273
# REFERRED                   4513
# CLOSED                     3464
# PROCESSING                 3454
# EXTENDED                     93
# Name: status, dtype: int64

# %% [markdown]
# # SALN requests, anyone?
#
# Stands for "Statements of Assets, Liabilities and Net Worth" filed by public officials every year.

# %%
df.title.str.contains("SALN", regex=False, case=False).value_counts()
# Out:
# False    163987
# True        297
# Name: title, dtype: int64

# %% [markdown]
# Over 200 requests using the exact words "SALN" on the FOI portal. Below, we use a regex pattern to screen this more.

# %%
saln = df.title.str.extractall(r'(.*\bSALN.+)', re.IGNORECASE)
saln.columns= ['title']
#374 requests mentioning SALN.

# %%
saln = saln.merge(df, on='title')
saln
# Out:
#                                                  title agency       date  \
# 0                              SALN of Bongbong Marcos   DOTr 2016-11-25
# 1    SALN of the following: Ronnan Y. Pado, Ernani ...    DOF 2016-12-05
# 2    SALN of Niño Maximino A. Lazaro Municipal Coun...    DOF 2016-12-17
# 3    The SALNs of each of the cabinet members of th...   PCOO 2016-12-23
# 4    The SALNs of Presidents Aquino and Duterte's C...   PCOO 2017-01-18
# ..                                                 ...    ...        ...
# 489                 ITR and SALN of Barangay Officials    BIR 2022-12-09
# 490                 ITR and SALN of Barangay Officials    BIR 2022-12-09
# 491                 ITR and SALN of Barangay Officials    BIR 2022-12-09
# 492                ITR and SALN of Baranggay Officials   DILG 2022-12-09
# 493  SALNs of Gerald Quietaleg Bantag, SJO2 Ricardo...   BJMP 2023-01-09
#
#          status                                            purpose  \
# 0        DENIED                      School Paper Research(Thesis)
# 1        DENIED                                       Transparency
# 2        DENIED                                 Public Information
# 3    SUCCESSFUL                  news reporting/public information
# 4    SUCCESSFUL                                           Research
# ..          ...                                                ...
# 489     PENDING                      Accountability & Transparency
# 490      DENIED                      Accountability & Transparency
# 491     PENDING                      Accountability & Transparency
# 492     PENDING                   Accountability and Transparency.
# 493    ACCEPTED  For legal research in connection with the murd...
#
#               period_covered  \
# 0    11/25/2016 - 11/25/2016
# 1    12/31/2015 - 12/31/2015
# 2    07/01/2013 - 12/31/2015
# 3    06/30/2016 - 12/23/2016
# 4    06/30/2016 - 06/30/2016
# ..                       ...
# 489  01/01/2018 - 12/09/2022
# 490  01/01/2018 - 12/09/2022
# 491  01/01/2018 - 12/09/2022
# 492  01/01/2018 - 12/09/2022
# 493  01/08/2010 - 01/08/2023
#
#                                                   link       reason_denial
# 0                                                  NaN        wrong-agency
# 1                                                  NaN  incomplete-request
# 2                                                  NaN        wrong-agency
# 3                                                  NaN                   —
# 4                                                  NaN                   —
# ..                                                 ...                 ...
# 489  https://www.foi.gov.ph/requests/aglzfmVmb2ktcG...                 NaN
# 490  https://www.foi.gov.ph/requests/aglzfmVmb2ktcG...                 NaN
# 491  https://www.foi.gov.ph/requests/aglzfmVmb2ktcG...                 NaN
# 492  https://www.foi.gov.ph/requests/aglzfmVmb2ktcG...                 NaN
# 493  https://www.foi.gov.ph/requests/aglzfmVmb2ktcG...                 NaN
#
# [494 rows x 8 columns]

# %%
saln = saln.drop_duplicates()
saln
# Out:
#                                                  title agency       date  \
# 0                              SALN of Bongbong Marcos   DOTr 2016-11-25
# 1    SALN of the following: Ronnan Y. Pado, Ernani ...    DOF 2016-12-05
# 2    SALN of Niño Maximino A. Lazaro Municipal Coun...    DOF 2016-12-17
# 3    The SALNs of each of the cabinet members of th...   PCOO 2016-12-23
# 4    The SALNs of Presidents Aquino and Duterte's C...   PCOO 2017-01-18
# ..                                                 ...    ...        ...
# 487                          SALN of former VP Robredo    OVP 2022-11-08
# 488                 ITR and SALN of Barangay Officials    BIR 2022-12-09
# 489                 ITR and SALN of Barangay Officials    BIR 2022-12-09
# 492                ITR and SALN of Baranggay Officials   DILG 2022-12-09
# 493  SALNs of Gerald Quietaleg Bantag, SJO2 Ricardo...   BJMP 2023-01-09
#
#          status                                            purpose  \
# 0        DENIED                      School Paper Research(Thesis)
# 1        DENIED                                       Transparency
# 2        DENIED                                 Public Information
# 3    SUCCESSFUL                  news reporting/public information
# 4    SUCCESSFUL                                           Research
# ..          ...                                                ...
# 487     PENDING                 For new research and documentation
# 488      DENIED                      Accountability & Transparency
# 489     PENDING                      Accountability & Transparency
# 492     PENDING                   Accountability and Transparency.
# 493    ACCEPTED  For legal research in connection with the murd...
#
#               period_covered  \
# 0    11/25/2016 - 11/25/2016
# 1    12/31/2015 - 12/31/2015
# 2    07/01/2013 - 12/31/2015
# 3    06/30/2016 - 12/23/2016
# 4    06/30/2016 - 06/30/2016
# ..                       ...
# 487  01/01/2013 - 01/07/2022
# 488  01/01/2018 - 12/09/2022
# 489  01/01/2018 - 12/09/2022
# 492  01/01/2018 - 12/09/2022
# 493  01/08/2010 - 01/08/2023
#
#                                                   link       reason_denial
# 0                                                  NaN        wrong-agency
# 1                                                  NaN  incomplete-request
# 2                                                  NaN        wrong-agency
# 3                                                  NaN                   —
# 4                                                  NaN                   —
# ..                                                 ...                 ...
# 487  https://www.foi.gov.ph/requests/aglzfmVmb2ktcG...                 NaN
# 488  https://www.foi.gov.ph/requests/aglzfmVmb2ktcG...                 NaN
# 489  https://www.foi.gov.ph/requests/aglzfmVmb2ktcG...                 NaN
# 492  https://www.foi.gov.ph/requests/aglzfmVmb2ktcG...                 NaN
# 493  https://www.foi.gov.ph/requests/aglzfmVmb2ktcG...                 NaN
#
# [242 rows x 8 columns]

# %%
saln.to_csv('saln.csv')

# %%
df[df.agency=="OVP"].title.str.extractall(r'(.*\bSALN.+)', re.IGNORECASE).value_counts().sum()
#66 requests for the SALN of the Vice President.
# Out:
# 78

# %% [markdown]
# ## Drug war

# %%
drug_war = df.title.str.extractall(r'(.*\bdrug war.+)', re.IGNORECASE)

# %%
war_on_drugs = df.title.str.extractall(r'(.*\bwar on drugs.+)', re.IGNORECASE)

# %%
drugs = pd.concat([drug_war, war_on_drugs], ignore_index=True)
drugs
# Out:
#                                                     0
# 0                      Impact of Drug War on Children
# 1               DOJ drug war panel preliminary report
# 2                    Data breakdown of drug war cases
# 3                                    Drug war orphans
# 4                                    Drug war orphans
# 5                                    Drug war orphans
# 6                                    Drug war orphans
# 7                                    Drug war orphans
# 8   Statistics on war on drugs nationwide AND, spe...
# 9                          War On Drugs/Oplan Tokhang
# 10                   DSWD - War on Drugs Intervention
# 11  Status of War on Drugs Program Implementation ...
# 12  Statistics on war on drugs nationwide and, spe...

# %%
drugs.columns= ['title']

# %%
drugs = drugs.merge(df, on='title')
drugs.head(10)
# Out:
#                                    title agency       date  \
# 0         Impact of Drug War on Children   DSWD 2020-03-02
# 1  DOJ drug war panel preliminary report    DOJ 2021-06-14
# 2       Data breakdown of drug war cases    DOJ 2021-06-21
# 3                       Drug war orphans    PNP 2022-08-10
# 4                       Drug war orphans    PSA 2022-08-10
# 5                       Drug war orphans   DSWD 2022-08-10
# 6                       Drug war orphans    PNP 2022-08-10
# 7                       Drug war orphans    PSA 2022-08-10
# 8                       Drug war orphans    PNP 2022-08-10
# 9                       Drug war orphans    PSA 2022-08-10
#
#                  status                        purpose  \
# 0                DENIED              academic research
# 1                DENIED               For media report
# 2              ACCEPTED  For media research and report
# 3            SUCCESSFUL           Undergraduate Thesis
# 4               PENDING           Undergraduate Thesis
# 5            PROCESSING           Undergraduate thesis
# 6              ACCEPTED           Undergraduate Thesis
# 7  PARTIALLY SUCCESSFUL           Undergraduate Thesis
# 8            SUCCESSFUL           Undergraduate Thesis
# 9               PENDING           Undergraduate Thesis
#
#             period_covered                                               link  \
# 0  06/01/2016 - 03/02/2020                                                NaN
# 1  06/01/2020 - 02/01/2021                                                NaN
# 2  06/01/2016 - 05/31/2020                                                NaN
# 3  06/01/2014 - 08/10/2022  https://www.foi.gov.ph/requests/aglzfmVmb2ktcG...
# 4  06/01/2014 - 08/10/2022  https://www.foi.gov.ph/requests/aglzfmVmb2ktcG...
# 5  06/01/2014 - 08/10/2022  https://www.foi.gov.ph/requests/aglzfmVmb2ktcG...
# 6  06/01/2014 - 08/10/2022  https://www.foi.gov.ph/requests/aglzfmVmb2ktcG...
# 7  06/01/2014 - 08/10/2022  https://www.foi.gov.ph/requests/aglzfmVmb2ktcG...
# 8  06/01/2014 - 08/10/2022  https://www.foi.gov.ph/requests/aglzfmVmb2ktcG...
# 9  06/01/2014 - 08/10/2022  https://www.foi.gov.ph/requests/aglzfmVmb2ktcG...
#
#   reason_denial
# 0             —
# 1             —
# 2             —
# 3           NaN
# 4           NaN
# 5           NaN
# 6           NaN
# 7           NaN
# 8           NaN
# 9           NaN

# %% [markdown]
# ## Track request numbers through time
#
# ### By month

# %%
month_query = df.resample('M', on='date').title.count().to_frame().reset_index()
month_query.tail()
# Out:
#          date  title
# 70 2022-09-30   6349
# 71 2022-10-31   7785
# 72 2022-11-30   7758
# 73 2022-12-31   4953
# 74 2023-01-31   1213

# %%
(
    ggplot(month_query, aes(x="date", y="title")) + 
    geom_col(color="blue", stat="identity") + 
    geom_smooth()+
    theme(figure_size=(15,7), axis_ticks_length=10) + 
    labs(title="FOI requests peak in 2021")
)
# Out:
# /opt/homebrew/lib/python3.10/site-packages/plotnine/stats/smoothers.py:309: PlotnineWarning: Confidence intervals are not yet implemented for lowess smoothings.
# <ggplot: (679122917)>

# %%
month_query = df.resample('M', on='date').title.count().sort_values(ascending=False)
month_query.head(10)
#Largest number of FOI requests recorded in February 2022.
# Out:
# date
# 2022-03-31    7837
# 2022-10-31    7785
# 2022-11-30    7758
# 2022-08-31    6615
# 2022-09-30    6349
# 2022-04-30    6326
# 2022-02-28    6218
# 2021-10-31    5481
# 2021-11-30    5349
# 2022-06-30    5050
# Name: title, dtype: int64

# %% [markdown]
# ### By year

# %%
year_query = df.resample('A', on='date').title.count().to_frame().reset_index()
year_query
# Out:
#         date  title
# 0 2016-12-31    311
# 1 2017-12-31   2413
# 2 2018-12-31   6484
# 3 2019-12-31  13489
# 4 2020-12-31  25588
# 5 2021-12-31  42478
# 6 2022-12-31  72308
# 7 2023-12-31   1213

# %%
(
    ggplot(year_query, aes(x="date", y="title")) + 
    geom_col(color="blue", stat='identity') + 
    theme(figure_size=(15,7), axis_ticks_length=10) + 
    labs(title="Rising FOI requests")
)
# Out:
# <ggplot: (679382989)>

# %% [markdown]
# ## Year-on-year change shows slowing down increase in FOI requests

# %%
df.resample('A', on='date').title.count().pct_change() * 100
#2016 started in September. 2022 as of few weeks of January.
# Out:
# date
# 2016-12-31           NaN
# 2017-12-31    675.884244
# 2018-12-31    168.711148
# 2019-12-31    108.035163
# 2020-12-31     89.695307
# 2021-12-31     66.007504
# 2022-12-31     70.224587
# 2023-12-31    -98.322454
# Freq: A-DEC, Name: title, dtype: float64

# %% [markdown]
# ## Percentage of denied each month

# %%
denied = df[df.status=='DENIED'].resample('M', on='date').agency.count().to_frame().reset_index()
deny = denied.merge(month_query, how='inner', on='date') #merge denied df with year_query
deny.columns= ['date', 'denials', 'total_requests'] #rename columns

# %%
deny ['pct_denied'] = (deny.denials / deny.total_requests) * 100
deny.pct_denied.round(2)
deny
# Out:
#          date  denials  total_requests  pct_denied
# 0  2016-11-30       45             117   38.461538
# 1  2016-12-31       75             194   38.659794
# 2  2017-01-31       41              93   44.086022
# 3  2017-02-28       44             127   34.645669
# 4  2017-03-31      126             222   56.756757
# ..        ...      ...             ...         ...
# 70 2022-09-30      934            6349   14.710978
# 71 2022-10-31      828            7785   10.635838
# 72 2022-11-30      957            7758   12.335654
# 73 2022-12-31      687            4953   13.870382
# 74 2023-01-31      126            1213   10.387469
#
# [75 rows x 4 columns]

# %%
(
    ggplot(deny, aes(x="date", y="pct_denied")) + 
    geom_col(color="red", stat='identity') + 
    theme(figure_size=(15,7), axis_ticks_length=10) + 
    labs(title="Denied")
)
# Out:
# <ggplot: (678985452)>

# %% [markdown]
# ## Percentage pending

# %%
pending = df[df.status=='PENDING'].resample('M', on='date').agency.count().to_frame().reset_index()
pending = pending.merge(month_query, how='inner', on='date') #merge denied df with year_query
pending.columns= ['date', 'pending_stat', 'total_requests'] #rename columns

# %%
pending ['pct_pending'] = (pending.pending_stat / pending.total_requests) * 100
pending.pct_pending.round(2)
pending
# Out:
#          date  pending_stat  total_requests  pct_pending
# 0  2017-01-31             2              93     2.150538
# 1  2017-02-28             4             127     3.149606
# 2  2017-03-31             6             222     2.702703
# 3  2017-04-30             5             102     4.901961
# 4  2017-05-31             3             139     2.158273
# ..        ...           ...             ...          ...
# 68 2022-09-30          2055            6349    32.367302
# 69 2022-10-31          2869            7785    36.852922
# 70 2022-11-30          2943            7758    37.935035
# 71 2022-12-31          1552            4953    31.334545
# 72 2023-01-31           476            1213    39.241550
#
# [73 rows x 4 columns]

# %%
pending.to_csv('pending.csv')

# %%
(
    ggplot(pending, aes(x="date", y="pct_pending")) + 
    geom_col(color="orange", stat='identity') + 
    theme(figure_size=(15,7), axis_ticks_length=10) + 
    labs(title="Pending")
)
# Out:
# <ggplot: (679423205)>

# %% [markdown]
# ## Percentage closed
#
# These are requests which were closed after 60 days of non-response from the requestor when the FOI officer asked for clarification of the request.

# %%
closed = df[df.status=='CLOSED'].resample('M', on='date').agency.count().to_frame().reset_index()
close = closed.merge(month_query, how='inner', on='date') #merge closed df with year_query
close.columns= ['date', 'closures', 'total_requests'] #rename columns

# %%
close.head()
# Out:
#         date  closures  total_requests
# 0 2016-11-30        13             117
# 1 2016-12-31        31             194
# 2 2017-01-31         7              93
# 3 2017-02-28        11             127
# 4 2017-03-31         7             222

# %%
close ['pct_closed'] = (close.closures / close.total_requests) * 100
close.head()
# Out:
#         date  closures  total_requests  pct_closed
# 0 2016-11-30        13             117   11.111111
# 1 2016-12-31        31             194   15.979381
# 2 2017-01-31         7              93    7.526882
# 3 2017-02-28        11             127    8.661417
# 4 2017-03-31         7             222    3.153153

# %%
(
    ggplot(close, aes(x="date", y="pct_closed")) + 
    geom_col(color="yellow", stat='identity') + 
    theme(figure_size=(15,7), axis_ticks_length=10) + 
    labs(title="Closed")
)
# Out:
# <ggplot: (679203856)>

# %% [markdown]
# ## Percentage approved

# %%
approved = df[df.status=='ACCEPTED'].resample('M', on='date').agency.count().to_frame().reset_index()
approve = approved.merge(month_query, how='inner', on='date') #merge approved df with year_query
approve.columns= ['date', 'approvals', 'total_requests'] #rename columns
approve
# Out:
#          date  approvals  total_requests
# 0  2016-11-30         13             117
# 1  2016-12-31          3             194
# 2  2017-01-31          1              93
# 3  2017-02-28          4             127
# 4  2017-03-31          9             222
# ..        ...        ...             ...
# 70 2022-09-30        933            6349
# 71 2022-10-31       1127            7785
# 72 2022-11-30       1112            7758
# 73 2022-12-31        670            4953
# 74 2023-01-31        205            1213
#
# [75 rows x 3 columns]

# %%
approve ['pct_approve'] = (approve.approvals / approve.total_requests) * 100
approve
# Out:
#          date  approvals  total_requests  pct_approve
# 0  2016-11-30         13             117    11.111111
# 1  2016-12-31          3             194     1.546392
# 2  2017-01-31          1              93     1.075269
# 3  2017-02-28          4             127     3.149606
# 4  2017-03-31          9             222     4.054054
# ..        ...        ...             ...          ...
# 70 2022-09-30        933            6349    14.695228
# 71 2022-10-31       1127            7785    14.476557
# 72 2022-11-30       1112            7758    14.333591
# 73 2022-12-31        670            4953    13.527155
# 74 2023-01-31        205            1213    16.900247
#
# [75 rows x 4 columns]

# %%
(
    ggplot(approve, aes(x="date", y="pct_approve")) + 
    geom_col(color="blue", stat='identity') + 
    geom_smooth()+
    theme(figure_size=(15,7), axis_ticks_length=10) + 
    labs(title="Approved")
)
# Out:
# /opt/homebrew/lib/python3.10/site-packages/plotnine/stats/smoothers.py:309: PlotnineWarning: Confidence intervals are not yet implemented for lowess smoothings.
# <ggplot: (679380695)>

# %%
df[df.status=="DENIED"].resample('D', on='date').agency.count().mean()
# Out:
# 15.824318283415288

# %% [markdown]
# ## Regression
#
# Our questions are:
#
# - What are the odds that your FOI request will be denied if your purpose is for media use?
# - Which agency is more likely to deny an FOI request?

# %%
df.status.value_counts()
# Out:
# SUCCESSFUL                56473
# DENIED                    35399
# PENDING                   30787
# ACCEPTED                  13017
# PARTIALLY SUCCESSFUL      10814
# AWAITING CLARIFICATION     6273
# REFERRED                   4513
# CLOSED                     3464
# PROCESSING                 3454
# EXTENDED                     93
# Name: status, dtype: int64

# %%
df['status_code'] = df.status.replace({'SUCCESSFUL' or 'PARTIALLY SUCCESSFUL': 1, 'DENIED': 0})

# %%
df
# Out:
#        agency       date                                              title  \
# 0         DBM 2016-11-25  Manampalataya Royalty Fee to the Philippine Go...
# 1        PCOO 2016-11-25                                               eFOI
# 2        DOTr 2016-11-25                            SALN of Bongbong Marcos
# 3        PCOO 2016-11-25                                    Agencies in FOI
# 4         DBM 2016-11-25           Bataan Nuclaer Power Plant Annual Budget
# ...       ...        ...                                                ...
# 164282    LMB 2023-01-10   pinpoint location of property in pagbilao quezon
# 164283  DepEd 2023-01-10                                           Form 137
# 164284    DOJ 2023-01-10  margareth rillo suspect for murder and dreaded...
# 164285    DOH 2023-01-10          3,127 Covid Cases for 1st week of January
# 164286    NAP 2023-01-10  Ernesto J Valentin extrajudicial settlement am...
#
#             status                                            purpose  \
# 0           DENIED                                       Transparency
# 1           DENIED                                      Clarification
# 2           DENIED                      School Paper Research(Thesis)
# 3       SUCCESSFUL                                            R and D
# 4           DENIED                                    Thesis Research
# ...            ...                                                ...
# 164282     PENDING                        Aide intent to buy property
# 164283     PENDING                                 for college abroad
# 164284     PENDING  Lifetime Permanent Banned Blacklist Order and ...
# 164285     PENDING  Request for transparency on the respective agency
# 164286     PENDING                         for transfer of land title
#
#                  period_covered  \
# 0       11/25/2005 - 11/25/2016
# 1       11/25/2016 - 11/25/2016
# 2       11/25/2016 - 11/25/2016
# 3       11/25/2016 - 11/25/2016
# 4       01/01/2015 - 11/25/2016
# ...                         ...
# 164282  01/10/2023 - 01/10/2023
# 164283  01/01/2009 - 05/01/2013
# 164284  01/01/2018 - 01/10/2023
# 164285  01/01/2023 - 01/08/2023
# 164286  01/01/2002 - 12/12/2002
#
#                                                      link reason_denial  \
# 0                                                     NaN             —
# 1                                                     NaN             —
# 2                                                     NaN  wrong-agency
# 3                                                     NaN             —
# 4                                                     NaN             —
# ...                                                   ...           ...
# 164282  https://www.foi.gov.ph/requests/aglzfmVmb2ktcG...           NaN
# 164283  https://www.foi.gov.ph/requests/aglzfmVmb2ktcG...           NaN
# 164284  https://www.foi.gov.ph/requests/aglzfmVmb2ktcG...           NaN
# 164285  https://www.foi.gov.ph/requests/aglzfmVmb2ktcG...           NaN
# 164286  https://www.foi.gov.ph/requests/aglzfmVmb2ktcG...           NaN
#
#        status_code
# 0                0
# 1                0
# 2                0
# 3                1
# 4                0
# ...            ...
# 164282     PENDING
# 164283     PENDING
# 164284     PENDING
# 164285     PENDING
# 164286     PENDING
#
# [164287 rows x 9 columns]
