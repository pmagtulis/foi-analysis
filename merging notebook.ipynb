# %%
import pandas as pd
import numpy as np
pd.set_option('display.max_columns', None)

# %%
df = pd.concat(
    map(pd.read_csv, ['output/foi1.csv', 'output/foi2.csv', 'output/foi3.csv', 'output/foi4.csv', 'output/foi5.csv', 'output/foi6.csv', 'output/foi7.csv', 'output/foi8.csv', 'output/foi9.csv', 'output/foi10.csv', 'output/foi11.csv', 'output/foi12.csv', 'output/foi13.csv', 'output/foi14.csv', 'output/foi15.csv', 'output/foi16.csv', 'output/foi17.csv', 'output/foi18.csv', 'output/foi19.csv', 'output/foi20.csv' ]), ignore_index=True).drop_duplicates()
df
# Out:
#       agency               date  \
# 0       OWWA  November 10, 2022
# 1        PSA  November 10, 2022
# 2        PCA  November 10, 2022
# 3        PSA  November 10, 2022
# 4        NBI  November 10, 2022
# ...      ...                ...
# 39720    LMB  December 26, 2022
# 39721    LTO  December 26, 2022
# 39729    MGB  December 26, 2022
# 39819    SEC  December 23, 2022
# 39870  DepEd  December 23, 2022
#
#                                                    title  \
# 0                      The number of OFWs in Region IV-A
# 1                 Labor Force and Employment of Batangas
# 2         2020-2021 poverty incidence of coconut farmers
# 3      Poverty incidence of coconut farmers for 2020 ...
# 4         FACEBOOK SCAMMER - NELLIE ROSE BRAGANZA BENITO
# ...                                                  ...
# 39720                   BLLM Coordinates (PRS, WGS, UTM)
# 39721  NUMBER OF REGISTERED VEHICLES IN LEON, ILOILO,...
# 39729  Annual Production (in tons) of Sand, Aggregate...
# 39819              Horizon Players Club SEC registration
# 39870  Population Growth of Autism in Cavite (2015-2020)
#
#                      status  \
# 0                   PENDING
# 1                   PENDING
# 2                   PENDING
# 3                   PENDING
# 4                   PENDING
# ...                     ...
# 39720            SUCCESSFUL
# 39721            SUCCESSFUL
# 39729  PARTIALLY SUCCESSFUL
# 39819            SUCCESSFUL
# 39870                DENIED
#
#                                                  purpose  \
# 0                               Research and Development
# 1                                   Architectural Thesis
# 2           PCA Case Study - Effectiveness of Govt Corps
# 3      Philippine Coconut Authority Case Study - Enha...
# 4      To investigate and retrieve funds and put her ...
# ...                                                  ...
# 39720  For tracking parcel of lands owned by our inst...
# 39721  For project feasibility study in establishing ...
# 39729                               Research and Develop
# 39819                    For public safety and awareness
# 39870                                   Undergrad Thesis
#
#                 period_covered  \
# 0      11/10/2012 - 11/10/2022
# 1      01/01/2014 - 01/01/2022
# 2      01/10/2020 - 12/10/2021
# 3      01/10/2020 - 12/10/2021
# 4      11/09/2022 - 11/10/2022
# ...                        ...
# 39720  01/01/2000 - 01/01/2022
# 39721  12/26/2022 - 12/26/2022
# 39729  01/01/2019 - 12/26/2022
# 39819  12/23/2020 - 12/23/2022
# 39870  11/06/2015 - 11/06/2022
#
#                                                     link
# 0      https://www.foi.gov.ph/requests/aglzfmVmb2ktcG...
# 1      https://www.foi.gov.ph/requests/aglzfmVmb2ktcG...
# 2      https://www.foi.gov.ph/requests/aglzfmVmb2ktcG...
# 3      https://www.foi.gov.ph/requests/aglzfmVmb2ktcG...
# 4      https://www.foi.gov.ph/requests/aglzfmVmb2ktcG...
# ...                                                  ...
# 39720  https://www.foi.gov.ph/requests/aglzfmVmb2ktcG...
# 39721  https://www.foi.gov.ph/requests/aglzfmVmb2ktcG...
# 39729  https://www.foi.gov.ph/requests/aglzfmVmb2ktcG...
# 39819  https://www.foi.gov.ph/requests/aglzfmVmb2ktcG...
# 39870  https://www.foi.gov.ph/requests/aglzfmVmb2ktcG...
#
# [13165 rows x 7 columns]

# %%
df.date = pd.to_datetime(df.date)
df
# Out:
#       agency       date                                              title  \
# 0       OWWA 2022-11-10                  The number of OFWs in Region IV-A
# 1        PSA 2022-11-10             Labor Force and Employment of Batangas
# 2        PCA 2022-11-10     2020-2021 poverty incidence of coconut farmers
# 3        PSA 2022-11-10  Poverty incidence of coconut farmers for 2020 ...
# 4        NBI 2022-11-10     FACEBOOK SCAMMER - NELLIE ROSE BRAGANZA BENITO
# ...      ...        ...                                                ...
# 39720    LMB 2022-12-26                   BLLM Coordinates (PRS, WGS, UTM)
# 39721    LTO 2022-12-26  NUMBER OF REGISTERED VEHICLES IN LEON, ILOILO,...
# 39729    MGB 2022-12-26  Annual Production (in tons) of Sand, Aggregate...
# 39819    SEC 2022-12-23              Horizon Players Club SEC registration
# 39870  DepEd 2022-12-23  Population Growth of Autism in Cavite (2015-2020)
#
#                      status  \
# 0                   PENDING
# 1                   PENDING
# 2                   PENDING
# 3                   PENDING
# 4                   PENDING
# ...                     ...
# 39720            SUCCESSFUL
# 39721            SUCCESSFUL
# 39729  PARTIALLY SUCCESSFUL
# 39819            SUCCESSFUL
# 39870                DENIED
#
#                                                  purpose  \
# 0                               Research and Development
# 1                                   Architectural Thesis
# 2           PCA Case Study - Effectiveness of Govt Corps
# 3      Philippine Coconut Authority Case Study - Enha...
# 4      To investigate and retrieve funds and put her ...
# ...                                                  ...
# 39720  For tracking parcel of lands owned by our inst...
# 39721  For project feasibility study in establishing ...
# 39729                               Research and Develop
# 39819                    For public safety and awareness
# 39870                                   Undergrad Thesis
#
#                 period_covered  \
# 0      11/10/2012 - 11/10/2022
# 1      01/01/2014 - 01/01/2022
# 2      01/10/2020 - 12/10/2021
# 3      01/10/2020 - 12/10/2021
# 4      11/09/2022 - 11/10/2022
# ...                        ...
# 39720  01/01/2000 - 01/01/2022
# 39721  12/26/2022 - 12/26/2022
# 39729  01/01/2019 - 12/26/2022
# 39819  12/23/2020 - 12/23/2022
# 39870  11/06/2015 - 11/06/2022
#
#                                                     link
# 0      https://www.foi.gov.ph/requests/aglzfmVmb2ktcG...
# 1      https://www.foi.gov.ph/requests/aglzfmVmb2ktcG...
# 2      https://www.foi.gov.ph/requests/aglzfmVmb2ktcG...
# 3      https://www.foi.gov.ph/requests/aglzfmVmb2ktcG...
# 4      https://www.foi.gov.ph/requests/aglzfmVmb2ktcG...
# ...                                                  ...
# 39720  https://www.foi.gov.ph/requests/aglzfmVmb2ktcG...
# 39721  https://www.foi.gov.ph/requests/aglzfmVmb2ktcG...
# 39729  https://www.foi.gov.ph/requests/aglzfmVmb2ktcG...
# 39819  https://www.foi.gov.ph/requests/aglzfmVmb2ktcG...
# 39870  https://www.foi.gov.ph/requests/aglzfmVmb2ktcG...
#
# [13165 rows x 7 columns]

# %%
df2 = pd.read_csv ('foi_final.csv')
df2 = df2.drop(['Unnamed: 0'], axis=1)
df2
# Out:
# /var/folders/00/cqb74mkn60g_hf2zk42fy8_m0000gp/T/ipykernel_3363/665146622.py:1: DtypeWarning: Columns (7,8) have mixed types. Specify dtype option on import or set low_memory=False.
#   df2 = pd.read_csv ('foi_final.csv')
#         agency        date                                              title  \
# 0          DBM  2016-11-25  The Budget for local government buildings proj...
# 1          DOH  2016-11-25  Incidence of diarrhea, constipation, and respi...
# 2          PNP  2016-11-25       Crime Statatistics and Programs to Combat it
# 3         PCGG  2016-11-25  HIRING GOVERNMENT CAREER EMPLOYEES (RANK AND F...
# 4          PSA  2016-11-25                                    Late Statistics
# ...        ...         ...                                                ...
# 163226  NAMRIA  2023-01-04                 Hazard Map of Sto. Tomas, Batangas
# 163227     DOT  2023-01-04  Number of Tourist Arrivals & Tourism Growth Ra...
# 163228     PNP  2023-01-04  margareth rillo suspect for murder and dreaded...
# 163229      IC  2023-01-04                             Loyola Time Plan Claim
# 163230     DOH  2023-01-04  Number of Cases of Covid 19 in Nabua, Camarine...
#
#                       status  \
# 0                   ACCEPTED
# 1       PARTIALLY SUCCESSFUL
# 2                     CLOSED
# 3                     DENIED
# 4                     DENIED
# ...                      ...
# 163226               PENDING
# 163227               PENDING
# 163228               PENDING
# 163229               PENDING
# 163230              ACCEPTED
#
#                                                   purpose  \
# 0       Architectural Thesis entitled Cagayan de Oro C...
# 1                                                Research
# 2                                            School Paper
# 3                                      PUBLIC INFORMATION
# 4                                            Transparency
# ...                                                   ...
# 163226                               Architectural Thesis
# 163227                           Research and Development
# 163228  Lifetime Permanent Banned Blacklist Order for ...
# 163229  To use the funds for medical treatment of my p...
# 163230         Research and Academic - For Thesis Writing
#
#                  period_covered  \
# 0       11/25/2015 - 11/25/2016
# 1       11/25/2010 - 11/25/2016
# 2       01/01/2000 - 11/25/2016
# 3       11/25/2016 - 11/25/2016
# 4       11/25/1900 - 11/25/2016
# ...                         ...
# 163226  01/01/2020 - 01/04/2023
# 163227  01/01/2018 - 12/31/2022
# 163228  01/01/2018 - 01/04/2023
# 163229  01/20/2003 - 01/04/2023
# 163230  01/04/2020 - 01/04/2023
#
#                                                      link reason_denial
# 0                                                     NaN             —
# 1                                                     NaN             —
# 2                                                     NaN             —
# 3                                                     NaN             —
# 4                                                     NaN             —
# ...                                                   ...           ...
# 163226  https://www.foi.gov.ph/requests/aglzfmVmb2ktcG...           NaN
# 163227  https://www.foi.gov.ph/requests/aglzfmVmb2ktcG...           NaN
# 163228  https://www.foi.gov.ph/requests/aglzfmVmb2ktcG...           NaN
# 163229  https://www.foi.gov.ph/requests/aglzfmVmb2ktcG...           NaN
# 163230  https://www.foi.gov.ph/requests/aglzfmVmb2ktcG...           NaN
#
# [163231 rows x 8 columns]

# %%
df_final = pd.concat([df, df2]).drop_duplicates().reset_index(drop=True)
df_final
# Out:
#         agency                 date  \
# 0         OWWA  2022-11-10 00:00:00
# 1          PSA  2022-11-10 00:00:00
# 2          PCA  2022-11-10 00:00:00
# 3          PSA  2022-11-10 00:00:00
# 4          NBI  2022-11-10 00:00:00
# ...        ...                  ...
# 176391  NAMRIA           2023-01-04
# 176392     DOT           2023-01-04
# 176393     PNP           2023-01-04
# 176394      IC           2023-01-04
# 176395     DOH           2023-01-04
#
#                                                     title    status  \
# 0                       The number of OFWs in Region IV-A   PENDING
# 1                  Labor Force and Employment of Batangas   PENDING
# 2          2020-2021 poverty incidence of coconut farmers   PENDING
# 3       Poverty incidence of coconut farmers for 2020 ...   PENDING
# 4          FACEBOOK SCAMMER - NELLIE ROSE BRAGANZA BENITO   PENDING
# ...                                                   ...       ...
# 176391                 Hazard Map of Sto. Tomas, Batangas   PENDING
# 176392  Number of Tourist Arrivals & Tourism Growth Ra...   PENDING
# 176393  margareth rillo suspect for murder and dreaded...   PENDING
# 176394                             Loyola Time Plan Claim   PENDING
# 176395  Number of Cases of Covid 19 in Nabua, Camarine...  ACCEPTED
#
#                                                   purpose  \
# 0                                Research and Development
# 1                                    Architectural Thesis
# 2            PCA Case Study - Effectiveness of Govt Corps
# 3       Philippine Coconut Authority Case Study - Enha...
# 4       To investigate and retrieve funds and put her ...
# ...                                                   ...
# 176391                               Architectural Thesis
# 176392                           Research and Development
# 176393  Lifetime Permanent Banned Blacklist Order for ...
# 176394  To use the funds for medical treatment of my p...
# 176395         Research and Academic - For Thesis Writing
#
#                  period_covered  \
# 0       11/10/2012 - 11/10/2022
# 1       01/01/2014 - 01/01/2022
# 2       01/10/2020 - 12/10/2021
# 3       01/10/2020 - 12/10/2021
# 4       11/09/2022 - 11/10/2022
# ...                         ...
# 176391  01/01/2020 - 01/04/2023
# 176392  01/01/2018 - 12/31/2022
# 176393  01/01/2018 - 01/04/2023
# 176394  01/20/2003 - 01/04/2023
# 176395  01/04/2020 - 01/04/2023
#
#                                                      link reason_denial
# 0       https://www.foi.gov.ph/requests/aglzfmVmb2ktcG...           NaN
# 1       https://www.foi.gov.ph/requests/aglzfmVmb2ktcG...           NaN
# 2       https://www.foi.gov.ph/requests/aglzfmVmb2ktcG...           NaN
# 3       https://www.foi.gov.ph/requests/aglzfmVmb2ktcG...           NaN
# 4       https://www.foi.gov.ph/requests/aglzfmVmb2ktcG...           NaN
# ...                                                   ...           ...
# 176391  https://www.foi.gov.ph/requests/aglzfmVmb2ktcG...           NaN
# 176392  https://www.foi.gov.ph/requests/aglzfmVmb2ktcG...           NaN
# 176393  https://www.foi.gov.ph/requests/aglzfmVmb2ktcG...           NaN
# 176394  https://www.foi.gov.ph/requests/aglzfmVmb2ktcG...           NaN
# 176395  https://www.foi.gov.ph/requests/aglzfmVmb2ktcG...           NaN
#
# [176396 rows x 8 columns]

# %%
df_final.date = pd.to_datetime(df_final.date)

# %%
df_final = df_final.drop_duplicates().sort_values('date').reset_index(drop=True)
df_final
# Out:
#        agency       date                                              title  \
# 0         DBM 2016-11-25  Manampalataya Royalty Fee to the Philippine Go...
# 1        PCOO 2016-11-25                                               eFOI
# 2        DOTr 2016-11-25                            SALN of Bongbong Marcos
# 3        PCOO 2016-11-25                                    Agencies in FOI
# 4         DBM 2016-11-25           Bataan Nuclaer Power Plant Annual Budget
# ...       ...        ...                                                ...
# 164282    LMB 2023-01-10   pinpoint location of property in pagbilao quezon
# 164283  DepEd 2023-01-10                                           Form 137
# 164284    DOJ 2023-01-10  margareth rillo suspect for murder and dreaded...
# 164285    DOH 2023-01-10          3,127 Covid Cases for 1st week of January
# 164286    NAP 2023-01-10  Ernesto J Valentin extrajudicial settlement am...
#
#             status                                            purpose  \
# 0           DENIED                                       Transparency
# 1           DENIED                                      Clarification
# 2           DENIED                      School Paper Research(Thesis)
# 3       SUCCESSFUL                                            R and D
# 4           DENIED                                    Thesis Research
# ...            ...                                                ...
# 164282     PENDING                        Aide intent to buy property
# 164283     PENDING                                 for college abroad
# 164284     PENDING  Lifetime Permanent Banned Blacklist Order and ...
# 164285     PENDING  Request for transparency on the respective agency
# 164286     PENDING                         for transfer of land title
#
#                  period_covered  \
# 0       11/25/2005 - 11/25/2016
# 1       11/25/2016 - 11/25/2016
# 2       11/25/2016 - 11/25/2016
# 3       11/25/2016 - 11/25/2016
# 4       01/01/2015 - 11/25/2016
# ...                         ...
# 164282  01/10/2023 - 01/10/2023
# 164283  01/01/2009 - 05/01/2013
# 164284  01/01/2018 - 01/10/2023
# 164285  01/01/2023 - 01/08/2023
# 164286  01/01/2002 - 12/12/2002
#
#                                                      link reason_denial
# 0                                                     NaN             —
# 1                                                     NaN             —
# 2                                                     NaN  wrong-agency
# 3                                                     NaN             —
# 4                                                     NaN             —
# ...                                                   ...           ...
# 164282  https://www.foi.gov.ph/requests/aglzfmVmb2ktcG...           NaN
# 164283  https://www.foi.gov.ph/requests/aglzfmVmb2ktcG...           NaN
# 164284  https://www.foi.gov.ph/requests/aglzfmVmb2ktcG...           NaN
# 164285  https://www.foi.gov.ph/requests/aglzfmVmb2ktcG...           NaN
# 164286  https://www.foi.gov.ph/requests/aglzfmVmb2ktcG...           NaN
#
# [164287 rows x 8 columns]

# %%
df_final.duplicated().value_counts()
# Out:
# False    164287
# dtype: int64

# %%
df_final.date.value_counts().plot(figsize=(12,8))
# Out:
# <AxesSubplot:>

# %%
df_final.to_csv('foi_final.csv')
