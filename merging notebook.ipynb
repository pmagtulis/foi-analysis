# %%
import pandas as pd
import numpy as np
pd.set_option('display.max_columns', None)

# %%
df = pd.concat(
    map(pd.read_csv, ['output/foi1.csv', 'output/foi2.csv', 'output/foi3.csv', 'output/foi4.csv', 'output/foi5.csv', 'output/foi6.csv', 'output/foi7.csv', 'output/foi8.csv', 'output/foi9.csv', 'output/foi10.csv', 'output/foi11.csv', 'output/foi12.csv', 'output/foi13.csv', 'output/foi14.csv', 'output/foi15.csv', 'output/foi16.csv', 'output/foi17.csv']), ignore_index=True).drop_duplicates()
df
# Out:
#       agency               date  \
# 0      DepEd   January 22, 2023
# 1        DOH   January 22, 2023
# 2        DOH   January 22, 2023
# 3        NPC   January 22, 2023
# 4       DSWD   January 22, 2023
# ...      ...                ...
# 33977    LMB  February 27, 2023
# 33981    NPC  February 27, 2023
# 33993    DOH  February 27, 2023
# 33994   GSIS  February 27, 2023
# 33995    DOH  February 27, 2023
#
#                                                    title  \
# 0                                               Form 137
# 1                                        Vax Certificate
# 2                        BOOSTER VAccination Certificate
# 3      Mocha mocha keeps on charging me even I paid f...
# 4      The total number of teenage parent in 4th dist...
# ...                                                  ...
# 33977  Request for Coordinates of Tie Point Used in T...
# 33981  Complaint for Harassment and threats from Onli...
# ...

# %%
df.date = pd.to_datetime(df.date)
df
# Out:
#       agency       date                                              title  \
# 0      DepEd 2023-01-22                                           Form 137
# 1        DOH 2023-01-22                                    Vax Certificate
# 2        DOH 2023-01-22                    BOOSTER VAccination Certificate
# 3        NPC 2023-01-22  Mocha mocha keeps on charging me even I paid f...
# 4       DSWD 2023-01-22  The total number of teenage parent in 4th dist...
# ...      ...        ...                                                ...
# 33977    LMB 2023-02-27  Request for Coordinates of Tie Point Used in T...
# 33981    NPC 2023-02-27  Complaint for Harassment and threats from Onli...
# 33993    DOH 2023-02-27  CALABARZON Annual statistics of Population rat...
# 33994   GSIS 2023-02-27                                     GSIS BP Number
# 33995    DOH 2023-02-27                        STATISTICAL DATA OF PATIENT
#
#                        status  \
# 0                     PENDING
# ...

# %%
df2 = pd.read_csv ('foi_final.csv')
df2 = df2.drop(['Unnamed: 0'], axis=1)
df2
# Out:
# /var/folders/00/cqb74mkn60g_hf2zk42fy8_m0000gp/T/ipykernel_12593/665146622.py:1: DtypeWarning: Columns (7,8) have mixed types. Specify dtype option on import or set low_memory=False.
#   df2 = pd.read_csv ('foi_final.csv')
#        agency        date                                              title  \
# 0         DBM  2016-11-25  Manampalataya Royalty Fee to the Philippine Go...
# 1        PCOO  2016-11-25                                               eFOI
# 2        DOTr  2016-11-25                            SALN of Bongbong Marcos
# 3        PCOO  2016-11-25                                    Agencies in FOI
# 4         DBM  2016-11-25           Bataan Nuclaer Power Plant Annual Budget
# ...       ...         ...                                                ...
# 164282    LMB  2023-01-10   pinpoint location of property in pagbilao quezon
# 164283  DepEd  2023-01-10                                           Form 137
# ...

# %%
df_final = pd.concat([df, df2]).drop_duplicates().reset_index(drop=True)
df_final
# Out:
#        agency                 date  \
# 0       DepEd  2023-01-22 00:00:00
# 1         DOH  2023-01-22 00:00:00
# 2         DOH  2023-01-22 00:00:00
# 3         NPC  2023-01-22 00:00:00
# 4        DSWD  2023-01-22 00:00:00
# ...       ...                  ...
# 177505    LMB           2023-01-10
# 177506  DepEd           2023-01-10
# 177507    DOJ           2023-01-10
# 177508    DOH           2023-01-10
# 177509    NAP           2023-01-10
#
#                                                     title   status  \
# 0                                                Form 137  PENDING
# 1                                         Vax Certificate  PENDING
# 2                         BOOSTER VAccination Certificate  PENDING
# 3       Mocha mocha keeps on charging me even I paid f...  PENDING
# 4       The total number of teenage parent in 4th dist...  PENDING
# ...                                                   ...      ...
# ...

# %%
df_final.date = pd.to_datetime(df_final.date)

# %%
df_final = df_final.drop_duplicates().sort_values('date').reset_index(drop=True)
df_final
# Out:
#        agency       date                                              title  \
# 0         DBM 2016-11-25  Cebu City Goverment Projects and Speding for 2016
# 1         DBM 2016-11-25  The Budget for local government buildings proj...
# 2         DOH 2016-11-25  Incidence of diarrhea, constipation, and respi...
# 3         PNP 2016-11-25       Crime Statatistics and Programs to Combat it
# 4        PCGG 2016-11-25  HIRING GOVERNMENT CAREER EMPLOYEES (RANK AND F...
# ...       ...        ...                                                ...
# 177505    PSA 2023-03-10  Number of employed veterinarians under governm...
# 177506   MMDA 2023-03-10                 Contingency Plan of Las Pinas City
# 177507    PSA 2023-03-10  Floor Plan of Las Pinas Disaster Risk Reductio...
# 177508    NTC 2023-03-10                     block my phone 358680937886817
# 177509    NTC 2023-03-10                                     block my phone
#
#                       status  \
# ...

# %%
# df_final.duplicated(subset=['title', 'date']).value_counts()
# Out:
# False    143435
# True      34075
# dtype: int64

# %%
df_final[df_final.duplicated(keep='first')].sort_values('date')
# Out:
# Empty DataFrame
# Columns: [agency, date, title, status, purpose, period_covered, link, reason_denial]
# Index: []

# %%
df_final.date.value_counts().plot(figsize=(12,8))
# Out:
# <AxesSubplot:>

# %%
df_final.to_csv('foi_final.csv')
